# %% [markdown]
# # 🤖 Modelo “MargaritaLSG1”
# #### IA para Traducción de Lengua de Señas Guatemalteca
# #### Versión: 1.0
# #### Autor: Fernando Josué Rivas Mauricio

# %% [markdown]
# ## 1. Importaciones y utilidades

# %%
import os
import cv2
import math
import json
from datetime import datetime
import mediapipe as mp
from mediapipe.python.solutions.holistic import Holistic

import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.regularizers import l2
from sklearn.model_selection import train_test_split
from sklearn.metrics import (
    confusion_matrix, ConfusionMatrixDisplay,
    classification_report, f1_score
)

import tensorflow as tf
from tensorflow.keras import regularizers
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import LSTM, Dense, Dropout
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, Callback
from tensorflow.keras.losses import CategoricalCrossentropy
import math
import json
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf

from tensorflow.keras.callbacks import Callback, EarlyStopping, ModelCheckpoint
from tensorflow.keras.losses import CategoricalCrossentropy
from sklearn.model_selection import train_test_split
from sklearn.metrics import f1_score, confusion_matrix, ConfusionMatrixDisplay, classification_report

ROOT_PATH = "data"
FRAME_ACTIONS_PATH = "frases"  # carpeta por palabra/frase
FONT = cv2.FONT_HERSHEY_SIMPLEX
FONT_SIZE = 1
FONT_POS = (10, 30)

# Crear carpeta si no existe
def create_folder(path):
    if not os.path.exists(path):
        os.makedirs(path)

# Detectar si hay manos en los resultados
def there_hand(results):
    return results.left_hand_landmarks or results.right_hand_landmarks

# Dibujar los keypoints de las manos
def draw_keypoints(image, results):
    if results.left_hand_landmarks:
        mp.solutions.drawing_utils.draw_landmarks(image, results.left_hand_landmarks, mp.solutions.holistic.HAND_CONNECTIONS)
    if results.right_hand_landmarks:
        mp.solutions.drawing_utils.draw_landmarks(image, results.right_hand_landmarks, mp.solutions.holistic.HAND_CONNECTIONS)

# Aplicar MediaPipe
def mediapipe_detection(image, model):
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    image.flags.writeable = False
    results = model.process(image)
    return results

# Extraer keypoints de ambas manos
def extract_keypoints(results):
    lh = np.array([[res.x, res.y, res.z] for res in results.left_hand_landmarks.landmark]).flatten() if results.left_hand_landmarks else np.zeros(21 * 3)
    rh = np.array([[res.x, res.y, res.z] for res in results.right_hand_landmarks.landmark]).flatten() if results.right_hand_landmarks else np.zeros(21 * 3)
    return np.concatenate([lh, rh])

# %% [markdown]
# ## 2. Captura de muestras

# %%
def capture_samples_npy(path, margin_frame=1, min_cant_frames=30, delay_frames=3):
    """
    CAPTURA DE MUESTRAS PARA UNA PALABRA Y GUARDA KEYPOINTS COMO .NPY
    - Comienza a grabar cuando detecta mano.
    - Sigue 'delay_frames' tras dejar de ver la mano, para no cortar brusco.
    - Recorta 'margin_frame' al inicio y 'delay_frames' al final ANTES de guardar.
    """
    create_folder(path)

    registro_actual = len([f for f in os.listdir(path) if f.endswith(".npy")]) + 1

    cap = cv2.VideoCapture(1)  # 0 suele ser la cámara principal (cambia si usas 1)
    window_name = "Vista previa de señas"
    cv2.namedWindow(window_name, cv2.WINDOW_NORMAL)
    cv2.resizeWindow(window_name, 800, 600)

    DISPLAY_WIDTH, DISPLAY_HEIGHT = 800, 600

    recording = False
    sequence = []
    count_frame = 0
    fix_frames = 0  # cuenta frames desde que se perdió la mano

    try:
        with mp.solutions.holistic.Holistic(min_detection_confidence=0.5,
                                            min_tracking_confidence=0.5) as holistic_model:
            while cap.isOpened():
                ret, frame = cap.read()
                if not ret:
                    break

                image = frame.copy()
                results = mediapipe_detection(frame, holistic_model)
                hand_present = there_hand(results)

                if hand_present:
                    # Si volvimos a ver la mano, resetea el contador de "perdida"
                    fix_frames = 0

                    # Si no estaba grabando, inicia
                    if not recording:
                        recording = True
                        sequence = []
                        count_frame = 0

                    count_frame += 1

                    # Mostrar estado
                    cv2.putText(image, f'Registro {registro_actual}...', (10, 30), FONT, FONT_SIZE, (100, 200, 255), 2)
                    cv2.putText(image, 'Capturando...', (20, image.shape[0] - 20), FONT, FONT_SIZE, (0, 50, 255), 2)

                    # A partir del margen inicial, acumulamos keypoints
                    if count_frame > margin_frame:
                        keypoints = extract_keypoints(results)
                        if keypoints is not None:
                            sequence.append(keypoints)

                elif recording:
                    # Se perdió la mano pero seguimos unos frames por "delay"
                    fix_frames += 1
                    cv2.putText(image, f'Registro {registro_actual}...', (10, 30), FONT, FONT_SIZE, (100, 200, 255), 2)
                    cv2.putText(image, f'Finalizando... ({fix_frames}/{delay_frames})', (20, image.shape[0] - 20),
                                FONT, FONT_SIZE, (0, 165, 255), 2)

                    if fix_frames >= delay_frames:
                        # Recorte final: quitamos 'delay_frames' al final y 'margin_frame' (ya no agregamos durante margen, pero por seguridad)
                        if delay_frames > 0 and len(sequence) > delay_frames:
                            sequence = sequence[:-delay_frames]

                        # Validar longitud mínima
                        if len(sequence) >= min_cant_frames:
                            timestamp = datetime.now().strftime('%y%m%d%H%M%S%f')
                            npy_path = os.path.join(path, f'sample_{timestamp}.npy')
                            np.save(npy_path, np.array(sequence))
                            print(f"✅ Muestra guardada: {npy_path}")
                            registro_actual += 1
                        else:
                            print("⚠️ Muestra descartada por ser muy corta.")

                        # Reset total
                        recording = False
                        sequence = []
                        count_frame = 0
                        fix_frames = 0

                else:
                    # No se está grabando y no hay mano: estado en espera
                    cv2.putText(image, f'Registro {registro_actual}...', (10, 30), FONT, FONT_SIZE, (100, 200, 255), 2)
                    cv2.putText(image, 'Listo para capturar...', (20, image.shape[0] - 20),
                                FONT, FONT_SIZE, (0, 220, 100), 2)

                # Dibujo y display
                draw_keypoints(image, results)
                image_display = cv2.resize(image, (DISPLAY_WIDTH, DISPLAY_HEIGHT))
                cv2.imshow(window_name, image_display)

                # Salir
                if cv2.waitKey(10) & 0xFF == ord('q'):
                    break
    finally:
        cap.release()
        cv2.destroyAllWindows()

if __name__ == "__main__":
    palabra = "gracias"
    word_path = os.path.join(ROOT_PATH, FRAME_ACTIONS_PATH, palabra)
    capture_samples_npy(word_path)
# Out:
# ✅ Muestra guardada: data\frases\gracias\sample_250911182531253620.npy
# ⚠️ Muestra descartada por ser muy corta.
# ⚠️ Muestra descartada por ser muy corta.
# ⚠️ Muestra descartada por ser muy corta.
# ⚠️ Muestra descartada por ser muy corta.
# ⚠️ Muestra descartada por ser muy corta.
# ⚠️ Muestra descartada por ser muy corta.
# ✅ Muestra guardada: data\frases\gracias\sample_250911182551699380.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911182557178399.npy
# ⚠️ Muestra descartada por ser muy corta.
# ⚠️ Muestra descartada por ser muy corta.
# ⚠️ Muestra descartada por ser muy corta.
# ⚠️ Muestra descartada por ser muy corta.
# ✅ Muestra guardada: data\frases\gracias\sample_250911182609652599.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911182614874931.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911182619535981.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911182624444462.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911182629309559.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911182635900435.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911182641805928.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911182647692497.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911182652985512.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911182658203834.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911182708677647.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911182713531602.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911182718572370.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911182723789905.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911182729217530.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911182733625499.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911182738145656.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911182743061791.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911182747422505.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911182752010975.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911182757105233.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911182801889408.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911182806051619.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911182810312612.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911182815784281.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911182826715789.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911182831996502.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911182837035626.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911182841695210.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911182846366149.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911182851331556.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911182855802719.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911182901457507.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911182906002348.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911182910700016.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911182915731691.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911182920931061.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911182926054401.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911182930937211.npy
# ⚠️ Muestra descartada por ser muy corta.
# ⚠️ Muestra descartada por ser muy corta.
# ✅ Muestra guardada: data\frases\gracias\sample_250911182940462552.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911182945245771.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911182950521283.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911182955219519.npy
# ⚠️ Muestra descartada por ser muy corta.
# ⚠️ Muestra descartada por ser muy corta.
# ✅ Muestra guardada: data\frases\gracias\sample_250911183004448612.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911183009164195.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911183149037367.npy
# ⚠️ Muestra descartada por ser muy corta.
# ⚠️ Muestra descartada por ser muy corta.
# ✅ Muestra guardada: data\frases\gracias\sample_250911183157253516.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911183202342497.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911183206931404.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911183211705384.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911183216423461.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911183221025734.npy
# ⚠️ Muestra descartada por ser muy corta.
# ⚠️ Muestra descartada por ser muy corta.
# ✅ Muestra guardada: data\frases\gracias\sample_250911183229333465.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911183233188023.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911183238409097.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911183253944761.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911183258545612.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911183302460830.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911183307006553.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911183311244739.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911183315097610.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911183319629129.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911183324096660.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911183328452706.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911183333064273.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911183342162643.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911183347499874.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911183351786241.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911183356632410.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911183401547160.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911183406338511.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911183410497540.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911183414916113.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911183419145695.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911183424111091.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911183427961005.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911183432894619.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911183438352224.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911183443169478.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911183447749995.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911183453399086.npy
# ⚠️ Muestra descartada por ser muy corta.
# ⚠️ Muestra descartada por ser muy corta.
# ✅ Muestra guardada: data\frases\gracias\sample_250911183502420358.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911183507269468.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911183512297638.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911183517939016.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911183523221991.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911183528507283.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911183533283944.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911183538938874.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911183544328093.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911183549412719.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911183554845506.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911183559780282.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911183605328963.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911183610258573.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911183844839861.npy
# ⚠️ Muestra descartada por ser muy corta.
# ✅ Muestra guardada: data\frases\gracias\sample_250911183850114202.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911183854953744.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911183900738626.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911183905937878.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911183911594216.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911183916995536.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911183922183651.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911183929315534.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911183934534870.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911183941331379.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911183947954984.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911183952682561.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911183957151634.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911184001928682.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911184007337483.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911184012312075.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911184017913783.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911184022578578.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911184027996318.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911184035163578.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911184039388666.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911184044109721.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911184049007763.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911184053511503.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911184057626291.npy
# ⚠️ Muestra descartada por ser muy corta.
# ✅ Muestra guardada: data\frases\gracias\sample_250911184102226376.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911184107070517.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911184111524431.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911184116748845.npy
# ⚠️ Muestra descartada por ser muy corta.
# ⚠️ Muestra descartada por ser muy corta.
# ✅ Muestra guardada: data\frases\gracias\sample_250911184518986712.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911184523516425.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911184527873712.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911184532349920.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911184536510294.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911184540854088.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911184545337462.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911184549645513.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911184554076148.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911184558353260.npy
# ⚠️ Muestra descartada por ser muy corta.
# ⚠️ Muestra descartada por ser muy corta.
# ⚠️ Muestra descartada por ser muy corta.
# ✅ Muestra guardada: data\frases\gracias\sample_250911184619630381.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911184626291120.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911184633182628.npy
# ⚠️ Muestra descartada por ser muy corta.
# ✅ Muestra guardada: data\frases\gracias\sample_250911184639135858.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911184643426511.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911184648713118.npy
# ⚠️ Muestra descartada por ser muy corta.
# ✅ Muestra guardada: data\frases\gracias\sample_250911184655341051.npy
# ⚠️ Muestra descartada por ser muy corta.
# ✅ Muestra guardada: data\frases\gracias\sample_250911184701428275.npy
# ⚠️ Muestra descartada por ser muy corta.
# ✅ Muestra guardada: data\frases\gracias\sample_250911184705597757.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911184711933762.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911184717509207.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911184722424020.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911184726831884.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911184731650259.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911184736599046.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911184741155653.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911184746259776.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911184750857569.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911184756030125.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911184800841615.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911184805924136.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911184810712011.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911184815310091.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911184820021123.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911184825277653.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911184832580940.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911184837493892.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911184842356726.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911184847262204.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911184851963341.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911184902429952.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911184907711869.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911184912475949.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911184917181953.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911184922024910.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911184926476618.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911184931313146.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911184935917342.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911184940404681.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911184944980066.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911184949671094.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911184954667337.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911185000007976.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911185005135806.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911185010107930.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911185014617305.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911185020154440.npy
# ⚠️ Muestra descartada por ser muy corta.
# ✅ Muestra guardada: data\frases\gracias\sample_250911185024727453.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911185029962990.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911185034564246.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911185039162597.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911185043159715.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911185047522304.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911185051522567.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911185055692152.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911185059962000.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911185104188631.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911185108025626.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911185111709613.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911185116256621.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911185126425930.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911185130718676.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911185135638397.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911185139545833.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911185144318869.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911185148737496.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911185153005170.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911185157179888.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911185201463537.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911185205879944.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911185210557284.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911185215312986.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911185219670607.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911185225934520.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911185230748581.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911185235160839.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911185239772075.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911185244377319.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911185249729529.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911185254978541.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911185304850789.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911185309757423.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911185314410524.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911185319208805.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911185323993688.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911185328237750.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911185333330209.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911185338021972.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911185342966544.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911185348173638.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911185355225953.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911185400752564.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911185405567596.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911185410293044.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911185415448514.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911185420401227.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911185425451416.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911185429626511.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911185434282887.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911185438623346.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911185445984375.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911185452410247.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911185459491485.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911185503877540.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911185508888235.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911185513562860.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911185517971059.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911185522689585.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911185527384488.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911185531848790.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911185805933106.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911185810531519.npy
# ⚠️ Muestra descartada por ser muy corta.
# ✅ Muestra guardada: data\frases\gracias\sample_250911185814628496.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911185819222568.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911185823688912.npy
# ⚠️ Muestra descartada por ser muy corta.
# ⚠️ Muestra descartada por ser muy corta.
# ✅ Muestra guardada: data\frases\gracias\sample_250911185832940319.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911185837316467.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911185845202183.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911185849117613.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911185852835899.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911185901185468.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911185905821366.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911185910230578.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911185914571024.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911185918855092.npy
# ⚠️ Muestra descartada por ser muy corta.
# ✅ Muestra guardada: data\frases\gracias\sample_250911185924162324.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911185928563639.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911185933403567.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911185937686239.npy
# ⚠️ Muestra descartada por ser muy corta.
# ✅ Muestra guardada: data\frases\gracias\sample_250911185942161366.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911185946020322.npy
# ⚠️ Muestra descartada por ser muy corta.
# ✅ Muestra guardada: data\frases\gracias\sample_250911185950971915.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911185955570533.npy
# ⚠️ Muestra descartada por ser muy corta.
# ⚠️ Muestra descartada por ser muy corta.
# ✅ Muestra guardada: data\frases\gracias\sample_250911190004137230.npy
# ⚠️ Muestra descartada por ser muy corta.
# ✅ Muestra guardada: data\frases\gracias\sample_250911190010884951.npy
# ⚠️ Muestra descartada por ser muy corta.
# ✅ Muestra guardada: data\frases\gracias\sample_250911190016445851.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911190021817414.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911190027481407.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911190032330740.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911190037351729.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911190047216049.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911190051371840.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911190055099360.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911190059038799.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911190102818758.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911190107058130.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911190111227390.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911190115697418.npy
# ⚠️ Muestra descartada por ser muy corta.
# ✅ Muestra guardada: data\frases\gracias\sample_250911190119796118.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911190124151004.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911190132506122.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911190137102112.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911190142436354.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911190146827731.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911190151062215.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911190155416298.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911190159953238.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911190204037732.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911190208272750.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911190212483353.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911190216282694.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911190219985927.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911190224311666.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911190228238274.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911190232320540.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911190236700034.npy
# ⚠️ Muestra descartada por ser muy corta.
# ✅ Muestra guardada: data\frases\gracias\sample_250911190241271144.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911190245267406.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911190249401715.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911190253816043.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911190300579225.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911190304293320.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911190307876653.npy
# ⚠️ Muestra descartada por ser muy corta.
# ✅ Muestra guardada: data\frases\gracias\sample_250911190311520717.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911190315534369.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911190319598407.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911190323277540.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911190327441826.npy
# ⚠️ Muestra descartada por ser muy corta.
# ✅ Muestra guardada: data\frases\gracias\sample_250911190335178448.npy
# ⚠️ Muestra descartada por ser muy corta.
# ✅ Muestra guardada: data\frases\gracias\sample_250911190343992898.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911190348417361.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911190353119683.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911190357549445.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911190401957910.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911190406544310.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911190411038904.npy
# ⚠️ Muestra descartada por ser muy corta.
# ✅ Muestra guardada: data\frases\gracias\sample_250911190415390990.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911190419601118.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911190423753898.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911190428032934.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911190434102354.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911190438144104.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911190442520651.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911190446507720.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911190450561854.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911190454206277.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911190458460647.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911190502707474.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911190506638153.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911190511076235.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911190520609285.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911190524288329.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911190528471667.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911190532489794.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911190536551811.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911190540484686.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911190544225603.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911190547804893.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911190551504323.npy
# ✅ Muestra guardada: data\frases\gracias\sample_250911190555243557.npy

# %% [markdown]
# ## 3. Normalización

# %%
ROOT_PATH = "data"
FRAME_ACTIONS_PATH = "frases"
MODEL_FRAMES = 30  

def normalize_keypoints_sequence(sequence, target_len=30):
    current_len = len(sequence)
    if current_len == target_len:
        return sequence
    elif current_len > target_len:
        # Reducir seleccionando frames uniformemente
        step = current_len / target_len
        indices = np.arange(0, current_len, step).astype(int)[:target_len]
        return sequence[indices]
    else:
        # Interpolar si es menor
        indices = np.linspace(0, current_len - 1, target_len)
        interpolated = []
        for i in indices:
            lower = int(np.floor(i))
            upper = int(np.ceil(i))
            weight = i - lower
            if upper >= current_len:
                upper = current_len - 1
            interpolated_frame = (1 - weight) * sequence[lower] + weight * sequence[upper]
            interpolated.append(interpolated_frame)
        return np.array(interpolated)

def process_npy_directory(word_directory, target_len=30):
    for fname in os.listdir(word_directory):
        if fname.endswith(".npy"):
            full_path = os.path.join(word_directory, fname)
            sequence = np.load(full_path)
            normalized = normalize_keypoints_sequence(sequence, target_len)
            np.save(full_path, normalized)
            print(f"✅ Normalizado: {fname} → {normalized.shape}")

if __name__ == "__main__":
    word_ids = [w for w in os.listdir(os.path.join(ROOT_PATH, FRAME_ACTIONS_PATH))]

    for word_id in word_ids:
        word_path = os.path.join(ROOT_PATH, FRAME_ACTIONS_PATH, word_id)
        if os.path.isdir(word_path):
            print(f"\n📦 Normalizando muestras de: {word_id}")
            process_npy_directory(word_path, target_len=MODEL_FRAMES)
# Out:
# 📦 Normalizando muestras de: adios
# ✅ Normalizado: sample_250911173514093009.npy → (30, 126)
# ✅ Normalizado: sample_250911173518505603.npy → (30, 126)
# ✅ Normalizado: sample_250911173522246092.npy → (30, 126)
# ✅ Normalizado: sample_250911173526969190.npy → (30, 126)
# ✅ Normalizado: sample_250911173531286471.npy → (30, 126)
# ✅ Normalizado: sample_250911173535634534.npy → (30, 126)
# ✅ Normalizado: sample_250911173540405201.npy → (30, 126)
# ✅ Normalizado: sample_250911173544863093.npy → (30, 126)
# ✅ Normalizado: sample_250911173549505823.npy → (30, 126)
# ✅ Normalizado: sample_250911173555224834.npy → (30, 126)
# ✅ Normalizado: sample_250911173559660009.npy → (30, 126)
# ✅ Normalizado: sample_250911173603810097.npy → (30, 126)
# ✅ Normalizado: sample_250911173607785777.npy → (30, 126)
# ✅ Normalizado: sample_250911173611721971.npy → (30, 126)
# ✅ Normalizado: sample_250911173615495941.npy → (30, 126)
# ✅ Normalizado: sample_250911173619508317.npy → (30, 126)
# ✅ Normalizado: sample_250911173623721692.npy → (30, 126)
# ✅ Normalizado: sample_250911173628052003.npy → (30, 126)
# ✅ Normalizado: sample_250911173632610122.npy → (30, 126)
# ✅ Normalizado: sample_250911173637009838.npy → (30, 126)
# ✅ Normalizado: sample_250911173643723327.npy → (30, 126)
# ✅ Normalizado: sample_250911173647739107.npy → (30, 126)
# ✅ Normalizado: sample_250911173652064031.npy → (30, 126)
# ✅ Normalizado: sample_250911173656639397.npy → (30, 126)
# ✅ Normalizado: sample_250911173701405777.npy → (30, 126)
# ✅ Normalizado: sample_250911173706403531.npy → (30, 126)
# ✅ Normalizado: sample_250911173710816204.npy → (30, 126)
# ✅ Normalizado: sample_250911173715162950.npy → (30, 126)
# ✅ Normalizado: sample_250911173719075918.npy → (30, 126)
# ✅ Normalizado: sample_250911173724176720.npy → (30, 126)
# ✅ Normalizado: sample_250911173734863917.npy → (30, 126)
# ✅ Normalizado: sample_250911173738281514.npy → (30, 126)
# ✅ Normalizado: sample_250911173743304784.npy → (30, 126)
# ✅ Normalizado: sample_250911173747699336.npy → (30, 126)
# ✅ Normalizado: sample_250911173751983579.npy → (30, 126)
# ✅ Normalizado: sample_250911173755901310.npy → (30, 126)
# ✅ Normalizado: sample_250911173800294311.npy → (30, 126)
# ✅ Normalizado: sample_250911173804645417.npy → (30, 126)
# ✅ Normalizado: sample_250911173808485943.npy → (30, 126)
# ✅ Normalizado: sample_250911173812556631.npy → (30, 126)
# ✅ Normalizado: sample_250911173914781166.npy → (30, 126)
# ✅ Normalizado: sample_250911173919486969.npy → (30, 126)
# ✅ Normalizado: sample_250911173924110425.npy → (30, 126)
# ✅ Normalizado: sample_250911173928234949.npy → (30, 126)
# ✅ Normalizado: sample_250911173933062978.npy → (30, 126)
# ✅ Normalizado: sample_250911173937300496.npy → (30, 126)
# ✅ Normalizado: sample_250911173942393610.npy → (30, 126)
# ✅ Normalizado: sample_250911173946320348.npy → (30, 126)
# ✅ Normalizado: sample_250911173951211482.npy → (30, 126)
# ✅ Normalizado: sample_250911173955309578.npy → (30, 126)
# ✅ Normalizado: sample_250911174000339539.npy → (30, 126)
# ✅ Normalizado: sample_250911174004179283.npy → (30, 126)
# ✅ Normalizado: sample_250911174008278386.npy → (30, 126)
# ✅ Normalizado: sample_250911174012483298.npy → (30, 126)
# ✅ Normalizado: sample_250911174017151466.npy → (30, 126)
# ✅ Normalizado: sample_250911174021918900.npy → (30, 126)
# ✅ Normalizado: sample_250911174026534962.npy → (30, 126)
# ✅ Normalizado: sample_250911174031309583.npy → (30, 126)
# ✅ Normalizado: sample_250911174036002750.npy → (30, 126)
# ✅ Normalizado: sample_250911174041210895.npy → (30, 126)
# ✅ Normalizado: sample_250911174045768206.npy → (30, 126)
# ✅ Normalizado: sample_250911174049915690.npy → (30, 126)
# ✅ Normalizado: sample_250911174054057775.npy → (30, 126)
# ✅ Normalizado: sample_250911174113002743.npy → (30, 126)
# ✅ Normalizado: sample_250911174117657816.npy → (30, 126)
# ✅ Normalizado: sample_250911174122248713.npy → (30, 126)
# ✅ Normalizado: sample_250911174126667644.npy → (30, 126)
# ✅ Normalizado: sample_250911174131132766.npy → (30, 126)
# ✅ Normalizado: sample_250911174135043299.npy → (30, 126)
# ✅ Normalizado: sample_250911174139117333.npy → (30, 126)
# ✅ Normalizado: sample_250911174147800677.npy → (30, 126)
# ✅ Normalizado: sample_250911174155147674.npy → (30, 126)
# ✅ Normalizado: sample_250911174159495111.npy → (30, 126)
# ✅ Normalizado: sample_250911174204145455.npy → (30, 126)
# ✅ Normalizado: sample_250911174208419068.npy → (30, 126)
# ✅ Normalizado: sample_250911174212329646.npy → (30, 126)
# ✅ Normalizado: sample_250911174216853323.npy → (30, 126)
# ✅ Normalizado: sample_250911174221072751.npy → (30, 126)
# ✅ Normalizado: sample_250911174225302527.npy → (30, 126)
# ✅ Normalizado: sample_250911174229932691.npy → (30, 126)
# ✅ Normalizado: sample_250911174250824903.npy → (30, 126)
# ✅ Normalizado: sample_250911174255551935.npy → (30, 126)
# ✅ Normalizado: sample_250911174300019220.npy → (30, 126)
# ✅ Normalizado: sample_250911174305072368.npy → (30, 126)
# ✅ Normalizado: sample_250911174309706097.npy → (30, 126)
# ✅ Normalizado: sample_250911174314603841.npy → (30, 126)
# ✅ Normalizado: sample_250911174318869166.npy → (30, 126)
# ✅ Normalizado: sample_250911174323269421.npy → (30, 126)
# ✅ Normalizado: sample_250911174328289658.npy → (30, 126)
# ✅ Normalizado: sample_250911174332954520.npy → (30, 126)
# ✅ Normalizado: sample_250911174336873273.npy → (30, 126)
# ✅ Normalizado: sample_250911174341036293.npy → (30, 126)
# ✅ Normalizado: sample_250911174345213565.npy → (30, 126)
# ✅ Normalizado: sample_250911174351208652.npy → (30, 126)
# ✅ Normalizado: sample_250911174355053234.npy → (30, 126)
# ✅ Normalizado: sample_250911174359338330.npy → (30, 126)
# ✅ Normalizado: sample_250911174403240472.npy → (30, 126)
# ✅ Normalizado: sample_250911174407067710.npy → (30, 126)
# ✅ Normalizado: sample_250911174411016481.npy → (30, 126)
# ✅ Normalizado: sample_250911174415465765.npy → (30, 126)
# ✅ Normalizado: sample_250911174458771810.npy → (30, 126)
# ✅ Normalizado: sample_250911174503677633.npy → (30, 126)
# ✅ Normalizado: sample_250911174510668601.npy → (30, 126)
# ✅ Normalizado: sample_250911174516427411.npy → (30, 126)
# ✅ Normalizado: sample_250911174522517268.npy → (30, 126)
# ✅ Normalizado: sample_250911174528687657.npy → (30, 126)
# ✅ Normalizado: sample_250911174534442876.npy → (30, 126)
# ✅ Normalizado: sample_250911174539796681.npy → (30, 126)
# ✅ Normalizado: sample_250911174544804154.npy → (30, 126)
# ✅ Normalizado: sample_250911174550263480.npy → (30, 126)
# ✅ Normalizado: sample_250911174559584193.npy → (30, 126)
# ✅ Normalizado: sample_250911174603857851.npy → (30, 126)
# ✅ Normalizado: sample_250911174608812149.npy → (30, 126)
# ✅ Normalizado: sample_250911174613336135.npy → (30, 126)
# ✅ Normalizado: sample_250911174617998331.npy → (30, 126)
# ✅ Normalizado: sample_250911174622523370.npy → (30, 126)
# ✅ Normalizado: sample_250911174627141208.npy → (30, 126)
# ✅ Normalizado: sample_250911174631715899.npy → (30, 126)
# ✅ Normalizado: sample_250911174635871954.npy → (30, 126)
# ✅ Normalizado: sample_250911174640209736.npy → (30, 126)
# ✅ Normalizado: sample_250911174647507690.npy → (30, 126)
# ✅ Normalizado: sample_250911174651209947.npy → (30, 126)
# ✅ Normalizado: sample_250911174655064987.npy → (30, 126)
# ✅ Normalizado: sample_250911174708500992.npy → (30, 126)
# ✅ Normalizado: sample_250911174713067990.npy → (30, 126)
# ✅ Normalizado: sample_250911174717960931.npy → (30, 126)
# ✅ Normalizado: sample_250911174722476169.npy → (30, 126)
# ✅ Normalizado: sample_250911174726741061.npy → (30, 126)
# ✅ Normalizado: sample_250911174731076454.npy → (30, 126)
# ✅ Normalizado: sample_250911174735829903.npy → (30, 126)
# ✅ Normalizado: sample_250911174740620636.npy → (30, 126)
# ✅ Normalizado: sample_250911174745218275.npy → (30, 126)
# ✅ Normalizado: sample_250911174749934200.npy → (30, 126)
# ✅ Normalizado: sample_250911174754965572.npy → (30, 126)
# ✅ Normalizado: sample_250911174800524500.npy → (30, 126)
# ✅ Normalizado: sample_250911174805796413.npy → (30, 126)
# ✅ Normalizado: sample_250911174810812085.npy → (30, 126)
# ✅ Normalizado: sample_250911174815958907.npy → (30, 126)
# ✅ Normalizado: sample_250911174820915245.npy → (30, 126)
# ✅ Normalizado: sample_250911174825069002.npy → (30, 126)
# ✅ Normalizado: sample_250911174829324618.npy → (30, 126)
# ✅ Normalizado: sample_250911174833221388.npy → (30, 126)
# ✅ Normalizado: sample_250911174836710632.npy → (30, 126)
# ✅ Normalizado: sample_250911174840745200.npy → (30, 126)
# ✅ Normalizado: sample_250911174844405593.npy → (30, 126)
# ✅ Normalizado: sample_250911174848567579.npy → (30, 126)
# ✅ Normalizado: sample_250911174852353885.npy → (30, 126)
# ✅ Normalizado: sample_250911174857099679.npy → (30, 126)
# ✅ Normalizado: sample_250911174902295411.npy → (30, 126)
# ✅ Normalizado: sample_250911174906571261.npy → (30, 126)
# ✅ Normalizado: sample_250911174917559317.npy → (30, 126)
# ✅ Normalizado: sample_250911174921414025.npy → (30, 126)
# ✅ Normalizado: sample_250911174925067177.npy → (30, 126)
# ✅ Normalizado: sample_250911174928957346.npy → (30, 126)
# ✅ Normalizado: sample_250911174932919475.npy → (30, 126)
# ✅ Normalizado: sample_250911174940000873.npy → (30, 126)
# ✅ Normalizado: sample_250911174943414274.npy → (30, 126)
# ✅ Normalizado: sample_250911174947452675.npy → (30, 126)
# ✅ Normalizado: sample_250911174950917755.npy → (30, 126)
# ✅ Normalizado: sample_250911174954955269.npy → (30, 126)
# ✅ Normalizado: sample_250911174958363926.npy → (30, 126)
# ✅ Normalizado: sample_250911175002521308.npy → (30, 126)
# ✅ Normalizado: sample_250911175006375142.npy → (30, 126)
# ✅ Normalizado: sample_250911175011224901.npy → (30, 126)
# ✅ Normalizado: sample_250911175016011339.npy → (30, 126)
# ✅ Normalizado: sample_250911175021100932.npy → (30, 126)
# ✅ Normalizado: sample_250911175025461536.npy → (30, 126)
# ✅ Normalizado: sample_250911175030168513.npy → (30, 126)
# ✅ Normalizado: sample_250911175039270299.npy → (30, 126)
# ✅ Normalizado: sample_250911175043727315.npy → (30, 126)
# ✅ Normalizado: sample_250911175053062468.npy → (30, 126)
# ✅ Normalizado: sample_250911175057898238.npy → (30, 126)
# ✅ Normalizado: sample_250911175102806158.npy → (30, 126)
# ✅ Normalizado: sample_250911175106741184.npy → (30, 126)
# ✅ Normalizado: sample_250911175110091805.npy → (30, 126)
# ✅ Normalizado: sample_250911175114389373.npy → (30, 126)
# ✅ Normalizado: sample_250911175118671263.npy → (30, 126)
# ✅ Normalizado: sample_250911175122774833.npy → (30, 126)
# ✅ Normalizado: sample_250911175127171282.npy → (30, 126)
# ✅ Normalizado: sample_250911175131383837.npy → (30, 126)
# ✅ Normalizado: sample_250911175143031421.npy → (30, 126)
# ✅ Normalizado: sample_250911175147502862.npy → (30, 126)
# ✅ Normalizado: sample_250911175152277751.npy → (30, 126)
# ✅ Normalizado: sample_250911175159581391.npy → (30, 126)
# ✅ Normalizado: sample_250911175203785263.npy → (30, 126)
# ✅ Normalizado: sample_250911175207889238.npy → (30, 126)
# ✅ Normalizado: sample_250911175212402795.npy → (30, 126)
# ✅ Normalizado: sample_250911175217546315.npy → (30, 126)
# ✅ Normalizado: sample_250911175221933541.npy → (30, 126)
# ✅ Normalizado: sample_250911175226267464.npy → (30, 126)
# ✅ Normalizado: sample_250911175229938662.npy → (30, 126)
# ✅ Normalizado: sample_250911175233824528.npy → (30, 126)
# ✅ Normalizado: sample_250911175237429770.npy → (30, 126)
# ✅ Normalizado: sample_250911175240715782.npy → (30, 126)
# ✅ Normalizado: sample_250911175246751850.npy → (30, 126)
# ✅ Normalizado: sample_250911175251062047.npy → (30, 126)
# ✅ Normalizado: sample_250911175255120641.npy → (30, 126)
# ✅ Normalizado: sample_250911175259881829.npy → (30, 126)
# ✅ Normalizado: sample_250911175304718569.npy → (30, 126)
# ✅ Normalizado: sample_250911175309177271.npy → (30, 126)
# ✅ Normalizado: sample_250911175313167339.npy → (30, 126)
# ✅ Normalizado: sample_250911175317125323.npy → (30, 126)
# ✅ Normalizado: sample_250911175321338795.npy → (30, 126)
# ✅ Normalizado: sample_250911175324933973.npy → (30, 126)
# ✅ Normalizado: sample_250911175328814356.npy → (30, 126)
# ✅ Normalizado: sample_250911175332600407.npy → (30, 126)
# ✅ Normalizado: sample_250911175336266143.npy → (30, 126)
# ✅ Normalizado: sample_250911175341839329.npy → (30, 126)
# ✅ Normalizado: sample_250911175346087295.npy → (30, 126)
# ✅ Normalizado: sample_250911175350170660.npy → (30, 126)
# ✅ Normalizado: sample_250911175401815592.npy → (30, 126)
# ✅ Normalizado: sample_250911175405217445.npy → (30, 126)
# ✅ Normalizado: sample_250911175409349112.npy → (30, 126)
# ✅ Normalizado: sample_250911175413329289.npy → (30, 126)
# ✅ Normalizado: sample_250911175417198937.npy → (30, 126)
# ✅ Normalizado: sample_250911175421174351.npy → (30, 126)
# ✅ Normalizado: sample_250911175425270366.npy → (30, 126)
# ✅ Normalizado: sample_250911175428367814.npy → (30, 126)
# ✅ Normalizado: sample_250911175431719726.npy → (30, 126)
# ✅ Normalizado: sample_250911175435507248.npy → (30, 126)
# ✅ Normalizado: sample_250911175442686216.npy → (30, 126)
# ✅ Normalizado: sample_250911175447035519.npy → (30, 126)
# ✅ Normalizado: sample_250911175452101545.npy → (30, 126)
# ✅ Normalizado: sample_250911175456206209.npy → (30, 126)
# ✅ Normalizado: sample_250911175500292172.npy → (30, 126)
# ✅ Normalizado: sample_250911175508045524.npy → (30, 126)
# ✅ Normalizado: sample_250911175513354728.npy → (30, 126)
# ✅ Normalizado: sample_250911175518039306.npy → (30, 126)
# ✅ Normalizado: sample_250911175522323408.npy → (30, 126)
# ✅ Normalizado: sample_250911175527999452.npy → (30, 126)
# ✅ Normalizado: sample_250911175533993369.npy → (30, 126)
# ✅ Normalizado: sample_250911175537885934.npy → (30, 126)
# ✅ Normalizado: sample_250911175541964329.npy → (30, 126)
# ✅ Normalizado: sample_250911175546151307.npy → (30, 126)
# ✅ Normalizado: sample_250911175600434487.npy → (30, 126)
# ✅ Normalizado: sample_250911175604413329.npy → (30, 126)
# ✅ Normalizado: sample_250911175608723704.npy → (30, 126)
# ✅ Normalizado: sample_250911175612979746.npy → (30, 126)
# ✅ Normalizado: sample_250911175616880344.npy → (30, 126)
# ✅ Normalizado: sample_250911175620958663.npy → (30, 126)
# ✅ Normalizado: sample_250911175717948487.npy → (30, 126)
# ✅ Normalizado: sample_250911175722946053.npy → (30, 126)
# ✅ Normalizado: sample_250911175727356087.npy → (30, 126)
# ✅ Normalizado: sample_250911175731947634.npy → (30, 126)
# ✅ Normalizado: sample_250911175737467422.npy → (30, 126)
# ✅ Normalizado: sample_250911175742615688.npy → (30, 126)
# ✅ Normalizado: sample_250911175747254485.npy → (30, 126)
# ✅ Normalizado: sample_250911175750958836.npy → (30, 126)
# ✅ Normalizado: sample_250911175755410387.npy → (30, 126)
# ✅ Normalizado: sample_250911175800813369.npy → (30, 126)
# ✅ Normalizado: sample_250911175828924665.npy → (30, 126)
# ✅ Normalizado: sample_250911175832839781.npy → (30, 126)
# ✅ Normalizado: sample_250911175836321747.npy → (30, 126)
# ✅ Normalizado: sample_250911175840051870.npy → (30, 126)
# ✅ Normalizado: sample_250911175844152309.npy → (30, 126)
# ✅ Normalizado: sample_250911175848432174.npy → (30, 126)
# ✅ Normalizado: sample_250911175855922800.npy → (30, 126)
# ✅ Normalizado: sample_250911175859523187.npy → (30, 126)
# ✅ Normalizado: sample_250911175903185644.npy → (30, 126)
# ✅ Normalizado: sample_250911175907970236.npy → (30, 126)
# ✅ Normalizado: sample_250911175912829764.npy → (30, 126)
# ✅ Normalizado: sample_250911175916304425.npy → (30, 126)
# ✅ Normalizado: sample_250911175920331924.npy → (30, 126)
# ✅ Normalizado: sample_250911175923928566.npy → (30, 126)
# ✅ Normalizado: sample_250911175927468204.npy → (30, 126)
# ✅ Normalizado: sample_250911175934607390.npy → (30, 126)
# ✅ Normalizado: sample_250911175938708921.npy → (30, 126)
# ✅ Normalizado: sample_250911175942370774.npy → (30, 126)
# ✅ Normalizado: sample_250911175951131503.npy → (30, 126)
# ✅ Normalizado: sample_250911175955165987.npy → (30, 126)
# ✅ Normalizado: sample_250911180004944690.npy → (30, 126)
# ✅ Normalizado: sample_250911180008794899.npy → (30, 126)
# ✅ Normalizado: sample_250911180013385530.npy → (30, 126)
# ✅ Normalizado: sample_250911180017489377.npy → (30, 126)
# ✅ Normalizado: sample_250911180021410316.npy → (30, 126)
# ✅ Normalizado: sample_250911180025021231.npy → (30, 126)
# ✅ Normalizado: sample_250911180029123614.npy → (30, 126)
# ✅ Normalizado: sample_250911180032845923.npy → (30, 126)
# ✅ Normalizado: sample_250911180036695603.npy → (30, 126)
# ✅ Normalizado: sample_250911180040535811.npy → (30, 126)
# ✅ Normalizado: sample_250911180044846349.npy → (30, 126)
# ✅ Normalizado: sample_250911180048980071.npy → (30, 126)
# ✅ Normalizado: sample_250911180052642164.npy → (30, 126)
# ✅ Normalizado: sample_250911180057016234.npy → (30, 126)
# ✅ Normalizado: sample_250911180101369476.npy → (30, 126)
# ✅ Normalizado: sample_250911180110919404.npy → (30, 126)
# ✅ Normalizado: sample_250911180115222945.npy → (30, 126)
# ✅ Normalizado: sample_250911180119568800.npy → (30, 126)
# ✅ Normalizado: sample_250911180124154385.npy → (30, 126)
# ✅ Normalizado: sample_250911180132459768.npy → (30, 126)
# ✅ Normalizado: sample_250911180136637535.npy → (30, 126)
# ✅ Normalizado: sample_250911180140187261.npy → (30, 126)
# ✅ Normalizado: sample_250911180144198837.npy → (30, 126)
# ✅ Normalizado: sample_250911180148184921.npy → (30, 126)
# ✅ Normalizado: sample_250911180152528491.npy → (30, 126)
# ✅ Normalizado: sample_250911180157082809.npy → (30, 126)
# ✅ Normalizado: sample_250911180201474319.npy → (30, 126)
# ✅ Normalizado: sample_250911180234713801.npy → (30, 126)
# ✅ Normalizado: sample_250911180240339242.npy → (30, 126)
# ✅ Normalizado: sample_250911180246191290.npy → (30, 126)
# ✅ Normalizado: sample_250911180310075347.npy → (30, 126)
# ✅ Normalizado: sample_250911180313984763.npy → (30, 126)
# ✅ Normalizado: sample_250911180317953225.npy → (30, 126)
# ✅ Normalizado: sample_250911180321941046.npy → (30, 126)
# ✅ Normalizado: sample_250911180326092570.npy → (30, 126)
# ✅ Normalizado: sample_250911180330032671.npy → (30, 126)
# ✅ Normalizado: sample_250911180334381955.npy → (30, 126)
# ✅ Normalizado: sample_250911180338052466.npy → (30, 126)
# ✅ Normalizado: sample_250911180341707839.npy → (30, 126)
# ✅ Normalizado: sample_250911180348686002.npy → (30, 126)
# ✅ Normalizado: sample_250911180353629061.npy → (30, 126)
# ✅ Normalizado: sample_250911180358237891.npy → (30, 126)
# ✅ Normalizado: sample_250911180403226728.npy → (30, 126)
# ✅ Normalizado: sample_250911180407567385.npy → (30, 126)
# ✅ Normalizado: sample_250911180411477320.npy → (30, 126)
# ✅ Normalizado: sample_250911180416308635.npy → (30, 126)
# ✅ Normalizado: sample_250911180421638931.npy → (30, 126)
# ✅ Normalizado: sample_250911180425667502.npy → (30, 126)
# ✅ Normalizado: sample_250911180429577943.npy → (30, 126)
# ✅ Normalizado: sample_250911180442929839.npy → (30, 126)
# ✅ Normalizado: sample_250911180446585522.npy → (30, 126)
# ✅ Normalizado: sample_250911180450430701.npy → (30, 126)
# ✅ Normalizado: sample_250911180454528615.npy → (30, 126)
# ✅ Normalizado: sample_250911180459072802.npy → (30, 126)
# ✅ Normalizado: sample_250911180503042124.npy → (30, 126)
# ✅ Normalizado: sample_250911180507644432.npy → (30, 126)
# ✅ Normalizado: sample_250911180512289807.npy → (30, 126)
# ✅ Normalizado: sample_250911180516384246.npy → (30, 126)
# ✅ Normalizado: sample_250911180519989950.npy → (30, 126)
# ✅ Normalizado: sample_250911180524388196.npy → (30, 126)
# ✅ Normalizado: sample_250911180534563606.npy → (30, 126)
# ✅ Normalizado: sample_250911180539040742.npy → (30, 126)
# ✅ Normalizado: sample_250911180543698381.npy → (30, 126)
# ✅ Normalizado: sample_250911180548345647.npy → (30, 126)
# ✅ Normalizado: sample_250911180552305528.npy → (30, 126)
# ✅ Normalizado: sample_250911180556200245.npy → (30, 126)
# ✅ Normalizado: sample_250911180600664172.npy → (30, 126)
# ✅ Normalizado: sample_250911180604880640.npy → (30, 126)
# ✅ Normalizado: sample_250911180608788139.npy → (30, 126)
# ✅ Normalizado: sample_250911180613384366.npy → (30, 126)
# ✅ Normalizado: sample_250911180626029681.npy → (30, 126)
# ✅ Normalizado: sample_250911180630432584.npy → (30, 126)
# ✅ Normalizado: sample_250911180633907473.npy → (30, 126)
# ✅ Normalizado: sample_250911180637880816.npy → (30, 126)
# ✅ Normalizado: sample_250911180641860619.npy → (30, 126)
# ✅ Normalizado: sample_250911180646232546.npy → (30, 126)
# ✅ Normalizado: sample_250911180649903674.npy → (30, 126)
# ✅ Normalizado: sample_250911180655028824.npy → (30, 126)
# ✅ Normalizado: sample_250911180659161669.npy → (30, 126)
# ✅ Normalizado: sample_250911180704639874.npy → (30, 126)
# ✅ Normalizado: sample_250911180735322297.npy → (30, 126)
# ✅ Normalizado: sample_250911180739040516.npy → (30, 126)
# ✅ Normalizado: sample_250911180743269500.npy → (30, 126)
# ✅ Normalizado: sample_250911180746746273.npy → (30, 126)
# ✅ Normalizado: sample_250911180751030371.npy → (30, 126)
# ✅ Normalizado: sample_250911180755373798.npy → (30, 126)
# ✅ Normalizado: sample_250911180759600632.npy → (30, 126)
# ✅ Normalizado: sample_250911180802960370.npy → (30, 126)
# ✅ Normalizado: sample_250911180806439418.npy → (30, 126)
# ✅ Normalizado: sample_250911180815352447.npy → (30, 126)
# ✅ Normalizado: sample_250911180818882881.npy → (30, 126)
# ✅ Normalizado: sample_250911180823041418.npy → (30, 126)
# ✅ Normalizado: sample_250911180826955904.npy → (30, 126)
# ✅ Normalizado: sample_250911180831310754.npy → (30, 126)
# ✅ Normalizado: sample_250911180835772514.npy → (30, 126)
# ✅ Normalizado: sample_250911180839775077.npy → (30, 126)
# ✅ Normalizado: sample_250911180843748173.npy → (30, 126)
# ✅ Normalizado: sample_250911180847944159.npy → (30, 126)
# ✅ Normalizado: sample_250911180852292823.npy → (30, 126)
# ✅ Normalizado: sample_250911180857163403.npy → (30, 126)
# ✅ Normalizado: sample_250911180911546052.npy → (30, 126)
# ✅ Normalizado: sample_250911180915415611.npy → (30, 126)
# ✅ Normalizado: sample_250911180920675672.npy → (30, 126)
# ✅ Normalizado: sample_250911180924260135.npy → (30, 126)
# ✅ Normalizado: sample_250911180928038554.npy → (30, 126)
# ✅ Normalizado: sample_250911180931905563.npy → (30, 126)
# ✅ Normalizado: sample_250911180935689845.npy → (30, 126)
# ✅ Normalizado: sample_250911180939173961.npy → (30, 126)
# ✅ Normalizado: sample_250911180942969722.npy → (30, 126)
# ✅ Normalizado: sample_250911180950688484.npy → (30, 126)
# ✅ Normalizado: sample_250911180959058689.npy → (30, 126)
# ✅ Normalizado: sample_250911181004334600.npy → (30, 126)
# ✅ Normalizado: sample_250911181009116644.npy → (30, 126)
# ✅ Normalizado: sample_250911181013661010.npy → (30, 126)
# ✅ Normalizado: sample_250911181018174209.npy → (30, 126)
# ✅ Normalizado: sample_250911181022765729.npy → (30, 126)
# ✅ Normalizado: sample_250911181027343776.npy → (30, 126)
# ✅ Normalizado: sample_250911181032174568.npy → (30, 126)
# ✅ Normalizado: sample_250911181037267561.npy → (30, 126)
# ✅ Normalizado: sample_250911181042204917.npy → (30, 126)
# ✅ Normalizado: sample_250911181046843609.npy → (30, 126)
# ✅ Normalizado: sample_250911181054342440.npy → (30, 126)
# ✅ Normalizado: sample_250911181058205741.npy → (30, 126)
# ✅ Normalizado: sample_250911181102435273.npy → (30, 126)
# ✅ Normalizado: sample_250911181106207318.npy → (30, 126)
# ✅ Normalizado: sample_250911181109734140.npy → (30, 126)
# ✅ Normalizado: sample_250911181113261629.npy → (30, 126)
# ✅ Normalizado: sample_250911181116547342.npy → (30, 126)
# ✅ Normalizado: sample_250911181120151188.npy → (30, 126)
# ✅ Normalizado: sample_250911181123990144.npy → (30, 126)
#
# 📦 Normalizando muestras de: feliz
# ✅ Normalizado: sample_250814162855548020.npy → (30, 126)
# ✅ Normalizado: sample_250814162859542306.npy → (30, 126)
# ✅ Normalizado: sample_250814162903820233.npy → (30, 126)
# ✅ Normalizado: sample_250814162907921888.npy → (30, 126)
# ✅ Normalizado: sample_250814162912129448.npy → (30, 126)
# ✅ Normalizado: sample_250814162916433365.npy → (30, 126)
# ✅ Normalizado: sample_250814162920721241.npy → (30, 126)
# ✅ Normalizado: sample_250814162924935005.npy → (30, 126)
# ✅ Normalizado: sample_250814162928970091.npy → (30, 126)
# ✅ Normalizado: sample_250814162940214360.npy → (30, 126)
# ✅ Normalizado: sample_250814162949077440.npy → (30, 126)
# ✅ Normalizado: sample_250814162953686389.npy → (30, 126)
# ✅ Normalizado: sample_250814162958326498.npy → (30, 126)
# ✅ Normalizado: sample_250814163003078372.npy → (30, 126)
# ✅ Normalizado: sample_250814163008372251.npy → (30, 126)
# ✅ Normalizado: sample_250814163012976561.npy → (30, 126)
# ✅ Normalizado: sample_250814163017368203.npy → (30, 126)
# ✅ Normalizado: sample_250814163021703320.npy → (30, 126)
# ✅ Normalizado: sample_250814163025976404.npy → (30, 126)
# ✅ Normalizado: sample_250814163030394478.npy → (30, 126)
# ✅ Normalizado: sample_250814163038825601.npy → (30, 126)
# ✅ Normalizado: sample_250814163043571407.npy → (30, 126)
# ✅ Normalizado: sample_250814163047793462.npy → (30, 126)
# ✅ Normalizado: sample_250814163051994304.npy → (30, 126)
# ✅ Normalizado: sample_250814163056473249.npy → (30, 126)
# ✅ Normalizado: sample_250814163100698383.npy → (30, 126)
# ✅ Normalizado: sample_250814163105359189.npy → (30, 126)
# ✅ Normalizado: sample_250814163109768236.npy → (30, 126)
# ✅ Normalizado: sample_250814163114058739.npy → (30, 126)
# ✅ Normalizado: sample_250814163118409328.npy → (30, 126)
# ✅ Normalizado: sample_250814163126714586.npy → (30, 126)
# ✅ Normalizado: sample_250814163130626520.npy → (30, 126)
# ✅ Normalizado: sample_250814163134661413.npy → (30, 126)
# ✅ Normalizado: sample_250814163138616285.npy → (30, 126)
# ✅ Normalizado: sample_250814163142834160.npy → (30, 126)
# ✅ Normalizado: sample_250814163146810261.npy → (30, 126)
# ✅ Normalizado: sample_250814163150612091.npy → (30, 126)
# ✅ Normalizado: sample_250814163154498338.npy → (30, 126)
# ✅ Normalizado: sample_250814163158807041.npy → (30, 126)
# ✅ Normalizado: sample_250814163203126470.npy → (30, 126)
# ✅ Normalizado: sample_250814163212249580.npy → (30, 126)
# ✅ Normalizado: sample_250814163216265162.npy → (30, 126)
# ✅ Normalizado: sample_250814163220491765.npy → (30, 126)
# ✅ Normalizado: sample_250814163224678202.npy → (30, 126)
# ✅ Normalizado: sample_250814163228224220.npy → (30, 126)
# ✅ Normalizado: sample_250814163232024509.npy → (30, 126)
# ✅ Normalizado: sample_250814163235754389.npy → (30, 126)
# ✅ Normalizado: sample_250814163239649600.npy → (30, 126)
# ✅ Normalizado: sample_250814163243210183.npy → (30, 126)
# ✅ Normalizado: sample_250814163247065522.npy → (30, 126)
# ✅ Normalizado: sample_250814163254041332.npy → (30, 126)
# ✅ Normalizado: sample_250814163257458262.npy → (30, 126)
# ✅ Normalizado: sample_250814163301276224.npy → (30, 126)
# ✅ Normalizado: sample_250814163304864314.npy → (30, 126)
# ✅ Normalizado: sample_250814163308564422.npy → (30, 126)
# ✅ Normalizado: sample_250814163312458320.npy → (30, 126)
# ✅ Normalizado: sample_250814163316418157.npy → (30, 126)
# ✅ Normalizado: sample_250814163320245670.npy → (30, 126)
# ✅ Normalizado: sample_250814163323886478.npy → (30, 126)
# ✅ Normalizado: sample_250814163334616603.npy → (30, 126)
# ✅ Normalizado: sample_250814163338617974.npy → (30, 126)
# ✅ Normalizado: sample_250814163342457848.npy → (30, 126)
# ✅ Normalizado: sample_250814163345971590.npy → (30, 126)
# ✅ Normalizado: sample_250814163349330621.npy → (30, 126)
# ✅ Normalizado: sample_250814163353114325.npy → (30, 126)
# ✅ Normalizado: sample_250814163356764338.npy → (30, 126)
# ✅ Normalizado: sample_250814163400294133.npy → (30, 126)
# ✅ Normalizado: sample_250814163403905626.npy → (30, 126)
# ✅ Normalizado: sample_250814163407409402.npy → (30, 126)
# ✅ Normalizado: sample_250814163411244257.npy → (30, 126)
# ✅ Normalizado: sample_250814163422114305.npy → (30, 126)
# ✅ Normalizado: sample_250814163425738120.npy → (30, 126)
# ✅ Normalizado: sample_250814163429361535.npy → (30, 126)
# ✅ Normalizado: sample_250814163433081434.npy → (30, 126)
# ✅ Normalizado: sample_250814163437096234.npy → (30, 126)
# ✅ Normalizado: sample_250814163440780994.npy → (30, 126)
# ✅ Normalizado: sample_250814163444378398.npy → (30, 126)
# ✅ Normalizado: sample_250814163448134105.npy → (30, 126)
# ✅ Normalizado: sample_250814163451981875.npy → (30, 126)
# ✅ Normalizado: sample_250814163455666113.npy → (30, 126)
# ✅ Normalizado: sample_250814163503274423.npy → (30, 126)
# ✅ Normalizado: sample_250814163506824498.npy → (30, 126)
# ✅ Normalizado: sample_250814163510346541.npy → (30, 126)
# ✅ Normalizado: sample_250814163514946969.npy → (30, 126)
# ✅ Normalizado: sample_250814163518477199.npy → (30, 126)
# ✅ Normalizado: sample_250814163522070202.npy → (30, 126)
# ✅ Normalizado: sample_250814163525771797.npy → (30, 126)
# ✅ Normalizado: sample_250814163529262211.npy → (30, 126)
# ✅ Normalizado: sample_250814163533154130.npy → (30, 126)
# ✅ Normalizado: sample_250814163536388579.npy → (30, 126)
# ✅ Normalizado: sample_250814163551654549.npy → (30, 126)
# ✅ Normalizado: sample_250814163555751459.npy → (30, 126)
# ✅ Normalizado: sample_250814163559598045.npy → (30, 126)
# ✅ Normalizado: sample_250814163603250746.npy → (30, 126)
# ✅ Normalizado: sample_250814163606997110.npy → (30, 126)
# ✅ Normalizado: sample_250814163610415787.npy → (30, 126)
# ✅ Normalizado: sample_250814163613813462.npy → (30, 126)
# ✅ Normalizado: sample_250814163617383862.npy → (30, 126)
# ✅ Normalizado: sample_250814163621208868.npy → (30, 126)
# ✅ Normalizado: sample_250814163628693638.npy → (30, 126)
# ✅ Normalizado: sample_250814163634859440.npy → (30, 126)
# ✅ Normalizado: sample_250814163638307400.npy → (30, 126)
# ✅ Normalizado: sample_250814163642017042.npy → (30, 126)
# ✅ Normalizado: sample_250814163645817348.npy → (30, 126)
# ✅ Normalizado: sample_250814163649234532.npy → (30, 126)
# ✅ Normalizado: sample_250814163652796375.npy → (30, 126)
# ✅ Normalizado: sample_250814163656311031.npy → (30, 126)
# ✅ Normalizado: sample_250814163659851113.npy → (30, 126)
# ✅ Normalizado: sample_250814163703221822.npy → (30, 126)
# ✅ Normalizado: sample_250814163708639221.npy → (30, 126)
# ✅ Normalizado: sample_250814163716048356.npy → (30, 126)
# ✅ Normalizado: sample_250814163719644186.npy → (30, 126)
# ✅ Normalizado: sample_250814163723420421.npy → (30, 126)
# ✅ Normalizado: sample_250814163730714557.npy → (30, 126)
# ✅ Normalizado: sample_250814163734232892.npy → (30, 126)
# ✅ Normalizado: sample_250814163737974754.npy → (30, 126)
# ✅ Normalizado: sample_250814163741844952.npy → (30, 126)
# ✅ Normalizado: sample_250814163745723116.npy → (30, 126)
# ✅ Normalizado: sample_250814163749469924.npy → (30, 126)
# ✅ Normalizado: sample_250814163756317294.npy → (30, 126)
# ✅ Normalizado: sample_250814163806542997.npy → (30, 126)
# ✅ Normalizado: sample_250814163810329353.npy → (30, 126)
# ✅ Normalizado: sample_250814163854963059.npy → (30, 126)
# ✅ Normalizado: sample_250814163859111981.npy → (30, 126)
# ✅ Normalizado: sample_250814163903239509.npy → (30, 126)
# ✅ Normalizado: sample_250814163907480153.npy → (30, 126)
# ✅ Normalizado: sample_250814163911569780.npy → (30, 126)
# ✅ Normalizado: sample_250814163915767046.npy → (30, 126)
# ✅ Normalizado: sample_250814163919966586.npy → (30, 126)
# ✅ Normalizado: sample_250814163924253060.npy → (30, 126)
# ✅ Normalizado: sample_250814163935471433.npy → (30, 126)
# ✅ Normalizado: sample_250814163939619464.npy → (30, 126)
# ✅ Normalizado: sample_250814163943680679.npy → (30, 126)
# ✅ Normalizado: sample_250814163947531440.npy → (30, 126)
# ✅ Normalizado: sample_250814163951257293.npy → (30, 126)
# ✅ Normalizado: sample_250814163955164345.npy → (30, 126)
# ✅ Normalizado: sample_250814163959020668.npy → (30, 126)
# ✅ Normalizado: sample_250814164003213022.npy → (30, 126)
# ✅ Normalizado: sample_250814164007231617.npy → (30, 126)
# ✅ Normalizado: sample_250814164010973884.npy → (30, 126)
# ✅ Normalizado: sample_250814164017224678.npy → (30, 126)
# ✅ Normalizado: sample_250814164020583272.npy → (30, 126)
# ✅ Normalizado: sample_250814164036757577.npy → (30, 126)
# ✅ Normalizado: sample_250814164040750751.npy → (30, 126)
# ✅ Normalizado: sample_250814164045285811.npy → (30, 126)
# ✅ Normalizado: sample_250814164049613086.npy → (30, 126)
# ✅ Normalizado: sample_250814164054104155.npy → (30, 126)
# ✅ Normalizado: sample_250814164058321214.npy → (30, 126)
# ✅ Normalizado: sample_250814164102748422.npy → (30, 126)
# ✅ Normalizado: sample_250814164107085093.npy → (30, 126)
# ✅ Normalizado: sample_250814164118746827.npy → (30, 126)
# ✅ Normalizado: sample_250814164122781984.npy → (30, 126)
# ✅ Normalizado: sample_250814164127431495.npy → (30, 126)
# ✅ Normalizado: sample_250814164132271434.npy → (30, 126)
# ✅ Normalizado: sample_250814164137110216.npy → (30, 126)
# ✅ Normalizado: sample_250814164141733796.npy → (30, 126)
# ✅ Normalizado: sample_250814164319478598.npy → (30, 126)
# ✅ Normalizado: sample_250814164324065003.npy → (30, 126)
# ✅ Normalizado: sample_250814164328714239.npy → (30, 126)
# ✅ Normalizado: sample_250814164333312001.npy → (30, 126)
# ✅ Normalizado: sample_250814164339668486.npy → (30, 126)
# ✅ Normalizado: sample_250814164344027356.npy → (30, 126)
# ✅ Normalizado: sample_250814164348365176.npy → (30, 126)
# ✅ Normalizado: sample_250814164353348797.npy → (30, 126)
# ✅ Normalizado: sample_250814164357569770.npy → (30, 126)
# ✅ Normalizado: sample_250814164402122959.npy → (30, 126)
# ✅ Normalizado: sample_250814164410343329.npy → (30, 126)
# ✅ Normalizado: sample_250814164415072199.npy → (30, 126)
# ✅ Normalizado: sample_250814164419733282.npy → (30, 126)
# ✅ Normalizado: sample_250814164430896631.npy → (30, 126)
# ✅ Normalizado: sample_250814164435571112.npy → (30, 126)
# ✅ Normalizado: sample_250814164439971585.npy → (30, 126)
# ✅ Normalizado: sample_250814164444680119.npy → (30, 126)
# ✅ Normalizado: sample_250814164448962138.npy → (30, 126)
# ✅ Normalizado: sample_250814164453210843.npy → (30, 126)
# ✅ Normalizado: sample_250814164457513837.npy → (30, 126)
# ✅ Normalizado: sample_250814164618729111.npy → (30, 126)
# ✅ Normalizado: sample_250814164622994439.npy → (30, 126)
# ✅ Normalizado: sample_250814164627288581.npy → (30, 126)
# ✅ Normalizado: sample_250814164632032417.npy → (30, 126)
# ✅ Normalizado: sample_250814164636505448.npy → (30, 126)
# ✅ Normalizado: sample_250814164641076729.npy → (30, 126)
# ✅ Normalizado: sample_250814164645873169.npy → (30, 126)
# ✅ Normalizado: sample_250814164650682568.npy → (30, 126)
# ✅ Normalizado: sample_250814164655413145.npy → (30, 126)
# ✅ Normalizado: sample_250814164706680845.npy → (30, 126)
# ✅ Normalizado: sample_250814164710694598.npy → (30, 126)
# ✅ Normalizado: sample_250814164715080945.npy → (30, 126)
# ✅ Normalizado: sample_250814164719552756.npy → (30, 126)
# ✅ Normalizado: sample_250814164724074508.npy → (30, 126)
# ✅ Normalizado: sample_250814164732634750.npy → (30, 126)
# ✅ Normalizado: sample_250814164736616928.npy → (30, 126)
# ✅ Normalizado: sample_250814164741038640.npy → (30, 126)
# ✅ Normalizado: sample_250814164745689751.npy → (30, 126)
# ✅ Normalizado: sample_250814164750329877.npy → (30, 126)
# ✅ Normalizado: sample_250814164754838137.npy → (30, 126)
# ✅ Normalizado: sample_250814164759850032.npy → (30, 126)
# ✅ Normalizado: sample_250814164804286839.npy → (30, 126)
# ✅ Normalizado: sample_250814164808977031.npy → (30, 126)
# ✅ Normalizado: sample_250814164813509012.npy → (30, 126)
# ✅ Normalizado: sample_250814164822087058.npy → (30, 126)
# ✅ Normalizado: sample_250814164825516826.npy → (30, 126)
# ✅ Normalizado: sample_250814164829622836.npy → (30, 126)
# ✅ Normalizado: sample_250814164833516985.npy → (30, 126)
# ✅ Normalizado: sample_250814164837652152.npy → (30, 126)
# ✅ Normalizado: sample_250814164841173969.npy → (30, 126)
# ✅ Normalizado: sample_250814164845306955.npy → (30, 126)
# ✅ Normalizado: sample_250814164849195282.npy → (30, 126)
# ✅ Normalizado: sample_250814164853299893.npy → (30, 126)
# ✅ Normalizado: sample_250814164857167001.npy → (30, 126)
# ✅ Normalizado: sample_250814164904082108.npy → (30, 126)
# ✅ Normalizado: sample_250814164907834655.npy → (30, 126)
# ✅ Normalizado: sample_250814164911873929.npy → (30, 126)
# ✅ Normalizado: sample_250814164915976248.npy → (30, 126)
# ✅ Normalizado: sample_250814164920228849.npy → (30, 126)
# ✅ Normalizado: sample_250814164924356670.npy → (30, 126)
# ✅ Normalizado: sample_250814164928786740.npy → (30, 126)
# ✅ Normalizado: sample_250814164933424913.npy → (30, 126)
# ✅ Normalizado: sample_250814164937937941.npy → (30, 126)
# ✅ Normalizado: sample_250814164942518834.npy → (30, 126)
# ✅ Normalizado: sample_250814164957349848.npy → (30, 126)
# ✅ Normalizado: sample_250814165001612838.npy → (30, 126)
# ✅ Normalizado: sample_250814165005233752.npy → (30, 126)
# ✅ Normalizado: sample_250814165009092060.npy → (30, 126)
# ✅ Normalizado: sample_250814165013059646.npy → (30, 126)
# ✅ Normalizado: sample_250814165016801097.npy → (30, 126)
# ✅ Normalizado: sample_250814165020596764.npy → (30, 126)
# ✅ Normalizado: sample_250814165025047166.npy → (30, 126)
# ✅ Normalizado: sample_250814165029210071.npy → (30, 126)
# ✅ Normalizado: sample_250814165033456275.npy → (30, 126)
# ✅ Normalizado: sample_250814165040059104.npy → (30, 126)
# ✅ Normalizado: sample_250814165043922747.npy → (30, 126)
# ✅ Normalizado: sample_250814165048343138.npy → (30, 126)
# ✅ Normalizado: sample_250814165052390150.npy → (30, 126)
# ✅ Normalizado: sample_250814165056228922.npy → (30, 126)
# ✅ Normalizado: sample_250814165100000759.npy → (30, 126)
# ✅ Normalizado: sample_250814165104186946.npy → (30, 126)
# ✅ Normalizado: sample_250814165108746800.npy → (30, 126)
# ✅ Normalizado: sample_250814165112373182.npy → (30, 126)
# ✅ Normalizado: sample_250814165116766974.npy → (30, 126)
# ✅ Normalizado: sample_250814165120840956.npy → (30, 126)
# ✅ Normalizado: sample_250814165129828461.npy → (30, 126)
# ✅ Normalizado: sample_250814165133636022.npy → (30, 126)
# ✅ Normalizado: sample_250814165137717040.npy → (30, 126)
# ✅ Normalizado: sample_250814165142426833.npy → (30, 126)
# ✅ Normalizado: sample_250814165146459453.npy → (30, 126)
# ✅ Normalizado: sample_250814165150779330.npy → (30, 126)
# ✅ Normalizado: sample_250814165155053948.npy → (30, 126)
# ✅ Normalizado: sample_250814165158867964.npy → (30, 126)
# ✅ Normalizado: sample_250814165202360811.npy → (30, 126)
# ✅ Normalizado: sample_250814165213187094.npy → (30, 126)
# ✅ Normalizado: sample_250814165217676877.npy → (30, 126)
# ✅ Normalizado: sample_250814165221916984.npy → (30, 126)
# ✅ Normalizado: sample_250814165226216833.npy → (30, 126)
# ✅ Normalizado: sample_250814165230256950.npy → (30, 126)
# ✅ Normalizado: sample_250814165234190903.npy → (30, 126)
# ✅ Normalizado: sample_250814165237817911.npy → (30, 126)
# ✅ Normalizado: sample_250814165241602117.npy → (30, 126)
# ✅ Normalizado: sample_250814165245626911.npy → (30, 126)
# ✅ Normalizado: sample_250814165249035096.npy → (30, 126)
# ✅ Normalizado: sample_250814165256816916.npy → (30, 126)
# ✅ Normalizado: sample_250814165300449545.npy → (30, 126)
# ✅ Normalizado: sample_250814165304530475.npy → (30, 126)
# ✅ Normalizado: sample_250814165308736625.npy → (30, 126)
# ✅ Normalizado: sample_250814165312948814.npy → (30, 126)
# ✅ Normalizado: sample_250814165317380705.npy → (30, 126)
# ✅ Normalizado: sample_250814165321722568.npy → (30, 126)
# ✅ Normalizado: sample_250814165325474279.npy → (30, 126)
# ✅ Normalizado: sample_250814165329323482.npy → (30, 126)
# ✅ Normalizado: sample_250814165333466602.npy → (30, 126)
# ✅ Normalizado: sample_250814165341325975.npy → (30, 126)
# ✅ Normalizado: sample_250814165345096719.npy → (30, 126)
# ✅ Normalizado: sample_250814165348624372.npy → (30, 126)
# ✅ Normalizado: sample_250814165352588077.npy → (30, 126)
# ✅ Normalizado: sample_250814165356742659.npy → (30, 126)
# ✅ Normalizado: sample_250814165400972742.npy → (30, 126)
# ✅ Normalizado: sample_250814165405221757.npy → (30, 126)
# ✅ Normalizado: sample_250814165408576600.npy → (30, 126)
# ✅ Normalizado: sample_250814165412186722.npy → (30, 126)
# ✅ Normalizado: sample_250814165415217944.npy → (30, 126)
# ✅ Normalizado: sample_250814165426328866.npy → (30, 126)
# ✅ Normalizado: sample_250814165430384824.npy → (30, 126)
# ✅ Normalizado: sample_250814165434450454.npy → (30, 126)
# ✅ Normalizado: sample_250814165438835491.npy → (30, 126)
# ✅ Normalizado: sample_250814165443403639.npy → (30, 126)
# ✅ Normalizado: sample_250814165447406687.npy → (30, 126)
# ✅ Normalizado: sample_250814165451115955.npy → (30, 126)
# ✅ Normalizado: sample_250814165454638680.npy → (30, 126)
# ✅ Normalizado: sample_250814165458768710.npy → (30, 126)
# ✅ Normalizado: sample_250814165502182544.npy → (30, 126)
# ✅ Normalizado: sample_250814165509456956.npy → (30, 126)
# ✅ Normalizado: sample_250814165513054588.npy → (30, 126)
# ✅ Normalizado: sample_250814165516666673.npy → (30, 126)
# ✅ Normalizado: sample_250814165520148928.npy → (30, 126)
# ✅ Normalizado: sample_250814165523496587.npy → (30, 126)
# ✅ Normalizado: sample_250814165526766882.npy → (30, 126)
# ✅ Normalizado: sample_250814165530679878.npy → (30, 126)
# ✅ Normalizado: sample_250814165534756865.npy → (30, 126)
# ✅ Normalizado: sample_250814165538693436.npy → (30, 126)
# ✅ Normalizado: sample_250814165542014437.npy → (30, 126)
# ✅ Normalizado: sample_250911165051891507.npy → (30, 126)
# ✅ Normalizado: sample_250911165056553938.npy → (30, 126)
# ✅ Normalizado: sample_250911165101155841.npy → (30, 126)
# ✅ Normalizado: sample_250911165105699250.npy → (30, 126)
# ✅ Normalizado: sample_250911165110663827.npy → (30, 126)
# ✅ Normalizado: sample_250911165115577360.npy → (30, 126)
# ✅ Normalizado: sample_250911165120444420.npy → (30, 126)
# ✅ Normalizado: sample_250911165125162437.npy → (30, 126)
# ✅ Normalizado: sample_250911165129940986.npy → (30, 126)
# ✅ Normalizado: sample_250911165134782473.npy → (30, 126)
# ✅ Normalizado: sample_250911172131182117.npy → (30, 126)
# ✅ Normalizado: sample_250911172140390493.npy → (30, 126)
# ✅ Normalizado: sample_250911172144929819.npy → (30, 126)
# ✅ Normalizado: sample_250911172149844324.npy → (30, 126)
# ✅ Normalizado: sample_250911172154602724.npy → (30, 126)
# ✅ Normalizado: sample_250911172159725220.npy → (30, 126)
# ✅ Normalizado: sample_250911172204811531.npy → (30, 126)
# ✅ Normalizado: sample_250911172209938715.npy → (30, 126)
# ✅ Normalizado: sample_250911172215390913.npy → (30, 126)
# ✅ Normalizado: sample_250911172221389778.npy → (30, 126)
# ✅ Normalizado: sample_250911172230500418.npy → (30, 126)
# ✅ Normalizado: sample_250911172234890271.npy → (30, 126)
# ✅ Normalizado: sample_250911172242981993.npy → (30, 126)
# ✅ Normalizado: sample_250911172248099995.npy → (30, 126)
# ✅ Normalizado: sample_250911172252849930.npy → (30, 126)
# ✅ Normalizado: sample_250911172257833170.npy → (30, 126)
# ✅ Normalizado: sample_250911172303097920.npy → (30, 126)
# ✅ Normalizado: sample_250911172308540880.npy → (30, 126)
# ✅ Normalizado: sample_250911172313338293.npy → (30, 126)
# ✅ Normalizado: sample_250911172318474833.npy → (30, 126)
# ✅ Normalizado: sample_250911172415457907.npy → (30, 126)
# ✅ Normalizado: sample_250911172419937827.npy → (30, 126)
# ✅ Normalizado: sample_250911172424522431.npy → (30, 126)
# ✅ Normalizado: sample_250911172429371991.npy → (30, 126)
# ✅ Normalizado: sample_250911172434152768.npy → (30, 126)
# ✅ Normalizado: sample_250911172438574503.npy → (30, 126)
# ✅ Normalizado: sample_250911172443110261.npy → (30, 126)
# ✅ Normalizado: sample_250911172447396223.npy → (30, 126)
# ✅ Normalizado: sample_250911172452544433.npy → (30, 126)
# ✅ Normalizado: sample_250911172457634670.npy → (30, 126)
# ✅ Normalizado: sample_250911172507878683.npy → (30, 126)
# ✅ Normalizado: sample_250911172513216038.npy → (30, 126)
# ✅ Normalizado: sample_250911172518612724.npy → (30, 126)
# ✅ Normalizado: sample_250911172523841673.npy → (30, 126)
# ✅ Normalizado: sample_250911172529247918.npy → (30, 126)
# ✅ Normalizado: sample_250911172534267560.npy → (30, 126)
# ✅ Normalizado: sample_250911172539292704.npy → (30, 126)
# ✅ Normalizado: sample_250911172544259905.npy → (30, 126)
# ✅ Normalizado: sample_250911172554948744.npy → (30, 126)
# ✅ Normalizado: sample_250911172607193497.npy → (30, 126)
# ✅ Normalizado: sample_250911172616516357.npy → (30, 126)
# ✅ Normalizado: sample_250911172626624218.npy → (30, 126)
# ✅ Normalizado: sample_250911172632271392.npy → (30, 126)
# ✅ Normalizado: sample_250911172637889978.npy → (30, 126)
# ✅ Normalizado: sample_250911172642988904.npy → (30, 126)
# ✅ Normalizado: sample_250911172650200585.npy → (30, 126)
# ✅ Normalizado: sample_250911172655342834.npy → (30, 126)
# ✅ Normalizado: sample_250911172700937869.npy → (30, 126)
# ✅ Normalizado: sample_250911172706162038.npy → (30, 126)
# ✅ Normalizado: sample_250911172711373227.npy → (30, 126)
# ✅ Normalizado: sample_250911172723412040.npy → (30, 126)
# ✅ Normalizado: sample_250911172728167334.npy → (30, 126)
# ✅ Normalizado: sample_250911172732568680.npy → (30, 126)
# ✅ Normalizado: sample_250911172737518642.npy → (30, 126)
# ✅ Normalizado: sample_250911172742788214.npy → (30, 126)
# ✅ Normalizado: sample_250911172747791375.npy → (30, 126)
# ✅ Normalizado: sample_250911172752851942.npy → (30, 126)
# ✅ Normalizado: sample_250911172757976176.npy → (30, 126)
# ✅ Normalizado: sample_250911172802957479.npy → (30, 126)
# ✅ Normalizado: sample_250911172807748011.npy → (30, 126)
# ✅ Normalizado: sample_250911172815939061.npy → (30, 126)
# ✅ Normalizado: sample_250911172820881928.npy → (30, 126)
# ✅ Normalizado: sample_250911172825678659.npy → (30, 126)
# ✅ Normalizado: sample_250911172830667357.npy → (30, 126)
# ✅ Normalizado: sample_250911172835644398.npy → (30, 126)
# ✅ Normalizado: sample_250911172840900188.npy → (30, 126)
# ✅ Normalizado: sample_250911172855065752.npy → (30, 126)
# ✅ Normalizado: sample_250911172859851525.npy → (30, 126)
# ✅ Normalizado: sample_250911172904447671.npy → (30, 126)
# ✅ Normalizado: sample_250911172909020974.npy → (30, 126)
# ✅ Normalizado: sample_250911173024972064.npy → (30, 126)
# ✅ Normalizado: sample_250911173035079691.npy → (30, 126)
# ✅ Normalizado: sample_250911173125414153.npy → (30, 126)
# ✅ Normalizado: sample_250911173130155074.npy → (30, 126)
# ✅ Normalizado: sample_250911173135084637.npy → (30, 126)
# ✅ Normalizado: sample_250911173140584051.npy → (30, 126)
# ✅ Normalizado: sample_250911173145889768.npy → (30, 126)
# ✅ Normalizado: sample_250911173150941952.npy → (30, 126)
# ✅ Normalizado: sample_250911173155740262.npy → (30, 126)
# ✅ Normalizado: sample_250911173200998159.npy → (30, 126)
# ✅ Normalizado: sample_250911173232338544.npy → (30, 126)
# ✅ Normalizado: sample_250911173236896069.npy → (30, 126)
# ✅ Normalizado: sample_250911173241936432.npy → (30, 126)
# ✅ Normalizado: sample_250911173246624876.npy → (30, 126)
# ✅ Normalizado: sample_250911173251253966.npy → (30, 126)
# ✅ Normalizado: sample_250911173256186131.npy → (30, 126)
# ✅ Normalizado: sample_250911173300882159.npy → (30, 126)
# ✅ Normalizado: sample_250911173305443164.npy → (30, 126)
# ✅ Normalizado: sample_250911173310620167.npy → (30, 126)
# ✅ Normalizado: sample_250911173336943328.npy → (30, 126)
#
# 📦 Normalizando muestras de: gracias
# ✅ Normalizado: sample_250911181824335095.npy → (30, 126)
# ✅ Normalizado: sample_250911181828925117.npy → (30, 126)
# ✅ Normalizado: sample_250911181832951640.npy → (30, 126)
# ✅ Normalizado: sample_250911181837163875.npy → (30, 126)
# ✅ Normalizado: sample_250911181845347696.npy → (30, 126)
# ✅ Normalizado: sample_250911181849871305.npy → (30, 126)
# ✅ Normalizado: sample_250911181854348066.npy → (30, 126)
# ✅ Normalizado: sample_250911181903603574.npy → (30, 126)
# ✅ Normalizado: sample_250911181907518653.npy → (30, 126)
# ✅ Normalizado: sample_250911181928727380.npy → (30, 126)
# ✅ Normalizado: sample_250911181937271495.npy → (30, 126)
# ✅ Normalizado: sample_250911181941643244.npy → (30, 126)
# ✅ Normalizado: sample_250911181945984842.npy → (30, 126)
# ✅ Normalizado: sample_250911181949852861.npy → (30, 126)
# ✅ Normalizado: sample_250911181957281651.npy → (30, 126)
# ✅ Normalizado: sample_250911182001515245.npy → (30, 126)
# ✅ Normalizado: sample_250911182005805716.npy → (30, 126)
# ✅ Normalizado: sample_250911182010463208.npy → (30, 126)
# ✅ Normalizado: sample_250911182014546030.npy → (30, 126)
# ✅ Normalizado: sample_250911182018822801.npy → (30, 126)
# ✅ Normalizado: sample_250911182028372549.npy → (30, 126)
# ✅ Normalizado: sample_250911182033284149.npy → (30, 126)
# ✅ Normalizado: sample_250911182037522708.npy → (30, 126)
# ✅ Normalizado: sample_250911182042183742.npy → (30, 126)
# ✅ Normalizado: sample_250911182046662741.npy → (30, 126)
# ✅ Normalizado: sample_250911182050627545.npy → (30, 126)
# ✅ Normalizado: sample_250911182054575832.npy → (30, 126)
# ✅ Normalizado: sample_250911182103827305.npy → (30, 126)
# ✅ Normalizado: sample_250911182107853690.npy → (30, 126)
# ✅ Normalizado: sample_250911182112077703.npy → (30, 126)
# ✅ Normalizado: sample_250911182116764158.npy → (30, 126)
# ✅ Normalizado: sample_250911182121292834.npy → (30, 126)
# ✅ Normalizado: sample_250911182125883192.npy → (30, 126)
# ✅ Normalizado: sample_250911182133513552.npy → (30, 126)
# ✅ Normalizado: sample_250911182138015737.npy → (30, 126)
# ✅ Normalizado: sample_250911182143107442.npy → (30, 126)
# ✅ Normalizado: sample_250911182147400803.npy → (30, 126)
# ✅ Normalizado: sample_250911182151615868.npy → (30, 126)
# ✅ Normalizado: sample_250911182155897322.npy → (30, 126)
# ✅ Normalizado: sample_250911182201242848.npy → (30, 126)
# ...
# ✅ Normalizado: sample_250814161006350454.npy → (30, 126)
# ✅ Normalizado: sample_250814161010160086.npy → (30, 126)
# ✅ Normalizado: sample_250814161013923586.npy → (30, 126)
# ✅ Normalizado: sample_250814161017479620.npy → (30, 126)
# ✅ Normalizado: sample_250814161020636792.npy → (30, 126)
# ✅ Normalizado: sample_250814161024263232.npy → (30, 126)
# ✅ Normalizado: sample_250814161027928831.npy → (30, 126)
# ✅ Normalizado: sample_250814161031467379.npy → (30, 126)
# ✅ Normalizado: sample_250814161035141278.npy → (30, 126)
# ✅ Normalizado: sample_250814161039065380.npy → (30, 126)
# ✅ Normalizado: sample_250814161048214388.npy → (30, 126)
# ✅ Normalizado: sample_250814161051329662.npy → (30, 126)
# ✅ Normalizado: sample_250814161055141216.npy → (30, 126)
# ✅ Normalizado: sample_250814161058502416.npy → (30, 126)
# ✅ Normalizado: sample_250814161101591243.npy → (30, 126)
# ✅ Normalizado: sample_250814161104671315.npy → (30, 126)
# ✅ Normalizado: sample_250814161107824773.npy → (30, 126)
# ✅ Normalizado: sample_250814161114291985.npy → (30, 126)
# ✅ Normalizado: sample_250814161117176090.npy → (30, 126)
# ✅ Normalizado: sample_250814161120294656.npy → (30, 126)
# ✅ Normalizado: sample_250814161123492730.npy → (30, 126)
# ✅ Normalizado: sample_250814161126626442.npy → (30, 126)
# ✅ Normalizado: sample_250814161135231309.npy → (30, 126)
# ✅ Normalizado: sample_250814161138177114.npy → (30, 126)
# ✅ Normalizado: sample_250814161143263195.npy → (30, 126)
# ✅ Normalizado: sample_250814161146365406.npy → (30, 126)
# ✅ Normalizado: sample_250814161149351393.npy → (30, 126)
# ✅ Normalizado: sample_250814161152418162.npy → (30, 126)
# ✅ Normalizado: sample_250814161155673965.npy → (30, 126)
# ✅ Normalizado: sample_250814161158929772.npy → (30, 126)
# ✅ Normalizado: sample_250814161208792811.npy → (30, 126)
# ✅ Normalizado: sample_250814161212084939.npy → (30, 126)
# ✅ Normalizado: sample_250814161215454452.npy → (30, 126)
# ✅ Normalizado: sample_250814161221199995.npy → (30, 126)
# ✅ Normalizado: sample_250814161224861357.npy → (30, 126)
# ✅ Normalizado: sample_250814161228065388.npy → (30, 126)
# ✅ Normalizado: sample_250814161231346031.npy → (30, 126)
# ✅ Normalizado: sample_250814161234632927.npy → (30, 126)
# ✅ Normalizado: sample_250814161238425110.npy → (30, 126)
# ✅ Normalizado: sample_250814161242686174.npy → (30, 126)
# ✅ Normalizado: sample_250814161246044105.npy → (30, 126)
# ✅ Normalizado: sample_250814161251881278.npy → (30, 126)
# ✅ Normalizado: sample_250814161254881087.npy → (30, 126)
# ✅ Normalizado: sample_250814161301721357.npy → (30, 126)
# ✅ Normalizado: sample_250814161305133612.npy → (30, 126)
# ✅ Normalizado: sample_250814161313286762.npy → (30, 126)
# ✅ Normalizado: sample_250814161316861088.npy → (30, 126)
# ✅ Normalizado: sample_250814161319848916.npy → (30, 126)
# ✅ Normalizado: sample_250814161323175121.npy → (30, 126)
# ✅ Normalizado: sample_250814161332524191.npy → (30, 126)
# ✅ Normalizado: sample_250814161335898945.npy → (30, 126)
# ✅ Normalizado: sample_250814161339393659.npy → (30, 126)
# ✅ Normalizado: sample_250814161342690138.npy → (30, 126)
# ✅ Normalizado: sample_250814161349698780.npy → (30, 126)
# ✅ Normalizado: sample_250814161353711222.npy → (30, 126)
# ✅ Normalizado: sample_250814161357371179.npy → (30, 126)
# ✅ Normalizado: sample_250814161401251389.npy → (30, 126)
# ✅ Normalizado: sample_250814161404790996.npy → (30, 126)
# ✅ Normalizado: sample_250814161408751189.npy → (30, 126)
# ✅ Normalizado: sample_250814161412570999.npy → (30, 126)
# ✅ Normalizado: sample_250814161511837879.npy → (30, 126)
# ✅ Normalizado: sample_250814161514850444.npy → (30, 126)
# ✅ Normalizado: sample_250814161518108938.npy → (30, 126)
# ✅ Normalizado: sample_250814161521738292.npy → (30, 126)
# ✅ Normalizado: sample_250814161525899899.npy → (30, 126)
# ✅ Normalizado: sample_250814161529740645.npy → (30, 126)
# ✅ Normalizado: sample_250814161533415003.npy → (30, 126)
# ✅ Normalizado: sample_250814161537031875.npy → (30, 126)
# ✅ Normalizado: sample_250814161540869467.npy → (30, 126)
# ✅ Normalizado: sample_250814161544143866.npy → (30, 126)
# ✅ Normalizado: sample_250814161552620814.npy → (30, 126)
# ✅ Normalizado: sample_250814161556602937.npy → (30, 126)
# ✅ Normalizado: sample_250814161600789442.npy → (30, 126)
# ✅ Normalizado: sample_250814161605068139.npy → (30, 126)
# ✅ Normalizado: sample_250814161609026117.npy → (30, 126)
# ✅ Normalizado: sample_250814161612963550.npy → (30, 126)
# ✅ Normalizado: sample_250814161616488429.npy → (30, 126)
# ✅ Normalizado: sample_250814161620490063.npy → (30, 126)
# ✅ Normalizado: sample_250814161623799138.npy → (30, 126)
# ✅ Normalizado: sample_250814161627593674.npy → (30, 126)
# ✅ Normalizado: sample_250814161643025413.npy → (30, 126)
# ✅ Normalizado: sample_250814161649606896.npy → (30, 126)
# ✅ Normalizado: sample_250814161652728940.npy → (30, 126)
# ✅ Normalizado: sample_250814161655874402.npy → (30, 126)
# ✅ Normalizado: sample_250814161658972689.npy → (30, 126)
# ✅ Normalizado: sample_250814161701996152.npy → (30, 126)
# ✅ Normalizado: sample_250814161705193983.npy → (30, 126)
# ✅ Normalizado: sample_250814161708521998.npy → (30, 126)
# ✅ Normalizado: sample_250814161711853177.npy → (30, 126)
# ✅ Normalizado: sample_250814161715012049.npy → (30, 126)
# ✅ Normalizado: sample_250814161718097187.npy → (30, 126)
# ✅ Normalizado: sample_250814161720971894.npy → (30, 126)
# ✅ Normalizado: sample_250814161723924145.npy → (30, 126)
# ✅ Normalizado: sample_250814161726782895.npy → (30, 126)
# ✅ Normalizado: sample_250814161730105854.npy → (30, 126)
# ✅ Normalizado: sample_250814161733168114.npy → (30, 126)
# ✅ Normalizado: sample_250814161736179084.npy → (30, 126)
# ✅ Normalizado: sample_250814161739290970.npy → (30, 126)
# ✅ Normalizado: sample_250814161742339825.npy → (30, 126)
# ✅ Normalizado: sample_250814161746021220.npy → (30, 126)
# ✅ Normalizado: sample_250814161753017688.npy → (30, 126)
# ✅ Normalizado: sample_250814161756252897.npy → (30, 126)
# ✅ Normalizado: sample_250814161759147064.npy → (30, 126)
# ✅ Normalizado: sample_250814161802083991.npy → (30, 126)
# ✅ Normalizado: sample_250814161804982591.npy → (30, 126)
# ✅ Normalizado: sample_250814161807860745.npy → (30, 126)
# ✅ Normalizado: sample_250814161810884420.npy → (30, 126)
# ✅ Normalizado: sample_250814161813808242.npy → (30, 126)
# ✅ Normalizado: sample_250814161816741173.npy → (30, 126)
# ✅ Normalizado: sample_250814161819583997.npy → (30, 126)
# ✅ Normalizado: sample_250814161826178935.npy → (30, 126)
# ✅ Normalizado: sample_250814161829233155.npy → (30, 126)
# ✅ Normalizado: sample_250814161832463317.npy → (30, 126)
# ✅ Normalizado: sample_250814161835493081.npy → (30, 126)
# ✅ Normalizado: sample_250814161846371125.npy → (30, 126)
# ✅ Normalizado: sample_250814161850137492.npy → (30, 126)
# ✅ Normalizado: sample_250814161853744521.npy → (30, 126)
# ✅ Normalizado: sample_250814161857399381.npy → (30, 126)
# ✅ Normalizado: sample_250814161900988069.npy → (30, 126)
# ✅ Normalizado: sample_250814161904330814.npy → (30, 126)
# ✅ Normalizado: sample_250814161911201844.npy → (30, 126)
# ✅ Normalizado: sample_250814161914467222.npy → (30, 126)
# ✅ Normalizado: sample_250814161917578251.npy → (30, 126)
# ✅ Normalizado: sample_250814161921039446.npy → (30, 126)
# ✅ Normalizado: sample_250814161924467916.npy → (30, 126)
# ✅ Normalizado: sample_250814161928072570.npy → (30, 126)
# ✅ Normalizado: sample_250814161931895528.npy → (30, 126)
# ✅ Normalizado: sample_250814161935548981.npy → (30, 126)
# ✅ Normalizado: sample_250814161939189865.npy → (30, 126)
# ✅ Normalizado: sample_250814161943791860.npy → (30, 126)
# ✅ Normalizado: sample_250814162044959923.npy → (30, 126)
# ✅ Normalizado: sample_250814162048667285.npy → (30, 126)
# ✅ Normalizado: sample_250814162052223151.npy → (30, 126)
# ✅ Normalizado: sample_250814162056091619.npy → (30, 126)
# ✅ Normalizado: sample_250814162059806641.npy → (30, 126)
# ✅ Normalizado: sample_250814162103405238.npy → (30, 126)
# ✅ Normalizado: sample_250814162107346099.npy → (30, 126)
# ✅ Normalizado: sample_250814162110986713.npy → (30, 126)
# ✅ Normalizado: sample_250814162114332615.npy → (30, 126)
# ✅ Normalizado: sample_250814162117849669.npy → (30, 126)
# ✅ Normalizado: sample_250814162126458215.npy → (30, 126)
# ✅ Normalizado: sample_250814162129702369.npy → (30, 126)
# ✅ Normalizado: sample_250814162133228518.npy → (30, 126)
# ✅ Normalizado: sample_250814162136395742.npy → (30, 126)
# ✅ Normalizado: sample_250814162141140166.npy → (30, 126)
# ✅ Normalizado: sample_250814162144209152.npy → (30, 126)
# ✅ Normalizado: sample_250814162148224337.npy → (30, 126)
# ✅ Normalizado: sample_250814162151705093.npy → (30, 126)
# ✅ Normalizado: sample_250814162155155547.npy → (30, 126)
# ✅ Normalizado: sample_250814162203338189.npy → (30, 126)
# ✅ Normalizado: sample_250814162215665135.npy → (30, 126)
# ✅ Normalizado: sample_250814162218965588.npy → (30, 126)
# ✅ Normalizado: sample_250814162222244236.npy → (30, 126)
# ✅ Normalizado: sample_250814162225571651.npy → (30, 126)
# ✅ Normalizado: sample_250814162229030606.npy → (30, 126)
# ✅ Normalizado: sample_250814162231879734.npy → (30, 126)
# ✅ Normalizado: sample_250814162235111573.npy → (30, 126)
# ✅ Normalizado: sample_250814162238201878.npy → (30, 126)
# ✅ Normalizado: sample_250814162241775943.npy → (30, 126)
# ✅ Normalizado: sample_250814162245306712.npy → (30, 126)
# ✅ Normalizado: sample_250814162253888332.npy → (30, 126)
# ✅ Normalizado: sample_250814162256944825.npy → (30, 126)
# ✅ Normalizado: sample_250814162300167014.npy → (30, 126)
# ✅ Normalizado: sample_250814162302955009.npy → (30, 126)
# ✅ Normalizado: sample_250814162305872657.npy → (30, 126)
# ✅ Normalizado: sample_250814162308971227.npy → (30, 126)
# ✅ Normalizado: sample_250814162311909961.npy → (30, 126)
# ✅ Normalizado: sample_250814162314903983.npy → (30, 126)
# ✅ Normalizado: sample_250814162317559977.npy → (30, 126)
# ✅ Normalizado: sample_250814162320841792.npy → (30, 126)
# ✅ Normalizado: sample_250814162326748428.npy → (30, 126)
# ✅ Normalizado: sample_250814162330111189.npy → (30, 126)
# ✅ Normalizado: sample_250814162333255374.npy → (30, 126)
# ✅ Normalizado: sample_250814162341834877.npy → (30, 126)
# ✅ Normalizado: sample_250814162345442426.npy → (30, 126)
# ✅ Normalizado: sample_250814162348644720.npy → (30, 126)
# ✅ Normalizado: sample_250814162352092025.npy → (30, 126)
# ✅ Normalizado: sample_250814162355482433.npy → (30, 126)
# ✅ Normalizado: sample_250814162358843356.npy → (30, 126)
# ✅ Normalizado: sample_250814162402553330.npy → (30, 126)
# ✅ Normalizado: sample_250911163823065760.npy → (30, 126)
# ✅ Normalizado: sample_250911163827724055.npy → (30, 126)
# ✅ Normalizado: sample_250911163833373596.npy → (30, 126)
# ✅ Normalizado: sample_250911163837640694.npy → (30, 126)
# ✅ Normalizado: sample_250911163841880878.npy → (30, 126)
# ✅ Normalizado: sample_250911163845855208.npy → (30, 126)
# ✅ Normalizado: sample_250911163935067964.npy → (30, 126)
# ✅ Normalizado: sample_250911163939165584.npy → (30, 126)
# ✅ Normalizado: sample_250911163942803042.npy → (30, 126)
# ✅ Normalizado: sample_250911163952696119.npy → (30, 126)
# ✅ Normalizado: sample_250911163959668893.npy → (30, 126)
# ✅ Normalizado: sample_250911164003688801.npy → (30, 126)
# ✅ Normalizado: sample_250911164008065357.npy → (30, 126)
# ✅ Normalizado: sample_250911164012237727.npy → (30, 126)
# ✅ Normalizado: sample_250911164016704929.npy → (30, 126)
# ✅ Normalizado: sample_250911164020760589.npy → (30, 126)
# ✅ Normalizado: sample_250911164039778578.npy → (30, 126)
# ✅ Normalizado: sample_250911164055489694.npy → (30, 126)
# ✅ Normalizado: sample_250911164100178924.npy → (30, 126)
# ✅ Normalizado: sample_250911164104331672.npy → (30, 126)
# ✅ Normalizado: sample_250911164114895595.npy → (30, 126)
# ✅ Normalizado: sample_250911164119476117.npy → (30, 126)
# ✅ Normalizado: sample_250911164123705584.npy → (30, 126)
# ✅ Normalizado: sample_250911164128063210.npy → (30, 126)
# ✅ Normalizado: sample_250911164132352071.npy → (30, 126)
# ✅ Normalizado: sample_250911164136310330.npy → (30, 126)
# ✅ Normalizado: sample_250911164141000556.npy → (30, 126)
# ✅ Normalizado: sample_250911164145647875.npy → (30, 126)
# ✅ Normalizado: sample_250911164149730787.npy → (30, 126)
# ✅ Normalizado: sample_250911164155344698.npy → (30, 126)
# ✅ Normalizado: sample_250911164213454848.npy → (30, 126)
# ✅ Normalizado: sample_250911164217834442.npy → (30, 126)
# ✅ Normalizado: sample_250911164222480967.npy → (30, 126)
# ✅ Normalizado: sample_250911164226740760.npy → (30, 126)
# ✅ Normalizado: sample_250911164231417776.npy → (30, 126)
# ✅ Normalizado: sample_250911164235475251.npy → (30, 126)
# ✅ Normalizado: sample_250911164239949798.npy → (30, 126)
# ✅ Normalizado: sample_250911164244607779.npy → (30, 126)
# ✅ Normalizado: sample_250911164248975769.npy → (30, 126)
# ✅ Normalizado: sample_250911164253543384.npy → (30, 126)
# ✅ Normalizado: sample_250911164259043539.npy → (30, 126)
# ✅ Normalizado: sample_250911164304353195.npy → (30, 126)
# ✅ Normalizado: sample_250911164309041773.npy → (30, 126)
# ✅ Normalizado: sample_250911164313659548.npy → (30, 126)
# ✅ Normalizado: sample_250911164318076209.npy → (30, 126)
# ✅ Normalizado: sample_250911164322727522.npy → (30, 126)
# ✅ Normalizado: sample_250911164327593393.npy → (30, 126)
# ✅ Normalizado: sample_250911164332643332.npy → (30, 126)
# ✅ Normalizado: sample_250911164337401488.npy → (30, 126)
# ✅ Normalizado: sample_250911164341781583.npy → (30, 126)
# ✅ Normalizado: sample_250911164353657622.npy → (30, 126)
# ✅ Normalizado: sample_250911164358909801.npy → (30, 126)
# ✅ Normalizado: sample_250911164403917334.npy → (30, 126)
# ✅ Normalizado: sample_250911164408491685.npy → (30, 126)
# ✅ Normalizado: sample_250911164412818698.npy → (30, 126)
# ✅ Normalizado: sample_250911164417537582.npy → (30, 126)
# ✅ Normalizado: sample_250911164422144550.npy → (30, 126)
# ✅ Normalizado: sample_250911164427209798.npy → (30, 126)
# ✅ Normalizado: sample_250911164431557702.npy → (30, 126)
# ✅ Normalizado: sample_250911164437522925.npy → (30, 126)
# ✅ Normalizado: sample_250911164614495615.npy → (30, 126)
# ✅ Normalizado: sample_250911164619010205.npy → (30, 126)
# ✅ Normalizado: sample_250911164623340982.npy → (30, 126)
# ✅ Normalizado: sample_250911164628153246.npy → (30, 126)
# ✅ Normalizado: sample_250911164633515983.npy → (30, 126)
# ✅ Normalizado: sample_250911164638037486.npy → (30, 126)
# ✅ Normalizado: sample_250911164642815725.npy → (30, 126)
# ✅ Normalizado: sample_250911164647541256.npy → (30, 126)
# ✅ Normalizado: sample_250911164652301765.npy → (30, 126)
# ✅ Normalizado: sample_250911164657656274.npy → (30, 126)
# ✅ Normalizado: sample_250911164711656429.npy → (30, 126)
# ✅ Normalizado: sample_250911164716106070.npy → (30, 126)
# ✅ Normalizado: sample_250911164720077744.npy → (30, 126)
# ✅ Normalizado: sample_250911164723950989.npy → (30, 126)
# ✅ Normalizado: sample_250911164728220658.npy → (30, 126)
# ✅ Normalizado: sample_250911164732049526.npy → (30, 126)
# ✅ Normalizado: sample_250911164736477894.npy → (30, 126)
# ✅ Normalizado: sample_250911164740194491.npy → (30, 126)
# ✅ Normalizado: sample_250911164744088706.npy → (30, 126)
# ✅ Normalizado: sample_250911164748389664.npy → (30, 126)
# ✅ Normalizado: sample_250911164757922498.npy → (30, 126)
# ✅ Normalizado: sample_250911164802336225.npy → (30, 126)
# ✅ Normalizado: sample_250911164806595331.npy → (30, 126)
# ✅ Normalizado: sample_250911164810896061.npy → (30, 126)
# ✅ Normalizado: sample_250911164814713595.npy → (30, 126)
# ✅ Normalizado: sample_250911164818671574.npy → (30, 126)
# ✅ Normalizado: sample_250911164822769300.npy → (30, 126)
# ✅ Normalizado: sample_250911164827221071.npy → (30, 126)
# ✅ Normalizado: sample_250911164832131166.npy → (30, 126)
# ✅ Normalizado: sample_250911164836594987.npy → (30, 126)
# ✅ Normalizado: sample_250911164840575615.npy → (30, 126)
# ✅ Normalizado: sample_250911164848044285.npy → (30, 126)
# ✅ Normalizado: sample_250911164851529332.npy → (30, 126)
# ✅ Normalizado: sample_250911164855199487.npy → (30, 126)
# ✅ Normalizado: sample_250911164902780498.npy → (30, 126)
# ✅ Normalizado: sample_250911164906594093.npy → (30, 126)
# ✅ Normalizado: sample_250911164910250715.npy → (30, 126)
# ✅ Normalizado: sample_250911164914102143.npy → (30, 126)
# ✅ Normalizado: sample_250911164918182435.npy → (30, 126)
# ✅ Normalizado: sample_250911173349316126.npy → (30, 126)

# %% [markdown]
# ## 4. Entrenamiento

# %%
MODEL_NAME = "MargaritaLSG1"
MODEL_PATH = os.path.join("models", f"{MODEL_NAME}.h5")

# Rutas relacionadas (manteniendo consistencia)
BASE_DIR    = os.path.dirname(MODEL_PATH)
BEST_VAL_H5 = os.path.join(BASE_DIR, f"best_val_loss_{MODEL_NAME}.h5")
BEST_F1_H5  = os.path.join(BASE_DIR, f"best_macro_f1_{MODEL_NAME}.h5")
LABELS_JSON = os.path.join(BASE_DIR, f"labels_{MODEL_NAME}.json")
CM_PNG      = os.path.join(BASE_DIR, f"confusion_matrix_{MODEL_NAME}.png")

LENGTH_KEYPOINTS = 126      # SOLO manos (21*3*2)
MODEL_FRAMES = 30           # frames por secuencia (coincidir con inferencia)

def load_dataset(base_path="data/frases"):
    X = []
    y = []
    label_map = {}

    palabras = sorted(os.listdir(base_path))
    for idx, palabra in enumerate(palabras):
        label_map[palabra] = idx
        palabra_path = os.path.join(base_path, palabra)
        for archivo in os.listdir(palabra_path):
            if archivo.endswith(".npy"):
                secuencia = np.load(os.path.join(palabra_path, archivo))
                if secuencia.shape[0] == MODEL_FRAMES:
                    X.append(secuencia)
                    y.append(idx)

    X = np.array(X)
    y = to_categorical(np.array(y))
    return X, y, label_map

# %%
def get_model(max_length_frames, output_length: int):
    model = Sequential()
    model.add(LSTM(64, return_sequences=True, input_shape=(max_length_frames, LENGTH_KEYPOINTS), kernel_regularizer=l2(0.01)))
    model.add(Dropout(0.5))
    model.add(LSTM(128, return_sequences=False, kernel_regularizer=l2(0.001)))
    model.add(Dropout(0.5))
    model.add(Dense(64, activation='relu', kernel_regularizer=l2(0.001)))
    model.add(Dense(64, activation='relu', kernel_regularizer=l2(0.001)))
    model.add(Dense(output_length, activation='softmax'))

    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
    return model

# %%
import os, json, math, random
import numpy as np
import matplotlib.pyplot as plt

from typing import Dict, Tuple
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, classification_report, f1_score
from sklearn.model_selection import train_test_split  # (Opcional) GroupShuffleSplit si usas grupos

import tensorflow as tf
from tensorflow.keras.callbacks import Callback, ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.losses import CategoricalCrossentropy

# ======================================================
# Config global
# ======================================================
SEED = 42
MODEL_FRAMES = 30
LENGTH_KEYPOINTS = 126  # (ej: 63 jp * 2 coords) + rest
LR_INIT = 3e-4

BASE_DIR = os.path.abspath(os.path.dirname(__file__)) if "__file__" in globals() else os.getcwd()
OUT_DIR  = os.path.join(BASE_DIR, "models")
FIG_DIR  = os.path.join(BASE_DIR, "figs")
os.makedirs(OUT_DIR, exist_ok=True)
os.makedirs(FIG_DIR, exist_ok=True)

BEST_VAL_H5 = os.path.join(OUT_DIR, "best_val_loss_MargaritaLSG1.h5")
BEST_F1_H5  = os.path.join(OUT_DIR, "best_macro_f1_MargaritaLSG1.h5")
MODEL_PATH  = os.path.join(OUT_DIR, "action_final_best_val.h5")
LABELS_JSON = os.path.join(OUT_DIR, "labels.json")
CM_PNG      = os.path.join(FIG_DIR,  "cm_validacion.png")

# ======================================================
# Semillas (reproducibilidad)
# ======================================================
def set_global_seed(seed=SEED):
    os.environ["PYTHONHASHSEED"] = str(seed)
    random.seed(seed)
    np.random.seed(seed)
    tf.random.set_seed(seed)

set_global_seed(SEED)

# ======================================================
# Stubs a reemplazar por tus funciones reales
# ======================================================
def get_model(input_length: int, output_length: int) -> tf.keras.Model:
    """
    Reemplaza esta función por tu arquitectura real.
    Debe recibir (MODEL_FRAMES, LENGTH_KEYPOINTS) y devolver C clases.
    """
    inp = tf.keras.Input(shape=(input_length, LENGTH_KEYPOINTS))
    x = tf.keras.layers.Masking(mask_value=-0.2)(inp)  # compatible con token de ausencia
    x = tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(128, return_sequences=True))(x)
    x = tf.keras.layers.Dropout(0.25)(x)
    x = tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(128))(x)
    x = tf.keras.layers.Dropout(0.25)(x)
    x = tf.keras.layers.Dense(256, activation="relu")(x)
    x = tf.keras.layers.Dropout(0.25)(x)
    out = tf.keras.layers.Dense(output_length, activation="softmax")(x)
    model = tf.keras.Model(inp, out)
    return model

def load_dataset() -> Tuple[np.ndarray, np.ndarray, Dict[int, str]]:
    """
    Reemplázala por tu carga real desde .npy u orígen.
    Debe retornar:
      X: (N, MODEL_FRAMES, LENGTH_KEYPOINTS) float32 normalizado
      y: (N, C) one-hot
      label_map: dict {idx:int -> nombre:str}
    """
    raise NotImplementedError("Implementa load_dataset() para tus datos reales.")

# ======================================================
# Aumentos para keypoints (solo en train)
# ======================================================
def _reshape_xy(seq: np.ndarray):
    """Divide en XY (T, J, 2) y resto (visibilidad/flags) plano."""
    T, K = seq.shape
    n_xy = (K // 2) * 2
    xy = seq[:, :n_xy].reshape(T, n_xy // 2, 2)  # (T, J, 2)
    rest = seq[:, n_xy:]
    return xy, rest, n_xy

def aug_jitter(seq, sigma=0.01):
    xy, rest, n_xy = _reshape_xy(seq)
    noise = np.random.normal(0, sigma, xy.shape)
    xy_aug = np.clip(xy + noise, 0.0, 1.0)
    return np.concatenate([xy_aug.reshape(seq.shape[0], n_xy), rest], axis=1)

def aug_scale_translate(seq, scale_range=(0.96, 1.04), trans_range=(-0.015, 0.015)):
    xy, rest, n_xy = _reshape_xy(seq)
    s  = np.random.uniform(*scale_range)
    tx = np.random.uniform(*trans_range)
    ty = np.random.uniform(*trans_range)
    center = np.array([0.5, 0.5])
    xy_aug = (xy - center) * s + center
    xy_aug[..., 0] = np.clip(xy_aug[..., 0] + tx, 0.0, 1.0)
    xy_aug[..., 1] = np.clip(xy_aug[..., 1] + ty, 0.0, 1.0)
    return np.concatenate([xy_aug.reshape(seq.shape[0], n_xy), rest], axis=1)

def aug_rotate(seq, deg=5):
    rad = np.deg2rad(np.random.uniform(-deg, deg))
    c, s = math.cos(rad), math.sin(rad)
    R = np.array([[c, -s], [s, c]])
    xy, rest, n_xy = _reshape_xy(seq)
    center = np.array([0.5, 0.5])
    xy_c = xy - center
    xy_r = np.einsum('ab,tkb->tka', R, xy_c)
    xy_aug = np.clip(xy_r + center, 0.0, 1.0)
    return np.concatenate([xy_aug.reshape(seq.shape[0], n_xy), rest], axis=1)

def aug_time_warp(seq, strength=0.05):
    """Warp temporal suave. (Puede no ser estrictamente monótono; suficiente en práctica)."""
    T = seq.shape[0]
    t = np.linspace(0, 1, T)
    warp = t + strength * np.sin(2 * np.pi * t * np.random.uniform(0.8, 1.2))
    warp = np.clip(warp, 0, 1)
    new_idx = warp * (T - 1)
    lo = np.floor(new_idx).astype(int)
    hi = np.clip(lo + 1, 0, T - 1)
    alpha = new_idx - lo
    out = seq[lo] * (1 - alpha[:, None]) + seq[hi] * alpha[:, None]
    return out.astype(seq.dtype)

def aug_frame_dropout_xy(seq, max_drop=2):
    """Elimina frames y reinterpola SOLO XY. 'rest' queda intacto."""
    xy, rest, n_xy = _reshape_xy(seq)
    T = xy.shape[0]
    d = np.random.randint(0, max_drop + 1)
    if d == 0:
        return seq
    keep_idx = sorted(np.random.choice(np.arange(T), T - d, replace=False))
    kept_xy = xy[keep_idx]
    new_idx = np.linspace(0, kept_xy.shape[0]-1, T)
    lo = np.floor(new_idx).astype(int)
    hi = np.clip(lo + 1, 0, kept_xy.shape[0]-1)
    alpha = new_idx - lo
    out_xy = kept_xy[lo] * (1 - alpha[:, None, None]) + kept_xy[hi] * alpha[:, None, None]
    out = np.concatenate([out_xy.reshape(T, n_xy), rest], axis=1)
    return out.astype(seq.dtype)

def aug_keypoint_mask(seq, max_points=3, missing_token=-0.2):
    """Enmascara J keypoints con un token fuera de [0,1] para distinguir ausencia real de 'borde'."""
    xy, rest, n_xy = _reshape_xy(seq)
    J = xy.shape[1]
    m = np.random.randint(0, max_points + 1)
    if m == 0:
        return np.concatenate([xy.reshape(seq.shape[0], n_xy), rest], axis=1)
    idx = np.random.choice(np.arange(J), m, replace=False)
    xy_mask = xy.copy()
    xy_mask[:, idx, :] = missing_token
    return np.concatenate([xy_mask.reshape(seq.shape[0], n_xy), rest], axis=1)

def augment_sequence(seq: np.ndarray):
    if np.random.rand() < 0.8: seq = aug_jitter(seq, 0.01)
    if np.random.rand() < 0.5: seq = aug_scale_translate(seq, (0.96, 1.04), (-0.015, 0.015))
    if np.random.rand() < 0.3: seq = aug_rotate(seq, 5)
    if np.random.rand() < 0.4: seq = aug_time_warp(seq, 0.05)
    if np.random.rand() < 0.3: seq = aug_frame_dropout_xy(seq, 2)
    if np.random.rand() < 0.2: seq = aug_keypoint_mask(seq, 3, missing_token=-0.2)
    return seq

# ======================================================
# tf.data (batch-wise augment rápido)
# ======================================================
def make_tf_dataset(X, y, batch_size=8, training=True, seed=SEED):
    ds = tf.data.Dataset.from_tensor_slices((X, y))
    if training:
        ds = ds.shuffle(min(10000, len(X)), reshuffle_each_iteration=True, seed=seed)
    ds = ds.batch(batch_size, drop_remainder=False)

    if training:
        def _batch_aug(x, y):
            x = tf.numpy_function(
                func=lambda arr: np.stack([augment_sequence(a) for a in arr], axis=0),
                inp=[x],
                Tout=tf.float32
            )
            x.set_shape((None, X.shape[1], X.shape[2]))
            return x, y
        ds = ds.map(_batch_aug, num_parallel_calls=tf.data.AUTOTUNE)

    return ds.prefetch(tf.data.AUTOTUNE)

# ======================================================
# Pesos por clase
# ======================================================
def compute_class_weights(y_onehot: np.ndarray):
    counts = y_onehot.sum(axis=0)
    total = counts.sum()
    weights = total / (len(counts) * np.maximum(counts, 1))
    return {i: float(w) for i, w in enumerate(weights)}

# ======================================================
# Callback Macro-F1 (loggea y checkpoint opcional)
# ======================================================
class MacroF1Callback(Callback):
    def __init__(self, X_val, y_val, save_path=None):
        super().__init__()
        self.X_val = X_val
        self.y_val = y_val
        self.best = -1.0
        self.save_path = save_path

    def on_epoch_end(self, epoch, logs=None):
        y_prob = self.model.predict(self.X_val, verbose=0)
        y_pred = y_prob.argmax(axis=1)
        y_true = self.y_val.argmax(axis=1)
        macro_f1 = f1_score(y_true, y_pred, average="macro")
        if logs is not None:
            logs["val_macro_f1"] = macro_f1
        if macro_f1 > self.best:
            self.best = macro_f1
            if self.save_path:
                self.model.save(self.save_path)
                print(f"\n💾 Macro-F1 mejoró a {macro_f1:.4f}. Guardado: {self.save_path}")

# ======================================================
# Entrenamiento principal
# ======================================================
def train_model_from_npy(epochs=150, batch_size=8, use_class_weights=True):
    # 1) Cargar dataset
    X, y, label_map = load_dataset()  # y one-hot (N, C)
    print(f"✅ Total muestras: {X.shape[0]}, Clases: {len(label_map)}")

    assert X.ndim == 3 and X.shape[1] == MODEL_FRAMES and X.shape[2] == LENGTH_KEYPOINTS, \
        f"X shape {X.shape} debe ser (N, {MODEL_FRAMES}, {LENGTH_KEYPOINTS})"
    assert y.ndim == 2, f"y debe ser one-hot (N, C); shape actual: {y.shape}"

    X = X.astype(np.float32)

    # 2) Split (estratificado). TIP: si tienes id_persona o id_video usa GroupShuffleSplit.
    X_train, X_val, y_train, y_val = train_test_split(
        X, y, test_size=0.2, random_state=SEED, stratify=np.argmax(y, axis=1)
    )

    # 3) Modelo
    model = get_model(MODEL_FRAMES, output_length=y.shape[1])
    print("MODEL in/out (entrenamiento):", model.input_shape, "->", model.output_shape)

    # 4) Callbacks
    ckpt_val = ModelCheckpoint(
        filepath=BEST_VAL_H5, monitor="val_loss",
        save_best_only=True, save_weights_only=False, verbose=1
    )
    ckpt_f1  = MacroF1Callback(X_val, y_val, save_path=BEST_F1_H5)

    early_stop = EarlyStopping(
        monitor="val_macro_f1", mode="max", patience=10,
        restore_best_weights=True, verbose=1
    )
    rlrop = ReduceLROnPlateau(
        monitor="val_loss", factor=0.5, patience=5,
        min_lr=1e-6, verbose=1
    )

    # 5) Loss con label smoothing (mejor calibración)
    loss = CategoricalCrossentropy(label_smoothing=0.05)

    # 6) Datasets TF
    train_ds = make_tf_dataset(X_train, y_train, batch_size=batch_size, training=True,  seed=SEED)
    val_ds   = make_tf_dataset(X_val,   y_val,   batch_size=batch_size, training=False, seed=SEED)

    # 7) Class weights (opcional)
    class_weights = compute_class_weights(y_train) if use_class_weights else None
    if class_weights:
        print("⚖️  Class weights:", class_weights)

    # 8) Compilar y entrenar
    optimizer = tf.keras.optimizers.Adam(learning_rate=LR_INIT, clipnorm=1.0)
    model.compile(optimizer=optimizer, loss=loss, metrics=["accuracy"])

    history = model.fit(
        train_ds,
        validation_data=val_ds,
        epochs=epochs,
        callbacks=[ckpt_val, ckpt_f1, rlrop, early_stop],
        class_weight=class_weights,
        verbose=1
    )

    # 9) Guardar modelo final (pesos restaurados del mejor val_macro_f1 vía EarlyStopping)
    model.save(MODEL_PATH)
    print(f"💾 Modelo final guardado en: {MODEL_PATH}")

    # 10) Guardar labels
    with open(LABELS_JSON, "w", encoding="utf-8") as f:
        json.dump(label_map, f, ensure_ascii=False, indent=2)
    print(f"🏷️  Labels guardadas en: {LABELS_JSON}")

    # 11) Matriz de confusión y reporte (validación pura)
    y_pred = model.predict(X_val, verbose=0)
    y_pred_labels = np.argmax(y_pred, axis=1)
    y_true = np.argmax(y_val, axis=1)

    # Orden de etiquetas fijo 0..C-1
    idx_to_name = [label_map[i] for i in range(len(label_map))]
    cm = confusion_matrix(y_true, y_pred_labels)
    disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=idx_to_name)
    disp.plot(cmap="Blues", values_format=".0f")
    plt.title("Matriz de Confusión - Validación")
    plt.tight_layout()
    plt.savefig(CM_PNG, dpi=160)
    print(f"🖼️  Matriz de confusión guardada en: {CM_PNG}")
    # plt.show()  # descomenta si entrenas local con UI

    train_acc = history.history.get('accuracy', [0])[-1]
    val_acc   = history.history.get('val_accuracy', [0])[-1]
    print(f"\n📊 Accuracy final - Train: {train_acc:.2f} | Val: {val_acc:.2f}")
    if abs(train_acc - val_acc) > 0.2:
        print("⚠️ Posible overfitting")
    elif max(history.history.get('val_accuracy', [0])) < 0.6:
        print("⚠️ Posible underfitting")
    else:
        print("✅ Buen desempeño general")

    print("\n📃 Classification report (validación):")
    print(classification_report(y_true, y_pred_labels, target_names=idx_to_name))

    return model, label_map


if __name__ == "__main__":
    # Ajusta epochs/batch según tu GPU
    model, label_map = train_model_from_npy(epochs=150, batch_size=8, use_class_weights=True)
# Out:
# ✅ Total muestras: 6000, Clases: 15
# MODEL in/out (entrenamiento): (None, 30, 126) -> (None, 15)
# ⚖️  Class weights: {0: 1.0, 1: 1.0, 2: 1.0, 3: 1.0, 4: 1.0, 5: 1.0, 6: 1.0, 7: 1.0, 8: 1.0, 9: 1.0, 10: 1.0, 11: 1.0, 12: 1.0, 13: 1.0, 14: 1.0}
# Epoch 1/150
# 600/600 [==============================] - ETA: 0s - loss: 2.5039 - accuracy: 0.2515
# Epoch 1: val_loss improved from inf to 2.12571, saving model to app\models\best_val_loss_MargaritaLSG1.h5
#
# 💾 Macro-F1 mejoró a 0.3159. Guardado: app\models\best_macro_f1_MargaritaLSG1.h5
# 600/600 [==============================] - 50s 65ms/step - loss: 2.5039 - accuracy: 0.2515 - val_loss: 2.1257 - val_accuracy: 0.3600
# Epoch 2/150
# 599/600 [============================>.] - ETA: 0s - loss: 1.8601 - accuracy: 0.4282
# Epoch 2: val_loss improved from 2.12571 to 1.58724, saving model to app\models\best_val_loss_MargaritaLSG1.h5
#
# 💾 Macro-F1 mejoró a 0.5250. Guardado: app\models\best_macro_f1_MargaritaLSG1.h5
# 600/600 [==============================] - 31s 52ms/step - loss: 1.8592 - accuracy: 0.4290 - val_loss: 1.5872 - val_accuracy: 0.5517
# Epoch 3/150
# 600/600 [==============================] - ETA: 0s - loss: 1.5419 - accuracy: 0.5550
# Epoch 3: val_loss improved from 1.58724 to 1.37832, saving model to app\models\best_val_loss_MargaritaLSG1.h5
# 600/600 [==============================] - 33s 55ms/step - loss: 1.5419 - accuracy: 0.5550 - val_loss: 1.3783 - val_accuracy: 0.5725
# Epoch 4/150
# 600/600 [==============================] - ETA: 0s - loss: 1.4035 - accuracy: 0.6052
# Epoch 4: val_loss improved from 1.37832 to 1.20619, saving model to app\models\best_val_loss_MargaritaLSG1.h5
#
# 💾 Macro-F1 mejoró a 0.6504. Guardado: app\models\best_macro_f1_MargaritaLSG1.h5
# 600/600 [==============================] - 35s 58ms/step - loss: 1.4035 - accuracy: 0.6052 - val_loss: 1.2062 - val_accuracy: 0.6850
# Epoch 5/150
# 599/600 [============================>.] - ETA: 0s - loss: 1.3220 - accuracy: 0.6384
# Epoch 5: val_loss improved from 1.20619 to 1.15281, saving model to app\models\best_val_loss_MargaritaLSG1.h5
#
# 💾 Macro-F1 mejoró a 0.6767. Guardado: app\models\best_macro_f1_MargaritaLSG1.h5
# 600/600 [==============================] - 37s 61ms/step - loss: 1.3218 - accuracy: 0.6383 - val_loss: 1.1528 - val_accuracy: 0.7017
# Epoch 6/150
# 600/600 [==============================] - ETA: 0s - loss: 1.2735 - accuracy: 0.6606
# Epoch 6: val_loss improved from 1.15281 to 1.08116, saving model to app\models\best_val_loss_MargaritaLSG1.h5
#
# 💾 Macro-F1 mejoró a 0.7100. Guardado: app\models\best_macro_f1_MargaritaLSG1.h5
# 600/600 [==============================] - 36s 60ms/step - loss: 1.2735 - accuracy: 0.6606 - val_loss: 1.0812 - val_accuracy: 0.7283
# Epoch 7/150
# 600/600 [==============================] - ETA: 0s - loss: 1.1851 - accuracy: 0.7075
# Epoch 7: val_loss improved from 1.08116 to 0.99091, saving model to app\models\best_val_loss_MargaritaLSG1.h5
#
# 💾 Macro-F1 mejoró a 0.7627. Guardado: app\models\best_macro_f1_MargaritaLSG1.h5
# 600/600 [==============================] - 36s 59ms/step - loss: 1.1851 - accuracy: 0.7075 - val_loss: 0.9909 - val_accuracy: 0.7758
# Epoch 8/150
# 600/600 [==============================] - ETA: 0s - loss: 1.1001 - accuracy: 0.7346
# Epoch 8: val_loss did not improve from 0.99091
#
# 💾 Macro-F1 mejoró a 0.7922. Guardado: app\models\best_macro_f1_MargaritaLSG1.h5
# 600/600 [==============================] - 33s 56ms/step - loss: 1.1001 - accuracy: 0.7346 - val_loss: 0.9916 - val_accuracy: 0.7967
# Epoch 9/150
# 599/600 [============================>.] - ETA: 0s - loss: 1.0651 - accuracy: 0.7577
# Epoch 9: val_loss improved from 0.99091 to 0.83812, saving model to app\models\best_val_loss_MargaritaLSG1.h5
#
# 💾 Macro-F1 mejoró a 0.8231. Guardado: app\models\best_macro_f1_MargaritaLSG1.h5
# 600/600 [==============================] - 32s 53ms/step - loss: 1.0655 - accuracy: 0.7575 - val_loss: 0.8381 - val_accuracy: 0.8408
# Epoch 10/150
# 600/600 [==============================] - ETA: 0s - loss: 1.0098 - accuracy: 0.7792
# Epoch 10: val_loss did not improve from 0.83812
# 600/600 [==============================] - 38s 62ms/step - loss: 1.0098 - accuracy: 0.7792 - val_loss: 0.9845 - val_accuracy: 0.7783
# Epoch 11/150
# 600/600 [==============================] - ETA: 0s - loss: 1.0117 - accuracy: 0.7671
# Epoch 11: val_loss did not improve from 0.83812
# 600/600 [==============================] - 37s 62ms/step - loss: 1.0117 - accuracy: 0.7671 - val_loss: 0.9979 - val_accuracy: 0.7642
# Epoch 12/150
# 600/600 [==============================] - ETA: 0s - loss: 1.0528 - accuracy: 0.7648
# Epoch 12: val_loss did not improve from 0.83812
#
# 💾 Macro-F1 mejoró a 0.8282. Guardado: app\models\best_macro_f1_MargaritaLSG1.h5
# 600/600 [==============================] - 42s 70ms/step - loss: 1.0528 - accuracy: 0.7648 - val_loss: 0.8518 - val_accuracy: 0.8325
# Epoch 13/150
# 600/600 [==============================] - ETA: 0s - loss: 0.9562 - accuracy: 0.7992
# Epoch 13: val_loss did not improve from 0.83812
#
# 💾 Macro-F1 mejoró a 0.8297. Guardado: app\models\best_macro_f1_MargaritaLSG1.h5
# 600/600 [==============================] - 40s 67ms/step - loss: 0.9562 - accuracy: 0.7992 - val_loss: 0.8655 - val_accuracy: 0.8308
# Epoch 14/150
# 600/600 [==============================] - ETA: 0s - loss: 0.9518 - accuracy: 0.7973
# Epoch 14: val_loss did not improve from 0.83812
# 600/600 [==============================] - 42s 70ms/step - loss: 0.9518 - accuracy: 0.7973 - val_loss: 0.9643 - val_accuracy: 0.7742
# Epoch 15/150
# 600/600 [==============================] - ETA: 0s - loss: 0.9120 - accuracy: 0.8146
# Epoch 15: val_loss improved from 0.83812 to 0.80350, saving model to app\models\best_val_loss_MargaritaLSG1.h5
#
# 💾 Macro-F1 mejoró a 0.8575. Guardado: app\models\best_macro_f1_MargaritaLSG1.h5
# 600/600 [==============================] - 47s 78ms/step - loss: 0.9120 - accuracy: 0.8146 - val_loss: 0.8035 - val_accuracy: 0.8592
# Epoch 16/150
# 600/600 [==============================] - ETA: 0s - loss: 0.9507 - accuracy: 0.7987
# Epoch 16: val_loss did not improve from 0.80350
# 600/600 [==============================] - 47s 78ms/step - loss: 0.9507 - accuracy: 0.7987 - val_loss: 0.8617 - val_accuracy: 0.8283
# Epoch 17/150
# 600/600 [==============================] - ETA: 0s - loss: 0.8926 - accuracy: 0.8246
# Epoch 17: val_loss did not improve from 0.80350
# 600/600 [==============================] - 50s 83ms/step - loss: 0.8926 - accuracy: 0.8246 - val_loss: 0.8890 - val_accuracy: 0.8050
# Epoch 18/150
# 600/600 [==============================] - ETA: 0s - loss: 0.8917 - accuracy: 0.8190
# Epoch 18: val_loss improved from 0.80350 to 0.79321, saving model to app\models\best_val_loss_MargaritaLSG1.h5
#
# 💾 Macro-F1 mejoró a 0.8607. Guardado: app\models\best_macro_f1_MargaritaLSG1.h5
# 600/600 [==============================] - 50s 83ms/step - loss: 0.8917 - accuracy: 0.8190 - val_loss: 0.7932 - val_accuracy: 0.8642
# Epoch 19/150
# 600/600 [==============================] - ETA: 0s - loss: 0.8697 - accuracy: 0.8254
# Epoch 19: val_loss improved from 0.79321 to 0.75944, saving model to app\models\best_val_loss_MargaritaLSG1.h5
#
# 💾 Macro-F1 mejoró a 0.8620. Guardado: app\models\best_macro_f1_MargaritaLSG1.h5
# 600/600 [==============================] - 48s 80ms/step - loss: 0.8697 - accuracy: 0.8254 - val_loss: 0.7594 - val_accuracy: 0.8658
# Epoch 20/150
# 600/600 [==============================] - ETA: 0s - loss: 0.8874 - accuracy: 0.8283
# Epoch 20: val_loss improved from 0.75944 to 0.72710, saving model to app\models\best_val_loss_MargaritaLSG1.h5
#
# 💾 Macro-F1 mejoró a 0.8858. Guardado: app\models\best_macro_f1_MargaritaLSG1.h5
# 600/600 [==============================] - 49s 82ms/step - loss: 0.8874 - accuracy: 0.8283 - val_loss: 0.7271 - val_accuracy: 0.8867
# Epoch 21/150
# 600/600 [==============================] - ETA: 0s - loss: 0.8590 - accuracy: 0.8350
# Epoch 21: val_loss improved from 0.72710 to 0.70175, saving model to app\models\best_val_loss_MargaritaLSG1.h5
#
# 💾 Macro-F1 mejoró a 0.8936. Guardado: app\models\best_macro_f1_MargaritaLSG1.h5
# 600/600 [==============================] - 50s 83ms/step - loss: 0.8590 - accuracy: 0.8350 - val_loss: 0.7017 - val_accuracy: 0.8983
# Epoch 22/150
# 600/600 [==============================] - ETA: 0s - loss: 0.8704 - accuracy: 0.8329
# Epoch 22: val_loss did not improve from 0.70175
# 600/600 [==============================] - 48s 80ms/step - loss: 0.8704 - accuracy: 0.8329 - val_loss: 0.8924 - val_accuracy: 0.8067
# Epoch 23/150
# 600/600 [==============================] - ETA: 0s - loss: 0.8336 - accuracy: 0.8408
# Epoch 23: val_loss did not improve from 0.70175
# 600/600 [==============================] - 49s 81ms/step - loss: 0.8336 - accuracy: 0.8408 - val_loss: 0.7027 - val_accuracy: 0.8917
# Epoch 24/150
# 600/600 [==============================] - ETA: 0s - loss: 0.8465 - accuracy: 0.8415
# Epoch 24: val_loss did not improve from 0.70175
# 600/600 [==============================] - 49s 82ms/step - loss: 0.8465 - accuracy: 0.8415 - val_loss: 0.7688 - val_accuracy: 0.8733
# Epoch 25/150
# 600/600 [==============================] - ETA: 0s - loss: 0.8512 - accuracy: 0.8471
# Epoch 25: val_loss improved from 0.70175 to 0.69969, saving model to app\models\best_val_loss_MargaritaLSG1.h5
#
# 💾 Macro-F1 mejoró a 0.9003. Guardado: app\models\best_macro_f1_MargaritaLSG1.h5
# 600/600 [==============================] - 47s 78ms/step - loss: 0.8512 - accuracy: 0.8471 - val_loss: 0.6997 - val_accuracy: 0.9017
# Epoch 26/150
# 600/600 [==============================] - ETA: 0s - loss: 0.8188 - accuracy: 0.8525
# Epoch 26: val_loss did not improve from 0.69969
# 600/600 [==============================] - 47s 78ms/step - loss: 0.8188 - accuracy: 0.8525 - val_loss: 0.8214 - val_accuracy: 0.8408
# Epoch 27/150
# 600/600 [==============================] - ETA: 0s - loss: 0.8056 - accuracy: 0.8596
# Epoch 27: val_loss improved from 0.69969 to 0.66381, saving model to app\models\best_val_loss_MargaritaLSG1.h5
#
# 💾 Macro-F1 mejoró a 0.9173. Guardado: app\models\best_macro_f1_MargaritaLSG1.h5
# 600/600 [==============================] - 48s 80ms/step - loss: 0.8056 - accuracy: 0.8596 - val_loss: 0.6638 - val_accuracy: 0.9200
# Epoch 28/150
# 600/600 [==============================] - ETA: 0s - loss: 0.8160 - accuracy: 0.8558
# Epoch 28: val_loss did not improve from 0.66381
# 600/600 [==============================] - 46s 76ms/step - loss: 0.8160 - accuracy: 0.8558 - val_loss: 0.8670 - val_accuracy: 0.8083
# Epoch 29/150
# 600/600 [==============================] - ETA: 0s - loss: 0.8055 - accuracy: 0.8631
# Epoch 29: val_loss improved from 0.66381 to 0.64890, saving model to app\models\best_val_loss_MargaritaLSG1.h5
# 600/600 [==============================] - 47s 78ms/step - loss: 0.8055 - accuracy: 0.8631 - val_loss: 0.6489 - val_accuracy: 0.9117
# Epoch 30/150
# 600/600 [==============================] - ETA: 0s - loss: 0.7769 - accuracy: 0.8740
# Epoch 30: val_loss did not improve from 0.64890
#
# 💾 Macro-F1 mejoró a 0.9257. Guardado: app\models\best_macro_f1_MargaritaLSG1.h5
# 600/600 [==============================] - 49s 82ms/step - loss: 0.7769 - accuracy: 0.8740 - val_loss: 0.6608 - val_accuracy: 0.9267
# Epoch 31/150
# 600/600 [==============================] - ETA: 0s - loss: 0.7733 - accuracy: 0.8754
# Epoch 31: val_loss improved from 0.64890 to 0.60929, saving model to app\models\best_val_loss_MargaritaLSG1.h5
#
# 💾 Macro-F1 mejoró a 0.9489. Guardado: app\models\best_macro_f1_MargaritaLSG1.h5
# 600/600 [==============================] - 50s 83ms/step - loss: 0.7733 - accuracy: 0.8754 - val_loss: 0.6093 - val_accuracy: 0.9492
# Epoch 32/150
# 600/600 [==============================] - ETA: 0s - loss: 0.7629 - accuracy: 0.8829
# Epoch 32: val_loss did not improve from 0.60929
# 600/600 [==============================] - 48s 79ms/step - loss: 0.7629 - accuracy: 0.8829 - val_loss: 0.6769 - val_accuracy: 0.9000
# Epoch 33/150
# 600/600 [==============================] - ETA: 0s - loss: 0.7799 - accuracy: 0.8746
# Epoch 33: val_loss did not improve from 0.60929
# 600/600 [==============================] - 42s 70ms/step - loss: 0.7799 - accuracy: 0.8746 - val_loss: 0.7110 - val_accuracy: 0.9100
# Epoch 34/150
# 600/600 [==============================] - ETA: 0s - loss: 0.7883 - accuracy: 0.8750
# Epoch 34: val_loss did not improve from 0.60929
# 600/600 [==============================] - 42s 70ms/step - loss: 0.7883 - accuracy: 0.8750 - val_loss: 0.7237 - val_accuracy: 0.8883
# Epoch 35/150
# 600/600 [==============================] - ETA: 0s - loss: 0.7707 - accuracy: 0.8840
# Epoch 35: val_loss did not improve from 0.60929
# 600/600 [==============================] - 41s 69ms/step - loss: 0.7707 - accuracy: 0.8840 - val_loss: 0.6906 - val_accuracy: 0.9092
# Epoch 36/150
# 600/600 [==============================] - ETA: 0s - loss: 0.8348 - accuracy: 0.8727
# Epoch 36: val_loss did not improve from 0.60929
# 600/600 [==============================] - 44s 73ms/step - loss: 0.8348 - accuracy: 0.8727 - val_loss: 0.6504 - val_accuracy: 0.9342
# Epoch 37/150
# 600/600 [==============================] - ETA: 0s - loss: 0.7578 - accuracy: 0.8908
# Epoch 37: val_loss improved from 0.60929 to 0.54528, saving model to app\models\best_val_loss_MargaritaLSG1.h5
#
# 💾 Macro-F1 mejoró a 0.9733. Guardado: app\models\best_macro_f1_MargaritaLSG1.h5
# 600/600 [==============================] - 40s 66ms/step - loss: 0.7578 - accuracy: 0.8908 - val_loss: 0.5453 - val_accuracy: 0.9733
# Epoch 38/150
# 600/600 [==============================] - ETA: 0s - loss: 0.7641 - accuracy: 0.8923
# Epoch 38: val_loss did not improve from 0.54528
# 600/600 [==============================] - 45s 75ms/step - loss: 0.7641 - accuracy: 0.8923 - val_loss: 0.5688 - val_accuracy: 0.9617
# Epoch 39/150
# 600/600 [==============================] - ETA: 0s - loss: 0.7366 - accuracy: 0.9010
# Epoch 39: val_loss did not improve from 0.54528
# 600/600 [==============================] - 44s 73ms/step - loss: 0.7366 - accuracy: 0.9010 - val_loss: 0.6582 - val_accuracy: 0.9208
# Epoch 40/150
# 600/600 [==============================] - ETA: 0s - loss: 0.7484 - accuracy: 0.8925
# Epoch 40: val_loss did not improve from 0.54528
# 600/600 [==============================] - 47s 78ms/step - loss: 0.7484 - accuracy: 0.8925 - val_loss: 0.6286 - val_accuracy: 0.9408
# Epoch 41/150
# 599/600 [============================>.] - ETA: 0s - loss: 0.7373 - accuracy: 0.8975
# Epoch 41: val_loss did not improve from 0.54528
# 600/600 [==============================] - 44s 73ms/step - loss: 0.7372 - accuracy: 0.8977 - val_loss: 0.6118 - val_accuracy: 0.9358
# Epoch 42/150
# 600/600 [==============================] - ETA: 0s - loss: 0.7139 - accuracy: 0.9027
# Epoch 42: val_loss did not improve from 0.54528
# 600/600 [==============================] - 43s 72ms/step - loss: 0.7139 - accuracy: 0.9027 - val_loss: 0.7086 - val_accuracy: 0.9058
# Epoch 43/150
# 600/600 [==============================] - ETA: 0s - loss: 0.7055 - accuracy: 0.9092
# Epoch 43: val_loss did not improve from 0.54528
# 600/600 [==============================] - 50s 84ms/step - loss: 0.7055 - accuracy: 0.9092 - val_loss: 0.6019 - val_accuracy: 0.9308
# Epoch 44/150
# 600/600 [==============================] - ETA: 0s - loss: 0.7114 - accuracy: 0.9075
# Epoch 44: val_loss did not improve from 0.54528
# 600/600 [==============================] - 51s 85ms/step - loss: 0.7114 - accuracy: 0.9075 - val_loss: 0.5893 - val_accuracy: 0.9467
# Epoch 45/150
# 600/600 [==============================] - ETA: 0s - loss: 0.6960 - accuracy: 0.9135
# Epoch 45: val_loss did not improve from 0.54528
# 600/600 [==============================] - 47s 79ms/step - loss: 0.6960 - accuracy: 0.9135 - val_loss: 0.5813 - val_accuracy: 0.9558
# Epoch 46/150
# 600/600 [==============================] - ETA: 0s - loss: 0.6923 - accuracy: 0.9131
# Epoch 46: val_loss did not improve from 0.54528
# 600/600 [==============================] - 41s 68ms/step - loss: 0.6923 - accuracy: 0.9131 - val_loss: 0.5883 - val_accuracy: 0.9517
# Epoch 47/150
# 600/600 [==============================] - ETA: 0s - loss: 0.6927 - accuracy: 0.9154
# Epoch 47: val_loss improved from 0.54528 to 0.53547, saving model to app\models\best_val_loss_MargaritaLSG1.h5
# 600/600 [==============================] - 39s 65ms/step - loss: 0.6927 - accuracy: 0.9154 - val_loss: 0.5355 - val_accuracy: 0.9717
# Epoch 48/150
# 600/600 [==============================] - ETA: 0s - loss: 0.6903 - accuracy: 0.9150
# Epoch 48: val_loss did not improve from 0.53547
# 600/600 [==============================] - 49s 81ms/step - loss: 0.6903 - accuracy: 0.9150 - val_loss: 0.7849 - val_accuracy: 0.8767
# Epoch 49/150
# 600/600 [==============================] - ETA: 0s - loss: 0.7516 - accuracy: 0.8965
# Epoch 49: val_loss did not improve from 0.53547
# 600/600 [==============================] - 54s 90ms/step - loss: 0.7516 - accuracy: 0.8965 - val_loss: 0.8269 - val_accuracy: 0.8708
# Epoch 50/150
# 600/600 [==============================] - ETA: 0s - loss: 0.6663 - accuracy: 0.9244
# Epoch 50: val_loss did not improve from 0.53547
# 600/600 [==============================] - 54s 90ms/step - loss: 0.6663 - accuracy: 0.9244 - val_loss: 0.6038 - val_accuracy: 0.9358
# Epoch 51/150
# 600/600 [==============================] - ETA: 0s - loss: 0.6793 - accuracy: 0.9231
# Epoch 51: val_loss did not improve from 0.53547
# 600/600 [==============================] - 46s 76ms/step - loss: 0.6793 - accuracy: 0.9231 - val_loss: 0.6827 - val_accuracy: 0.9150
# Epoch 52/150
# 600/600 [==============================] - ETA: 0s - loss: 0.7138 - accuracy: 0.9054
# Epoch 52: val_loss did not improve from 0.53547
# 600/600 [==============================] - 56s 93ms/step - loss: 0.7138 - accuracy: 0.9054 - val_loss: 0.5910 - val_accuracy: 0.9458
# Epoch 53/150
# 600/600 [==============================] - ETA: 0s - loss: 0.7086 - accuracy: 0.9121
# Epoch 53: val_loss improved from 0.53547 to 0.51569, saving model to app\models\best_val_loss_MargaritaLSG1.h5
#
# 💾 Macro-F1 mejoró a 0.9799. Guardado: app\models\best_macro_f1_MargaritaLSG1.h5
# 600/600 [==============================] - 54s 89ms/step - loss: 0.7086 - accuracy: 0.9121 - val_loss: 0.5157 - val_accuracy: 0.9800
# Epoch 54/150
# 600/600 [==============================] - ETA: 0s - loss: 0.6782 - accuracy: 0.9248
# Epoch 54: val_loss did not improve from 0.51569
# 600/600 [==============================] - 54s 90ms/step - loss: 0.6782 - accuracy: 0.9248 - val_loss: 0.5768 - val_accuracy: 0.9608
# Epoch 55/150
# 600/600 [==============================] - ETA: 0s - loss: 0.6693 - accuracy: 0.9210
# Epoch 55: val_loss did not improve from 0.51569
# 600/600 [==============================] - 54s 90ms/step - loss: 0.6693 - accuracy: 0.9210 - val_loss: 0.5307 - val_accuracy: 0.9683
# Epoch 56/150
# 600/600 [==============================] - ETA: 0s - loss: 0.6549 - accuracy: 0.9294
# Epoch 56: val_loss did not improve from 0.51569
# 600/600 [==============================] - 54s 90ms/step - loss: 0.6549 - accuracy: 0.9294 - val_loss: 0.7336 - val_accuracy: 0.8900
# Epoch 57/150
# 600/600 [==============================] - ETA: 0s - loss: 0.6931 - accuracy: 0.9177
# Epoch 57: val_loss did not improve from 0.51569
# 600/600 [==============================] - 54s 90ms/step - loss: 0.6931 - accuracy: 0.9177 - val_loss: 0.5636 - val_accuracy: 0.9550
# Epoch 58/150
# 600/600 [==============================] - ETA: 0s - loss: 0.6452 - accuracy: 0.9265
# Epoch 58: val_loss improved from 0.51569 to 0.49222, saving model to app\models\best_val_loss_MargaritaLSG1.h5
#
# 💾 Macro-F1 mejoró a 0.9859. Guardado: app\models\best_macro_f1_MargaritaLSG1.h5
# 600/600 [==============================] - 54s 90ms/step - loss: 0.6452 - accuracy: 0.9265 - val_loss: 0.4922 - val_accuracy: 0.9858
# Epoch 59/150
# 600/600 [==============================] - ETA: 0s - loss: 0.6695 - accuracy: 0.9265
# Epoch 59: val_loss did not improve from 0.49222
# 600/600 [==============================] - 53s 89ms/step - loss: 0.6695 - accuracy: 0.9265 - val_loss: 0.5708 - val_accuracy: 0.9483
# Epoch 60/150
# 600/600 [==============================] - ETA: 0s - loss: 0.6632 - accuracy: 0.9242
# Epoch 60: val_loss did not improve from 0.49222
# 600/600 [==============================] - 51s 85ms/step - loss: 0.6632 - accuracy: 0.9242 - val_loss: 0.6017 - val_accuracy: 0.9292
# Epoch 61/150
# 600/600 [==============================] - ETA: 0s - loss: 0.6536 - accuracy: 0.9300
# Epoch 61: val_loss did not improve from 0.49222
# 600/600 [==============================] - 51s 85ms/step - loss: 0.6536 - accuracy: 0.9300 - val_loss: 0.6309 - val_accuracy: 0.9325
# Epoch 62/150
# 600/600 [==============================] - ETA: 0s - loss: 0.6417 - accuracy: 0.9315
# Epoch 62: val_loss did not improve from 0.49222
# 600/600 [==============================] - 51s 85ms/step - loss: 0.6417 - accuracy: 0.9315 - val_loss: 0.5867 - val_accuracy: 0.9425
# Epoch 63/150
# 600/600 [==============================] - ETA: 0s - loss: 0.6813 - accuracy: 0.9167
# Epoch 63: val_loss did not improve from 0.49222
# 600/600 [==============================] - 53s 88ms/step - loss: 0.6813 - accuracy: 0.9167 - val_loss: 0.5565 - val_accuracy: 0.9692
# Epoch 64/150
# 600/600 [==============================] - ETA: 0s - loss: 0.6918 - accuracy: 0.9144
# Epoch 64: val_loss did not improve from 0.49222
# 600/600 [==============================] - 51s 85ms/step - loss: 0.6918 - accuracy: 0.9144 - val_loss: 0.4947 - val_accuracy: 0.9858
# Epoch 65/150
# 600/600 [==============================] - ETA: 0s - loss: 0.6225 - accuracy: 0.9394
# Epoch 65: val_loss did not improve from 0.49222
# 600/600 [==============================] - 53s 88ms/step - loss: 0.6225 - accuracy: 0.9394 - val_loss: 0.6797 - val_accuracy: 0.9033
# Epoch 66/150
# 600/600 [==============================] - ETA: 0s - loss: 0.6652 - accuracy: 0.9244
# Epoch 66: val_loss did not improve from 0.49222
# 600/600 [==============================] - 52s 86ms/step - loss: 0.6652 - accuracy: 0.9244 - val_loss: 0.5203 - val_accuracy: 0.9783
# Epoch 67/150
# 600/600 [==============================] - ETA: 0s - loss: 0.6297 - accuracy: 0.9408
# Epoch 67: val_loss did not improve from 0.49222
# 600/600 [==============================] - 53s 88ms/step - loss: 0.6297 - accuracy: 0.9408 - val_loss: 0.7383 - val_accuracy: 0.8875
# Epoch 68/150
# 600/600 [==============================] - ETA: 0s - loss: 0.6361 - accuracy: 0.9337
# Epoch 68: val_loss did not improve from 0.49222
# 600/600 [==============================] - 53s 87ms/step - loss: 0.6361 - accuracy: 0.9337 - val_loss: 0.5724 - val_accuracy: 0.9533
# Epoch 69/150
# 600/600 [==============================] - ETA: 0s - loss: 0.6507 - accuracy: 0.9292
# Epoch 69: val_loss did not improve from 0.49222
# 600/600 [==============================] - 53s 88ms/step - loss: 0.6507 - accuracy: 0.9292 - val_loss: 0.7486 - val_accuracy: 0.9025
# Epoch 70/150
# 600/600 [==============================] - ETA: 0s - loss: 0.6180 - accuracy: 0.9410
# Epoch 70: val_loss improved from 0.49222 to 0.47634, saving model to app\models\best_val_loss_MargaritaLSG1.h5
#
# 💾 Macro-F1 mejoró a 0.9908. Guardado: app\models\best_macro_f1_MargaritaLSG1.h5
# 600/600 [==============================] - 55s 91ms/step - loss: 0.6180 - accuracy: 0.9410 - val_loss: 0.4763 - val_accuracy: 0.9908
# Epoch 71/150
# 600/600 [==============================] - ETA: 0s - loss: 0.6462 - accuracy: 0.9354
# Epoch 71: val_loss did not improve from 0.47634
# 600/600 [==============================] - 51s 84ms/step - loss: 0.6462 - accuracy: 0.9354 - val_loss: 0.4811 - val_accuracy: 0.9883
# Epoch 72/150
# 600/600 [==============================] - ETA: 0s - loss: 0.6499 - accuracy: 0.9321
# Epoch 72: val_loss did not improve from 0.47634
# 600/600 [==============================] - 50s 83ms/step - loss: 0.6499 - accuracy: 0.9321 - val_loss: 0.6084 - val_accuracy: 0.9417
# Epoch 73/150
# 600/600 [==============================] - ETA: 0s - loss: 0.6616 - accuracy: 0.9325
# Epoch 73: val_loss did not improve from 0.47634
# 600/600 [==============================] - 46s 77ms/step - loss: 0.6616 - accuracy: 0.9325 - val_loss: 0.5641 - val_accuracy: 0.9542
# Epoch 74/150
# 600/600 [==============================] - ETA: 0s - loss: 0.6532 - accuracy: 0.9275
# Epoch 74: val_loss did not improve from 0.47634
# 600/600 [==============================] - 46s 76ms/step - loss: 0.6532 - accuracy: 0.9275 - val_loss: 0.5457 - val_accuracy: 0.9658
# Epoch 75/150
# 600/600 [==============================] - ETA: 0s - loss: 0.6216 - accuracy: 0.9425
# Epoch 75: val_loss did not improve from 0.47634
# 600/600 [==============================] - 48s 79ms/step - loss: 0.6216 - accuracy: 0.9425 - val_loss: 0.4989 - val_accuracy: 0.9800
# Epoch 76/150
# 600/600 [==============================] - ETA: 0s - loss: 0.6561 - accuracy: 0.9279
# Epoch 76: val_loss did not improve from 0.47634
# 600/600 [==============================] - 45s 75ms/step - loss: 0.6561 - accuracy: 0.9279 - val_loss: 0.5996 - val_accuracy: 0.9442
# Epoch 77/150
# 600/600 [==============================] - ETA: 0s - loss: 0.6401 - accuracy: 0.9410
# Epoch 77: val_loss did not improve from 0.47634
# 600/600 [==============================] - 52s 86ms/step - loss: 0.6401 - accuracy: 0.9410 - val_loss: 0.5245 - val_accuracy: 0.9750
# Epoch 78/150
# 600/600 [==============================] - ETA: 0s - loss: 0.6524 - accuracy: 0.9300
# Epoch 78: val_loss did not improve from 0.47634
# 600/600 [==============================] - 53s 88ms/step - loss: 0.6524 - accuracy: 0.9300 - val_loss: 0.5066 - val_accuracy: 0.9808
# Epoch 79/150
# 600/600 [==============================] - ETA: 0s - loss: 0.6493 - accuracy: 0.9317
# Epoch 79: val_loss did not improve from 0.47634
# 600/600 [==============================] - 54s 90ms/step - loss: 0.6493 - accuracy: 0.9317 - val_loss: 0.5211 - val_accuracy: 0.9775
# Epoch 80/150
# 600/600 [==============================] - ETA: 0s - loss: 0.6424 - accuracy: 0.9356
# Epoch 80: val_loss did not improve from 0.47634
# 600/600 [==============================] - 54s 89ms/step - loss: 0.6424 - accuracy: 0.9356 - val_loss: 0.5120 - val_accuracy: 0.9783
# Epoch 81/150
# 600/600 [==============================] - ETA: 0s - loss: 0.6034 - accuracy: 0.9481
# Epoch 81: val_loss did not improve from 0.47634
# 600/600 [==============================] - 54s 90ms/step - loss: 0.6034 - accuracy: 0.9481 - val_loss: 0.5033 - val_accuracy: 0.9825
# Epoch 82/150
# 600/600 [==============================] - ETA: 0s - loss: 0.6249 - accuracy: 0.9396
# Epoch 82: val_loss did not improve from 0.47634
# 600/600 [==============================] - 52s 87ms/step - loss: 0.6249 - accuracy: 0.9396 - val_loss: 0.4928 - val_accuracy: 0.9892
# Epoch 83/150
# 600/600 [==============================] - ETA: 0s - loss: 0.6188 - accuracy: 0.9421
# Epoch 83: val_loss did not improve from 0.47634
# 600/600 [==============================] - 41s 69ms/step - loss: 0.6188 - accuracy: 0.9421 - val_loss: 0.4795 - val_accuracy: 0.9883
# Epoch 84/150
# 599/600 [============================>.] - ETA: 0s - loss: 0.6403 - accuracy: 0.9320
# Epoch 84: val_loss did not improve from 0.47634
# 600/600 [==============================] - 38s 64ms/step - loss: 0.6406 - accuracy: 0.9317 - val_loss: 0.5681 - val_accuracy: 0.9575
# Epoch 85/150
# 600/600 [==============================] - ETA: 0s - loss: 0.6045 - accuracy: 0.9477Restoring model weights from the end of the best epoch: 70.
#
# Epoch 85: val_loss did not improve from 0.47634
# 600/600 [==============================] - 38s 64ms/step - loss: 0.6045 - accuracy: 0.9477 - val_loss: 0.5231 - val_accuracy: 0.9683
# Epoch 85: early stopping
# 💾 Modelo final (best val_loss) guardado en: app\models\MargaritaLSG1.h5
# 🏷️  Labels guardadas en: app\models\labels_MargaritaLSG1.json
# 🖼️  Matriz de confusión guardada en: app\models\confusion_matrix_MargaritaLSG1.png
# 📊 Accuracy final - Train: 0.95 | Val: 0.97
# ✅ Buen desempeño general
#
# 📃 Classification report (validación):
#               precision    recall  f1-score   support
#
#        adios       0.99      1.00      0.99        80
#       cantar       1.00      0.99      0.99        80
#         cual       1.00      0.99      0.99        80
#        dolor       0.97      0.97      0.97        80
#        donde       0.97      0.96      0.97        80
#     estudiar       1.00      0.99      0.99        80
#        feliz       0.99      1.00      0.99        80
#      gracias       0.99      0.99      0.99        80
#         hola       1.00      1.00      1.00        80
#        jugar       1.00      1.00      1.00        80
#        lunes       0.99      0.99      0.99        80
#    miercoles       1.00      1.00      1.00        80
#      por_que       0.98      0.99      0.98        80
#         reir       1.00      1.00      1.00        80
#          ser       0.99      1.00      0.99        80
#
#     accuracy                           0.99      1200
#    macro avg       0.99      0.99      0.99      1200
# weighted avg       0.99      0.99      0.99      1200

# %% [markdown]
# ## 5. Validaciones

# %%
MODEL_PATH = "models/MargaritaLSG1.h5"
DATA_PATH = "data/frases"
WORDS = sorted(os.listdir(DATA_PATH))  # nombres de las clases
MODEL_FRAMES = 30
MIN_LENGTH_FRAMES = 10
FONT = cv2.FONT_HERSHEY_SIMPLEX
FONT_POS = (10, 30)
FONT_SIZE = 1

def mediapipe_detection(image, model):
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    image.flags.writeable = False
    return model.process(image)

def there_hand(results):
    return results.left_hand_landmarks or results.right_hand_landmarks

def extract_keypoints(results):
    lh = np.array([[res.x, res.y, res.z] for res in results.left_hand_landmarks.landmark]) if results.left_hand_landmarks else np.zeros((21, 3))
    rh = np.array([[res.x, res.y, res.z] for res in results.right_hand_landmarks.landmark]) if results.right_hand_landmarks else np.zeros((21, 3))
    return np.concatenate([lh, rh]).flatten()

def normalize_keypoints(keypoints, target_length=30):
    current_length = len(keypoints)
    if current_length == target_length:
        return keypoints
    elif current_length > target_length:
        step = current_length / target_length
        indices = np.arange(0, current_length, step).astype(int)[:target_length]
        return [keypoints[i] for i in indices]
    else:
        indices = np.linspace(0, current_length - 1, target_length)
        interpolated = []
        for i in indices:
            lower = int(np.floor(i))
            upper = int(np.ceil(i))
            weight = i - lower
            if lower == upper:
                interpolated.append(keypoints[lower])
            else:
                interpolated.append(((1 - weight) * np.array(keypoints[lower]) + weight * np.array(keypoints[upper])).tolist())
        return interpolated

def draw_keypoints(image, results):
    mp_drawing = mp.solutions.drawing_utils
    if results.left_hand_landmarks:
        mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp.solutions.holistic.HAND_CONNECTIONS)
    if results.right_hand_landmarks:
        mp_drawing.draw_landmarks(image, results.right_hand_landmarks, mp.solutions.holistic.HAND_CONNECTIONS)

# %%
def evaluate_model(threshold=0.8, margin_frame=1, delay_frames=3, src=0):
    print("🟡 Cargando modelo...")
    model = load_model(MODEL_PATH)

    print("📷 Inicializando cámara...")
    cap = cv2.VideoCapture(src)
    if not cap.isOpened():
        print("❌ No se pudo abrir la cámara.")
        return

    sentence = []
    pred_label = ""
    pred_prob = 0.0
    kp_seq, count_frame, fix_frames = [], 0, 0
    recording = False

    with Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
        print("🎥 Traductor en vivo iniciado. Presiona 'q' para salir.")
        while True:
            ret, frame = cap.read()
            if not ret:
                print("⚠️ No se pudo leer el frame de la cámara.")
                break

            results = mediapipe_detection(frame, holistic)

            if there_hand(results) or recording:
                recording = False
                count_frame += 1
                if count_frame > margin_frame:
                    kp_frame = extract_keypoints(results)
                    kp_seq.append(kp_frame)
            else:
                if count_frame >= MIN_LENGTH_FRAMES + margin_frame:
                    fix_frames += 1
                    if fix_frames < delay_frames:
                        recording = True
                        continue

                    kp_seq = kp_seq[: -(margin_frame + delay_frames)]
                    kp_normalized = normalize_keypoints(kp_seq, target_length=MODEL_FRAMES)
                    input_data = np.expand_dims(np.array(kp_normalized), axis=0)

                    prediction = model.predict(input_data, verbose=0)[0]
                    max_idx = np.argmax(prediction)
                    max_prob = prediction[max_idx]

                    if max_prob > threshold:
                        pred_label = WORDS[max_idx]
                        pred_prob = max_prob * 100
                        sentence.insert(0, pred_label)

                kp_seq = []
                count_frame = 0
                fix_frames = 0
                recording = False

            # Mostrar texto y porcentaje en ventana
            cv2.rectangle(frame, (0, 0), (640, 60), (245, 117, 16), -1)
            cv2.putText(frame, f'{pred_label.upper()} ({pred_prob:.1f}%)', FONT_POS, FONT, FONT_SIZE, (255, 255, 255), 2)

            draw_keypoints(frame, results)
            cv2.imshow('Traductor LSP', frame)

            if cv2.waitKey(10) & 0xFF == ord('q'):
                print("🛑 Cerrando traductor.")
                break

        cap.release()
        cv2.destroyAllWindows()

if __name__ == "__main__":
    evaluate_model()
# Out:
# 🟡 Cargando modelo...
# 📷 Inicializando cámara...
# 🎥 Traductor en vivo iniciado. Presiona 'q' para salir.
# 🛑 Cerrando traductor.

# %%
from contextlib import contextmanager
def evaluate_video(
    video_path: str,
    threshold: float = 0.8,
    margin_frame: int = 1,
    delay_frames: int = 3,
    output: bool = True,
    show_window: bool = False,
):
    """
    Evalúa un video en archivo en lugar de la cámara.
    - Detecta ventanas de gesto (aparece mano -> desaparece) y predice con el modelo.
    - Genera un MP4 anotado con el texto (si output=True).
    - Devuelve una lista de detecciones con tiempos de inicio/fin y probabilidad.
    """
    if not os.path.isfile(video_path):
        print(f"❌ No existe el archivo: {video_path}")
        return []

    print("🟡 Cargando modelo...")
    model = load_model(MODEL_PATH)

    print(f"🎬 Abriendo video: {video_path}")
    cap = cv2.VideoCapture(video_path)
    if not cap.isOpened():
        print("❌ No se pudo abrir el video.")
        return []

    fps = cap.get(cv2.CAP_PROP_FPS) or 30.0
    width  = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH)  or 640)
    height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT) or 480)
    total_frames = int(cap.get(cv2.CAP_PROP_FRAME_COUNT) or 0)

    # Preparar salida de video
    writer = None
    out_path = None
    if output:
        base = os.path.splitext(os.path.basename(video_path))[0]
        out_path = f"resultado_{base}.mp4"
        fourcc = cv2.VideoWriter_fourcc(*"mp4v")
        writer = cv2.VideoWriter(out_path, fourcc, fps, (width, height))

    detections = []  # cada item: {label, prob, start_frame, end_frame, start_time, end_time}

    kp_seq, count_frame, fix_frames = [], 0, 0
    recording = False

    pred_label = ""
    pred_prob = 0.0
    overlay_cooldown = 0  # frames para mostrar el texto en el video

    # --- MediaPipe Holistic context manager (usa tu helper si lo tienes) ---
    import mediapipe as mp
    with mp.solutions.holistic.Holistic(
        min_detection_confidence=0.5,
        min_tracking_confidence=0.5
    ) as holistic:

        frame_idx = 0
        print("▶️ Procesando frames...")
        while True:
            ret, frame = cap.read()
            if not ret:
                break

            # Detección con tu helper (si ya lo tienes). Si no, usa el pipeline normal de MP:
            # results = mediapipe_detection(frame, holistic)
            # Si tu mediapipe_detection ya convierte a RGB y llama holistic.process, úsalo.
            # Aquí uso el helper por compatibilidad con tu notebook:
            results = mediapipe_detection(frame, holistic)

            if there_hand(results) or recording:
                recording = False
                count_frame += 1
                if count_frame > margin_frame:
                    kp_frame = extract_keypoints(results)  # Debe regresar vector de 126 (o lo que uses)
                    kp_seq.append(kp_frame)
            else:
                # Sección de cierre del gesto
                if count_frame >= MIN_LENGTH_FRAMES + margin_frame:
                    fix_frames += 1
                    if fix_frames < delay_frames:
                        recording = True
                        # seguimos acumulando el "colchón" de cierre
                    else:
                        # recorta margen + delay
                        if margin_frame + delay_frames > 0:
                            kp_seq = kp_seq[:-(margin_frame + delay_frames)] if len(kp_seq) > (margin_frame + delay_frames) else kp_seq

                        # normaliza y remuestrea a MODEL_FRAMES
                        kp_normalized = normalize_keypoints(kp_seq, target_length=MODEL_FRAMES)  # (30, D)
                        input_data = np.expand_dims(np.array(kp_normalized), axis=0)            # (1,30,D)

                        prediction = model.predict(input_data, verbose=0)[0]
                        max_idx = int(np.argmax(prediction))
                        max_prob = float(prediction[max_idx])

                        if max_prob > threshold:
                            pred_label = WORDS[max_idx]
                            pred_prob = max_prob * 100.0
                            overlay_cooldown = int(fps * 0.7)  # muestra ~0.7s el texto

                            # marca temporal (aprox): usamos frame actual como fin, y restamos la duración de la ventana
                            end_frame = frame_idx
                            dur_frames = len(kp_seq)
                            start_frame = max(0, end_frame - dur_frames)
                            detections.append({
                                "label": pred_label,
                                "prob": pred_prob,
                                "start_frame": start_frame,
                                "end_frame": end_frame,
                                "start_time": start_frame / fps,
                                "end_time": end_frame / fps,
                            })

                        # reset para siguiente gesto
                        kp_seq, count_frame, fix_frames, recording = [], 0, 0, False
                else:
                    # No hubo suficiente material para formar gesto
                    kp_seq, count_frame, fix_frames, recording = [], 0, 0, False

            # --- Overlay de texto (si hubo predicción reciente) ---
            if overlay_cooldown > 0:
                cv2.rectangle(frame, (0, 0), (max(300, width // 2), 60), (245, 117, 16), -1)
                cv2.putText(frame, f'{pred_label.upper()} ({pred_prob:.1f}%)',
                            (20, 40), FONT, FONT_SIZE, (255, 255, 255), 2)
                overlay_cooldown -= 1

            # Dibuja keypoints si quieres mantener tu visualización
            try:
                draw_keypoints(frame, results)
            except Exception:
                pass  # por si tu helper no está cargado aquí

            # Escribir/frame y/o mostrar
            if writer is not None:
                writer.write(frame)

            if show_window:
                cv2.imshow('Traductor LSP (video)', frame)
                if cv2.waitKey(1) & 0xFF == ord('q'):
                    break

            frame_idx += 1

    cap.release()
    if writer is not None:
        writer.release()
    if show_window:
        cv2.destroyAllWindows()

    # --- Resumen ---
    print("✅ Detecciones:")
    if not detections:
        print("   (sin resultados sobre el umbral)")
    else:
        for i, d in enumerate(detections, 1):
            print(f" {i:02d}. {d['label']}  {d['prob']:.1f}%  "
                  f"{d['start_time']:.2f}s → {d['end_time']:.2f}s  "
                  f"(frames {d['start_frame']}–{d['end_frame']})")

    if out_path:
        print(f"💾 Video anotado: {out_path}")

    return detections

# %%
detecciones = evaluate_video(
    "prueba.mp4",   # ruta a tu video
    threshold=0.8,   # probabilidad mínima aceptada
    output=True,     # genera un video anotado
    show_window=False # pon True si quieres que se abra una ventana en vivo
)

print(detecciones)
# Out:
# 🟡 Cargando modelo...
# 🎬 Abriendo video: prueba.mp4
# ▶️ Procesando frames...
# ✅ Detecciones:
#  01. hola  99.9%  1.33s → 2.66s  (frames 40–80)
#  02. hola  99.9%  4.02s → 5.28s  (frames 121–159)
#  03. feliz  99.9%  6.57s → 8.80s  (frames 198–265)
#  04. adios  99.9%  9.92s → 11.68s  (frames 299–352)
#  05. adios  99.9%  12.58s → 13.94s  (frames 379–420)
#  06. gracias  100.0%  14.97s → 16.16s  (frames 451–487)
#  07. gracias  100.0%  16.99s → 18.69s  (frames 512–563)
# 💾 Video anotado: resultado_prueba.mp4
# [{'label': 'hola', 'prob': 99.93089437484741, 'start_frame': 40, 'end_frame': 80, 'start_time': 1.3276146179401993, 'end_time': 2.6552292358803986}, {'label': 'hola', 'prob': 99.91962313652039, 'start_frame': 121, 'end_frame': 159, 'start_time': 4.016034219269103, 'end_time': 5.277268106312293}, {'label': 'feliz', 'prob': 99.94334578514099, 'start_frame': 198, 'end_frame': 265, 'start_time': 6.571692358803987, 'end_time': 8.79544684385382}, {'label': 'adios', 'prob': 99.91087317466736, 'start_frame': 299, 'end_frame': 352, 'start_time': 9.92391926910299, 'end_time': 11.683008637873755}, {'label': 'adios', 'prob': 99.91414546966553, 'start_frame': 379, 'end_frame': 420, 'start_time': 12.57914850498339, 'end_time': 13.939953488372094}, {'label': 'gracias', 'prob': 99.98397827148438, 'start_frame': 451, 'end_frame': 487, 'start_time': 14.968854817275748, 'end_time': 16.16370797342193}, {'label': 'gracias', 'prob': 99.96888637542725, 'start_frame': 512, 'end_frame': 563, 'start_time': 16.99346710963455, 'end_time': 18.686175747508308}]
