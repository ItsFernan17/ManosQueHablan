# %% [markdown]
# # Modelo No. 2

# %% [markdown]
# ## 1. Importaciones y utilidades

# %%
import os
import cv2
import numpy as np
from datetime import datetime
import mediapipe as mp
from keras.models import Sequential
from keras.layers import LSTM, Dense, Dropout
from keras.regularizers import l2
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.callbacks import EarlyStopping
from keras.models import load_model
from mediapipe.python.solutions.holistic import Holistic
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt

ROOT_PATH = "data"
FRAME_ACTIONS_PATH = "frases"  # carpeta por palabra/frase
FONT = cv2.FONT_HERSHEY_SIMPLEX
FONT_SIZE = 1
FONT_POS = (10, 30)

# Crear carpeta si no existe
def create_folder(path):
    if not os.path.exists(path):
        os.makedirs(path)

# Detectar si hay manos en los resultados
def there_hand(results):
    return results.left_hand_landmarks or results.right_hand_landmarks

# Dibujar los keypoints de las manos
def draw_keypoints(image, results):
    if results.left_hand_landmarks:
        mp.solutions.drawing_utils.draw_landmarks(image, results.left_hand_landmarks, mp.solutions.holistic.HAND_CONNECTIONS)
    if results.right_hand_landmarks:
        mp.solutions.drawing_utils.draw_landmarks(image, results.right_hand_landmarks, mp.solutions.holistic.HAND_CONNECTIONS)

# Aplicar MediaPipe
def mediapipe_detection(image, model):
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    image.flags.writeable = False
    results = model.process(image)
    return results

# Extraer keypoints de ambas manos
def extract_keypoints(results):
    lh = np.array([[res.x, res.y, res.z] for res in results.left_hand_landmarks.landmark]).flatten() if results.left_hand_landmarks else np.zeros(21 * 3)
    rh = np.array([[res.x, res.y, res.z] for res in results.right_hand_landmarks.landmark]).flatten() if results.right_hand_landmarks else np.zeros(21 * 3)
    return np.concatenate([lh, rh])

# %% [markdown]
# ## 2. Captura de muestras

# %%
def capture_samples_npy(path, margin_frame=1, min_cant_frames=30, delay_frames=3):
    '''
    CAPTURA DE MUESTRAS PARA UNA PALABRA Y GUARDA KEYPOINTS COMO .NPY

    path: ruta base de la palabra (se creará una carpeta por muestra)
    margin_frame: frames ignorados al inicio/final
    min_cant_frames: mínimo de frames válidos requeridos
    delay_frames: frames extra que espera antes de cortar grabación
    '''
    create_folder(path)

    count_frame = 0
    sequence = []
    fix_frames = 0
    recording = False

    # Detectar cuántos registros ya hay
    registro_actual = len([f for f in os.listdir(path) if f.endswith(".npy")]) + 1

    cap = cv2.VideoCapture(0)
    with mp.solutions.holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic_model:

        while cap.isOpened():
            ret, frame = cap.read()
            if not ret:
                break

            image = frame.copy()
            results = mediapipe_detection(frame, holistic_model)

            if there_hand(results) or recording:
                recording = False
                count_frame += 1
                if count_frame > margin_frame:
                    cv2.putText(image, f'Registro {registro_actual}...', (10, 30), FONT, FONT_SIZE, (100, 200, 255), 2)
                    cv2.putText(
                        image,
                        'Capturando...',
                        (20, image.shape[0] - 20),  # Abajo izquierda
                        FONT,
                        FONT_SIZE,
                        (0, 50, 255),  # Azul fuerte
                        2
                    )
                    keypoints = extract_keypoints(results)
                    sequence.append(keypoints)
            else:
                if len(sequence) >= min_cant_frames + margin_frame:
                    fix_frames += 1
                    if fix_frames < delay_frames:
                        recording = True
                        continue

                    # Cortar exceso
                    sequence = sequence[: - (margin_frame + delay_frames)]
                    if len(sequence) < min_cant_frames:
                        print("⚠️ Muestra descartada por ser muy corta.")
                    else:
                        timestamp = datetime.now().strftime('%y%m%d%H%M%S%f')
                        npy_path = os.path.join(path, f'sample_{timestamp}.npy')
                        np.save(npy_path, np.array(sequence))
                        print(f"✅ Muestra guardada: {npy_path}")
                        registro_actual += 1

                recording, fix_frames = False, 0
                sequence, count_frame = [], 0
                cv2.putText(image, f'Registro {registro_actual}...', (10, 30), FONT, FONT_SIZE, (100, 200, 255), 2)
                cv2.putText(
                    image,
                    'Listo para capturar...',
                    (20, image.shape[0] - 20),  # Abajo izquierda
                    FONT,
                    FONT_SIZE,
                    (0, 220, 100),  # Verde fuerte
                    2
                )

            draw_keypoints(image, results)
            cv2.imshow(f'Toma de muestras (keypoints) para \"{os.path.basename(path)}\"', image)
            if cv2.waitKey(10) & 0xFF == ord('q'):
                break

    cap.release()
    cv2.destroyAllWindows()
    
if __name__ == "__main__":
    palabra = "gracias"
    word_path = os.path.join(ROOT_PATH, FRAME_ACTIONS_PATH, palabra)
    capture_samples_npy(word_path)
# Out:
# libEGL warning: MESA-LOADER: failed to open iris: /usr/lib/dri/iris_dri.so: cannot open shared object file: No such file or directory (search paths /usr/lib/x86_64-linux-gnu/dri:\$${ORIGIN}/dri:/usr/lib/dri, suffix _dri)
#
# libEGL warning: MESA-LOADER: failed to open iris: /usr/lib/dri/iris_dri.so: cannot open shared object file: No such file or directory (search paths /usr/lib/x86_64-linux-gnu/dri:\$${ORIGIN}/dri:/usr/lib/dri, suffix _dri)
#
# libEGL warning: MESA-LOADER: failed to open swrast: /usr/lib/dri/swrast_dri.so: cannot open shared object file: No such file or directory (search paths /usr/lib/x86_64-linux-gnu/dri:\$${ORIGIN}/dri:/usr/lib/dri, suffix _dri)
#
# libEGL warning: MESA-LOADER: failed to open iris: /usr/lib/dri/iris_dri.so: cannot open shared object file: No such file or directory (search paths /usr/lib/x86_64-linux-gnu/dri:\$${ORIGIN}/dri:/usr/lib/dri, suffix _dri)
#
# libEGL warning: MESA-LOADER: failed to open iris: /usr/lib/dri/iris_dri.so: cannot open shared object file: No such file or directory (search paths /usr/lib/x86_64-linux-gnu/dri:\$${ORIGIN}/dri:/usr/lib/dri, suffix _dri)
#
# libEGL warning: MESA-LOADER: failed to open swrast: /usr/lib/dri/swrast_dri.so: cannot open shared object file: No such file or directory (search paths /usr/lib/x86_64-linux-gnu/dri:\$${ORIGIN}/dri:/usr/lib/dri, suffix _dri)
#
# libEGL warning: MESA-LOADER: failed to open iris: /usr/lib/dri/iris_dri.so: cannot open shared object file: No such file or directory (search paths /usr/lib/x86_64-linux-gnu/dri:\$${ORIGIN}/dri:/usr/lib/dri, suffix _dri)
#
# libEGL warning: MESA-LOADER: failed to open iris: /usr/lib/dri/iris_dri.so: cannot open shared object file: No such file or directory (search paths /usr/lib/x86_64-linux-gnu/dri:\$${ORIGIN}/dri:/usr/lib/dri, suffix _dri)
#
# libEGL warning: MESA-LOADER: failed to open swrast: /usr/lib/dri/swrast_dri.so: cannot open shared object file: No such file or directory (search paths /usr/lib/x86_64-linux-gnu/dri:\$${ORIGIN}/dri:/usr/lib/dri, suffix _dri)
#
# libEGL warning: MESA-LOADER: failed to open iris: /usr/lib/dri/iris_dri.so: cannot open shared object file: No such file or directory (search paths /usr/lib/x86_64-linux-gnu/dri:\$${ORIGIN}/dri:/usr/lib/dri, suffix _dri)
#
# libEGL warning: MESA-LOADER: failed to open iris: /usr/lib/dri/iris_dri.so: cannot open shared object file: No such file or directory (search paths /usr/lib/x86_64-linux-gnu/dri:\$${ORIGIN}/dri:/usr/lib/dri, suffix _dri)
#
# libEGL warning: MESA-LOADER: failed to open swrast: /usr/lib/dri/swrast_dri.so: cannot open shared object file: No such file or directory (search paths /usr/lib/x86_64-linux-gnu/dri:\$${ORIGIN}/dri:/usr/lib/dri, suffix _dri)
#
# libEGL warning: MESA-LOADER: failed to open iris: /usr/lib/dri/iris_dri.so: cannot open shared object file: No such file or directory (search paths /usr/lib/x86_64-linux-gnu/dri:\$${ORIGIN}/dri:/usr/lib/dri, suffix _dri)
#
# libEGL warning: MESA-LOADER: failed to open iris: /usr/lib/dri/iris_dri.so: cannot open shared object file: No such file or directory (search paths /usr/lib/x86_64-linux-gnu/dri:\$${ORIGIN}/dri:/usr/lib/dri, suffix _dri)
#
# libEGL warning: MESA-LOADER: failed to open swrast: /usr/lib/dri/swrast_dri.so: cannot open shared object file: No such file or directory (search paths /usr/lib/x86_64-linux-gnu/dri:\$${ORIGIN}/dri:/usr/lib/dri, suffix _dri)
#
# libEGL warning: MESA-LOADER: failed to open iris: /usr/lib/dri/iris_dri.so: cannot open shared object file: No such file or directory (search paths /usr/lib/x86_64-linux-gnu/dri:\$${ORIGIN}/dri:/usr/lib/dri, suffix _dri)
#
# libEGL warning: MESA-LOADER: failed to open iris: /usr/lib/dri/iris_dri.so: cannot open shared object file: No such file or directory (search paths /usr/lib/x86_64-linux-gnu/dri:\$${ORIGIN}/dri:/usr/lib/dri, suffix _dri)
#
# libEGL warning: MESA-LOADER: failed to open swrast: /usr/lib/dri/swrast_dri.so: cannot open shared object file: No such file or directory (search paths /usr/lib/x86_64-linux-gnu/dri:\$${ORIGIN}/dri:/usr/lib/dri, suffix _dri)
#
# libEGL warning: MESA-LOADER: failed to open iris: /usr/lib/dri/iris_dri.so: cannot open shared object file: No such file or directory (search paths /usr/lib/x86_64-linux-gnu/dri:\$${ORIGIN}/dri:/usr/lib/dri, suffix _dri)
#
# libEGL warning: MESA-LOADER: failed to open iris: /usr/lib/dri/iris_dri.so: cannot open shared object file: No such file or directory (search paths /usr/lib/x86_64-linux-gnu/dri:\$${ORIGIN}/dri:/usr/lib/dri, suffix _dri)
#
# libEGL warning: MESA-LOADER: failed to open swrast: /usr/lib/dri/swrast_dri.so: cannot open shared object file: No such file or directory (search paths /usr/lib/x86_64-linux-gnu/dri:\$${ORIGIN}/dri:/usr/lib/dri, suffix _dri)
#
# libEGL warning: MESA-LOADER: failed to open iris: /usr/lib/dri/iris_dri.so: cannot open shared object file: No such file or directory (search paths /usr/lib/x86_64-linux-gnu/dri:\$${ORIGIN}/dri:/usr/lib/dri, suffix _dri)
#
# libEGL warning: MESA-LOADER: failed to open iris: /usr/lib/dri/iris_dri.so: cannot open shared object file: No such file or directory (search paths /usr/lib/x86_64-linux-gnu/dri:\$${ORIGIN}/dri:/usr/lib/dri, suffix _dri)
#
# libEGL warning: MESA-LOADER: failed to open swrast: /usr/lib/dri/swrast_dri.so: cannot open shared object file: No such file or directory (search paths /usr/lib/x86_64-linux-gnu/dri:\$${ORIGIN}/dri:/usr/lib/dri, suffix _dri)
#
# libEGL warning: MESA-LOADER: failed to open iris: /usr/lib/dri/iris_dri.so: cannot open shared object file: No such file or directory (search paths /usr/lib/x86_64-linux-gnu/dri:\$${ORIGIN}/dri:/usr/lib/dri, suffix _dri)
#
# libEGL warning: MESA-LOADER: failed to open iris: /usr/lib/dri/iris_dri.so: cannot open shared object file: No such file or directory (search paths /usr/lib/x86_64-linux-gnu/dri:\$${ORIGIN}/dri:/usr/lib/dri, suffix _dri)
#
# libEGL warning: MESA-LOADER: failed to open swrast: /usr/lib/dri/swrast_dri.so: cannot open shared object file: No such file or directory (search paths /usr/lib/x86_64-linux-gnu/dri:\$${ORIGIN}/dri:/usr/lib/dri, suffix _dri)
#
# libEGL warning: MESA-LOADER: failed to open iris: /usr/lib/dri/iris_dri.so: cannot open shared object file: No such file or directory (search paths /usr/lib/x86_64-linux-gnu/dri:\$${ORIGIN}/dri:/usr/lib/dri, suffix _dri)
#
# libEGL warning: MESA-LOADER: failed to open iris: /usr/lib/dri/iris_dri.so: cannot open shared object file: No such file or directory (search paths /usr/lib/x86_64-linux-gnu/dri:\$${ORIGIN}/dri:/usr/lib/dri, suffix _dri)
#
# libEGL warning: MESA-LOADER: failed to open swrast: /usr/lib/dri/swrast_dri.so: cannot open shared object file: No such file or directory (search paths /usr/lib/x86_64-linux-gnu/dri:\$${ORIGIN}/dri:/usr/lib/dri, suffix _dri)
#
# libEGL warning: MESA-LOADER: failed to open iris: /usr/lib/dri/iris_dri.so: cannot open shared object file: No such file or directory (search paths /usr/lib/x86_64-linux-gnu/dri:\$${ORIGIN}/dri:/usr/lib/dri, suffix _dri)
#
# libEGL warning: MESA-LOADER: failed to open iris: /usr/lib/dri/iris_dri.so: cannot open shared object file: No such file or directory (search paths /usr/lib/x86_64-linux-gnu/dri:\$${ORIGIN}/dri:/usr/lib/dri, suffix _dri)
#
# libEGL warning: MESA-LOADER: failed to open swrast: /usr/lib/dri/swrast_dri.so: cannot open shared object file: No such file or directory (search paths /usr/lib/x86_64-linux-gnu/dri:\$${ORIGIN}/dri:/usr/lib/dri, suffix _dri)
#
# libEGL warning: MESA-LOADER: failed to open iris: /usr/lib/dri/iris_dri.so: cannot open shared object file: No such file or directory (search paths /usr/lib/x86_64-linux-gnu/dri:\$${ORIGIN}/dri:/usr/lib/dri, suffix _dri)
#
# libEGL warning: MESA-LOADER: failed to open iris: /usr/lib/dri/iris_dri.so: cannot open shared object file: No such file or directory (search paths /usr/lib/x86_64-linux-gnu/dri:\$${ORIGIN}/dri:/usr/lib/dri, suffix _dri)
#
# libEGL warning: MESA-LOADER: failed to open swrast: /usr/lib/dri/swrast_dri.so: cannot open shared object file: No such file or directory (search paths /usr/lib/x86_64-linux-gnu/dri:\$${ORIGIN}/dri:/usr/lib/dri, suffix _dri)
#
# libEGL warning: MESA-LOADER: failed to open iris: /usr/lib/dri/iris_dri.so: cannot open shared object file: No such file or directory (search paths /usr/lib/x86_64-linux-gnu/dri:\$${ORIGIN}/dri:/usr/lib/dri, suffix _dri)
#
# libEGL warning: MESA-LOADER: failed to open iris: /usr/lib/dri/iris_dri.so: cannot open shared object file: No such file or directory (search paths /usr/lib/x86_64-linux-gnu/dri:\$${ORIGIN}/dri:/usr/lib/dri, suffix _dri)
#
# libEGL warning: MESA-LOADER: failed to open swrast: /usr/lib/dri/swrast_dri.so: cannot open shared object file: No such file or directory (search paths /usr/lib/x86_64-linux-gnu/dri:\$${ORIGIN}/dri:/usr/lib/dri, suffix _dri)
#
# W0000 00:00:1754010144.940647   19598 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1754010144.964525   19598 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1754010144.965824   19596 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1754010144.966485   19598 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1754010144.966704   19600 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1754010144.971980   19607 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1754010144.979049   19598 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1754010144.981862   19600 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.

# %% [markdown]
# ## 3. Normalización

# %%
ROOT_PATH = "data"
FRAME_ACTIONS_PATH = "frases"
MODEL_FRAMES = 30  

def normalize_keypoints_sequence(sequence, target_len=30):
    current_len = len(sequence)
    if current_len == target_len:
        return sequence
    elif current_len > target_len:
        # Reducir seleccionando frames uniformemente
        step = current_len / target_len
        indices = np.arange(0, current_len, step).astype(int)[:target_len]
        return sequence[indices]
    else:
        # Interpolar si es menor
        indices = np.linspace(0, current_len - 1, target_len)
        interpolated = []
        for i in indices:
            lower = int(np.floor(i))
            upper = int(np.ceil(i))
            weight = i - lower
            if upper >= current_len:
                upper = current_len - 1
            interpolated_frame = (1 - weight) * sequence[lower] + weight * sequence[upper]
            interpolated.append(interpolated_frame)
        return np.array(interpolated)

def process_npy_directory(word_directory, target_len=30):
    for fname in os.listdir(word_directory):
        if fname.endswith(".npy"):
            full_path = os.path.join(word_directory, fname)
            sequence = np.load(full_path)
            normalized = normalize_keypoints_sequence(sequence, target_len)
            np.save(full_path, normalized)
            print(f"✅ Normalizado: {fname} → {normalized.shape}")

if __name__ == "__main__":
    word_ids = [w for w in os.listdir(os.path.join(ROOT_PATH, FRAME_ACTIONS_PATH))]

    for word_id in word_ids:
        word_path = os.path.join(ROOT_PATH, FRAME_ACTIONS_PATH, word_id)
        if os.path.isdir(word_path):
            print(f"\n📦 Normalizando muestras de: {word_id}")
            process_npy_directory(word_path, target_len=MODEL_FRAMES)
# Out:
# 📦 Normalizando muestras de: hola
# ✅ Normalizado: sample_250729215552766802.npy → (30, 126)
# ✅ Normalizado: sample_250729215510861187.npy → (30, 126)
# ✅ Normalizado: sample_250729215504327477.npy → (30, 126)
# ✅ Normalizado: sample_250729215440975792.npy → (30, 126)
# ✅ Normalizado: sample_250729215506527407.npy → (30, 126)
# ✅ Normalizado: sample_250729215508671929.npy → (30, 126)
# ✅ Normalizado: sample_250729215545929684.npy → (30, 126)
# ✅ Normalizado: sample_250729215539287852.npy → (30, 126)
# ✅ Normalizado: sample_250729215530735714.npy → (30, 126)
# ✅ Normalizado: sample_250729215436434260.npy → (30, 126)
# ✅ Normalizado: sample_250729215455887260.npy → (30, 126)
# ✅ Normalizado: sample_250729215548194886.npy → (30, 126)
# ✅ Normalizado: sample_250729215534879067.npy → (30, 126)
# ✅ Normalizado: sample_250729215515218243.npy → (30, 126)
# ✅ Normalizado: sample_250729215528722940.npy → (30, 126)
# ✅ Normalizado: sample_250729215607059574.npy → (30, 126)
# ✅ Normalizado: sample_250729215502177175.npy → (30, 126)
# ✅ Normalizado: sample_250729215513017172.npy → (30, 126)
# ✅ Normalizado: sample_250729215526720106.npy → (30, 126)
# ✅ Normalizado: sample_250729215602772604.npy → (30, 126)
# ✅ Normalizado: sample_250729215536961658.npy → (30, 126)
# ✅ Normalizado: sample_250729215609332104.npy → (30, 126)
# ✅ Normalizado: sample_250729215604841862.npy → (30, 126)
# ✅ Normalizado: sample_250729215550540754.npy → (30, 126)
# ✅ Normalizado: sample_250729215532747227.npy → (30, 126)
# ✅ Normalizado: sample_250729215453618784.npy → (30, 126)
# ✅ Normalizado: sample_250729215517428886.npy → (30, 126)
# ✅ Normalizado: sample_250729215458019169.npy → (30, 126)
# ✅ Normalizado: sample_250729215600232166.npy → (30, 126)
# ✅ Normalizado: sample_250729215500102473.npy → (30, 126)
#
# 📦 Normalizando muestras de: gracias
# ✅ Normalizado: sample_250729215827534281.npy → (30, 126)
# ✅ Normalizado: sample_250729215949104572.npy → (30, 126)
# ✅ Normalizado: sample_250729215822646649.npy → (30, 126)
# ✅ Normalizado: sample_250729215746068072.npy → (30, 126)
# ✅ Normalizado: sample_250729215743578537.npy → (30, 126)
# ✅ Normalizado: sample_250729215940544362.npy → (30, 126)
# ✅ Normalizado: sample_250729215809737498.npy → (30, 126)
# ✅ Normalizado: sample_250729215959151545.npy → (30, 126)
# ✅ Normalizado: sample_250729215804997602.npy → (30, 126)
# ✅ Normalizado: sample_250729215824987257.npy → (30, 126)
# ✅ Normalizado: sample_250729215943088505.npy → (30, 126)
# ✅ Normalizado: sample_250729215807458758.npy → (30, 126)
# ✅ Normalizado: sample_250729215758100038.npy → (30, 126)
# ✅ Normalizado: sample_250729220001871583.npy → (30, 126)
# ✅ Normalizado: sample_250729215946833813.npy → (30, 126)
# ✅ Normalizado: sample_250729215816983751.npy → (30, 126)
# ✅ Normalizado: sample_250729215748126443.npy → (30, 126)
# ✅ Normalizado: sample_250729215951578868.npy → (30, 126)
# ✅ Normalizado: sample_250729215750802232.npy → (30, 126)
# ✅ Normalizado: sample_250729215837090168.npy → (30, 126)
# ✅ Normalizado: sample_250729215832276354.npy → (30, 126)
# ✅ Normalizado: sample_250729215829958686.npy → (30, 126)
# ✅ Normalizado: sample_250729215839568937.npy → (30, 126)
# ✅ Normalizado: sample_250729215819904436.npy → (30, 126)
# ✅ Normalizado: sample_250729215815091311.npy → (30, 126)
# ✅ Normalizado: sample_250729215812628668.npy → (30, 126)
# ✅ Normalizado: sample_250729215834636403.npy → (30, 126)
# ✅ Normalizado: sample_250729215753493767.npy → (30, 126)
# ✅ Normalizado: sample_250729215755751557.npy → (30, 126)
# ✅ Normalizado: sample_250729215800575440.npy → (30, 126)

# %% [markdown]
# ## 4. Entrenamiento

# %%
# Número total de keypoints por frame: 21 puntos × 3 coords × 2 manos
LENGTH_KEYPOINTS = 126  
MODEL_PATH = "action.h5"

def get_model(max_length_frames, output_length: int):
    model = Sequential()
    model.add(LSTM(64, return_sequences=True, input_shape=(max_length_frames, LENGTH_KEYPOINTS), kernel_regularizer=l2(0.01)))
    model.add(Dropout(0.5))
    model.add(LSTM(128, return_sequences=False, kernel_regularizer=l2(0.001)))
    model.add(Dropout(0.5))
    model.add(Dense(64, activation='relu', kernel_regularizer=l2(0.001)))
    model.add(Dense(64, activation='relu', kernel_regularizer=l2(0.001)))
    model.add(Dense(output_length, activation='softmax'))

    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
    return model

# %%
def train_model_from_npy(epochs=300):
    X, y, label_map = load_dataset()
    print(f"✅ Total muestras: {X.shape[0]}, Clases: {len(label_map)}")

    X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.05, random_state=42)

    model = get_model(MODEL_FRAMES, output_length=len(label_map))

    early_stop = EarlyStopping(monitor="val_loss", patience=15, restore_best_weights=True, verbose=1)

    history = model.fit(
        X_train, y_train,
        validation_data=(X_val, y_val),
        epochs=epochs,
        batch_size=8,
        callbacks=[early_stop],
        verbose=1
    )

    model.save(MODEL_PATH)
    print(f"💾 Modelo guardado en: {MODEL_PATH}")

    # 📊 Matriz de Confusión
    y_pred = model.predict(X_val)
    y_pred_labels = np.argmax(y_pred, axis=1)
    y_true = np.argmax(y_val, axis=1)
    WORDS = list(label_map.keys())

    cm = confusion_matrix(y_true, y_pred_labels)
    disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=WORDS)
    disp.plot(cmap="Blues", values_format=".0f")
    plt.title("Matriz de Confusión - Validación")
    plt.show()

    # 📈 Diagnóstico
    train_acc = history.history['accuracy'][-1]
    val_acc = history.history['val_accuracy'][-1]
    print(f"\n📊 Accuracy final - Entrenamiento: {train_acc:.2f}, Validación: {val_acc:.2f}")
    if abs(train_acc - val_acc) > 0.2:
        print("⚠️ Posible overfitting")
    elif max(history.history['val_accuracy']) < 0.6:
        print("⚠️ Posible underfitting")
    else:
        print("✅ Buen desempeño general")

    return model, label_map

model, label_map = train_model_from_npy(epochs=150)
# Out:
# ✅ Total muestras: 60, Clases: 2
# Epoch 1/150
# 2025-07-29 22:45:58.638323: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2025-07-29 22:45:58.639168: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2025-07-29 22:45:58.639784: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2025-07-29 22:45:58.738279: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2025-07-29 22:45:58.739011: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2025-07-29 22:45:58.739626: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2025-07-29 22:45:58.891989: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2025-07-29 22:45:58.893257: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2025-07-29 22:45:58.893978: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2025-07-29 22:45:59.285531: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2025-07-29 22:45:59.286407: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2025-07-29 22:45:59.287064: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2025-07-29 22:45:59.810635: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2025-07-29 22:45:59.811675: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2025-07-29 22:45:59.812370: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2025-07-29 22:45:59.927179: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2025-07-29 22:45:59.927990: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2025-07-29 22:45:59.928659: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 5/8 [=================>............] - ETA: 0s - loss: 2.5451 - accuracy: 0.7250
# 2025-07-29 22:46:01.121509: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2025-07-29 22:46:01.122633: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2025-07-29 22:46:01.123288: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2025-07-29 22:46:01.225348: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2025-07-29 22:46:01.226051: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2025-07-29 22:46:01.226709: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 8/8 [==============================] - 3s 74ms/step - loss: 2.4819 - accuracy: 0.7368 - val_loss: 2.2896 - val_accuracy: 0.6667
# Epoch 2/150
# 8/8 [==============================] - 0s 25ms/step - loss: 2.1191 - accuracy: 0.7719 - val_loss: 2.0371 - val_accuracy: 0.6667
# Epoch 3/150
# 8/8 [==============================] - 0s 17ms/step - loss: 1.8519 - accuracy: 0.7719 - val_loss: 1.7944 - val_accuracy: 0.6667
# Epoch 4/150
# 8/8 [==============================] - 0s 15ms/step - loss: 1.6365 - accuracy: 0.7719 - val_loss: 1.5623 - val_accuracy: 0.6667
# Epoch 5/150
# 8/8 [==============================] - 0s 13ms/step - loss: 1.5143 - accuracy: 0.7719 - val_loss: 1.4343 - val_accuracy: 0.6667
# Epoch 6/150
# 8/8 [==============================] - 0s 24ms/step - loss: 1.3479 - accuracy: 0.7719 - val_loss: 1.2945 - val_accuracy: 0.6667
# Epoch 7/150
# 8/8 [==============================] - 0s 12ms/step - loss: 1.2574 - accuracy: 0.7719 - val_loss: 1.2647 - val_accuracy: 0.6667
# Epoch 8/150
# 8/8 [==============================] - 0s 21ms/step - loss: 1.1282 - accuracy: 0.7719 - val_loss: 1.0938 - val_accuracy: 0.6667
# Epoch 9/150
# 8/8 [==============================] - 0s 25ms/step - loss: 1.0610 - accuracy: 0.7544 - val_loss: 1.0649 - val_accuracy: 0.6667
# Epoch 10/150
# 8/8 [==============================] - 0s 19ms/step - loss: 0.9960 - accuracy: 0.7719 - val_loss: 1.0381 - val_accuracy: 0.6667
# Epoch 11/150
# 8/8 [==============================] - 0s 12ms/step - loss: 0.9801 - accuracy: 0.7719 - val_loss: 0.9284 - val_accuracy: 0.6667
# Epoch 12/150
# 8/8 [==============================] - 0s 17ms/step - loss: 0.8698 - accuracy: 0.7895 - val_loss: 0.8842 - val_accuracy: 0.6667
# Epoch 13/150
# 8/8 [==============================] - 0s 15ms/step - loss: 0.8304 - accuracy: 0.7719 - val_loss: 0.9097 - val_accuracy: 0.6667
# Epoch 14/150
# 8/8 [==============================] - 0s 20ms/step - loss: 0.8096 - accuracy: 0.7719 - val_loss: 0.7991 - val_accuracy: 0.6667
# Epoch 15/150
# 8/8 [==============================] - 0s 16ms/step - loss: 0.7459 - accuracy: 0.8947 - val_loss: 0.7242 - val_accuracy: 0.6667
# Epoch 16/150
# 8/8 [==============================] - 0s 26ms/step - loss: 0.6261 - accuracy: 0.9474 - val_loss: 0.4586 - val_accuracy: 1.0000
# Epoch 17/150
# 8/8 [==============================] - 0s 15ms/step - loss: 0.9775 - accuracy: 0.7895 - val_loss: 1.0115 - val_accuracy: 0.6667
# Epoch 18/150
# 8/8 [==============================] - 0s 16ms/step - loss: 0.8007 - accuracy: 0.7719 - val_loss: 0.8055 - val_accuracy: 0.6667
# Epoch 19/150
# 8/8 [==============================] - 0s 17ms/step - loss: 0.7394 - accuracy: 0.7719 - val_loss: 0.7534 - val_accuracy: 0.6667
# Epoch 20/150
# 8/8 [==============================] - 0s 20ms/step - loss: 0.7165 - accuracy: 0.7719 - val_loss: 0.7134 - val_accuracy: 0.6667
# Epoch 21/150
# 8/8 [==============================] - 0s 17ms/step - loss: 0.6762 - accuracy: 0.7719 - val_loss: 0.7317 - val_accuracy: 0.6667
# Epoch 22/150
# 8/8 [==============================] - 0s 12ms/step - loss: 0.6110 - accuracy: 0.8070 - val_loss: 0.6154 - val_accuracy: 0.6667
# Epoch 23/150
# 8/8 [==============================] - 0s 15ms/step - loss: 0.5990 - accuracy: 0.8772 - val_loss: 0.6860 - val_accuracy: 0.6667
# Epoch 24/150
# 8/8 [==============================] - 0s 13ms/step - loss: 0.5326 - accuracy: 0.9123 - val_loss: 0.3530 - val_accuracy: 1.0000
# Epoch 25/150
# 8/8 [==============================] - 0s 15ms/step - loss: 0.4045 - accuracy: 0.9649 - val_loss: 0.2895 - val_accuracy: 1.0000
# Epoch 26/150
# 8/8 [==============================] - 0s 20ms/step - loss: 0.3926 - accuracy: 0.9123 - val_loss: 0.3108 - val_accuracy: 1.0000
# Epoch 27/150
# 8/8 [==============================] - 0s 13ms/step - loss: 0.4343 - accuracy: 0.9474 - val_loss: 0.5115 - val_accuracy: 0.6667
# Epoch 28/150
# 8/8 [==============================] - 0s 20ms/step - loss: 0.9586 - accuracy: 0.7895 - val_loss: 1.0157 - val_accuracy: 0.6667
# Epoch 29/150
# 8/8 [==============================] - 0s 19ms/step - loss: 0.5803 - accuracy: 0.8947 - val_loss: 0.4078 - val_accuracy: 1.0000
# Epoch 30/150
# 8/8 [==============================] - 0s 17ms/step - loss: 0.4569 - accuracy: 0.9649 - val_loss: 0.5381 - val_accuracy: 0.6667
# Epoch 31/150
# 8/8 [==============================] - 0s 16ms/step - loss: 0.4224 - accuracy: 0.9474 - val_loss: 0.3206 - val_accuracy: 1.0000
# Epoch 32/150
# 8/8 [==============================] - 0s 12ms/step - loss: 0.4195 - accuracy: 0.9474 - val_loss: 0.9983 - val_accuracy: 0.6667
# Epoch 33/150
# 8/8 [==============================] - 0s 16ms/step - loss: 0.5962 - accuracy: 0.8421 - val_loss: 0.2917 - val_accuracy: 1.0000
# Epoch 34/150
# 8/8 [==============================] - 0s 14ms/step - loss: 0.3289 - accuracy: 0.9825 - val_loss: 0.4517 - val_accuracy: 1.0000
# Epoch 35/150
# 8/8 [==============================] - 0s 21ms/step - loss: 0.3410 - accuracy: 0.9825 - val_loss: 0.2851 - val_accuracy: 1.0000
# Epoch 36/150
# 8/8 [==============================] - 0s 15ms/step - loss: 0.3226 - accuracy: 0.9825 - val_loss: 0.4023 - val_accuracy: 1.0000
# Epoch 37/150
# 8/8 [==============================] - 0s 13ms/step - loss: 0.3117 - accuracy: 0.9649 - val_loss: 0.2536 - val_accuracy: 1.0000
# Epoch 38/150
# 8/8 [==============================] - 0s 13ms/step - loss: 0.3106 - accuracy: 0.9825 - val_loss: 0.3167 - val_accuracy: 1.0000
# Epoch 39/150
# 8/8 [==============================] - 0s 17ms/step - loss: 0.3095 - accuracy: 0.9825 - val_loss: 0.2448 - val_accuracy: 1.0000
# Epoch 40/150
# 8/8 [==============================] - 0s 17ms/step - loss: 0.3230 - accuracy: 0.9649 - val_loss: 0.2612 - val_accuracy: 1.0000
# Epoch 41/150
# 8/8 [==============================] - 0s 18ms/step - loss: 0.2833 - accuracy: 0.9825 - val_loss: 0.2611 - val_accuracy: 1.0000
# Epoch 42/150
# 8/8 [==============================] - 0s 12ms/step - loss: 0.2503 - accuracy: 1.0000 - val_loss: 0.2383 - val_accuracy: 1.0000
# Epoch 43/150
# 8/8 [==============================] - 0s 20ms/step - loss: 0.2762 - accuracy: 0.9649 - val_loss: 0.2584 - val_accuracy: 1.0000
# Epoch 44/150
# 8/8 [==============================] - 0s 18ms/step - loss: 0.2820 - accuracy: 0.9825 - val_loss: 0.2353 - val_accuracy: 1.0000
# Epoch 45/150
# 8/8 [==============================] - 0s 15ms/step - loss: 0.2436 - accuracy: 1.0000 - val_loss: 0.2371 - val_accuracy: 1.0000
# Epoch 46/150
# 8/8 [==============================] - 0s 16ms/step - loss: 0.2373 - accuracy: 1.0000 - val_loss: 0.2266 - val_accuracy: 1.0000
# Epoch 47/150
# 8/8 [==============================] - 0s 16ms/step - loss: 0.2360 - accuracy: 1.0000 - val_loss: 0.2682 - val_accuracy: 1.0000
# Epoch 48/150
# 8/8 [==============================] - 0s 14ms/step - loss: 0.2812 - accuracy: 0.9649 - val_loss: 0.2198 - val_accuracy: 1.0000
# Epoch 49/150
# 8/8 [==============================] - 0s 24ms/step - loss: 0.4521 - accuracy: 0.9649 - val_loss: 0.2403 - val_accuracy: 1.0000
# Epoch 50/150
# 8/8 [==============================] - 0s 17ms/step - loss: 0.2448 - accuracy: 1.0000 - val_loss: 0.6535 - val_accuracy: 0.6667
# Epoch 51/150
# 8/8 [==============================] - 0s 14ms/step - loss: 0.2886 - accuracy: 0.9825 - val_loss: 0.2700 - val_accuracy: 1.0000
# Epoch 52/150
# 8/8 [==============================] - 0s 17ms/step - loss: 0.2689 - accuracy: 0.9825 - val_loss: 0.2194 - val_accuracy: 1.0000
# Epoch 53/150
# 8/8 [==============================] - 0s 33ms/step - loss: 0.2291 - accuracy: 1.0000 - val_loss: 0.2213 - val_accuracy: 1.0000
# Epoch 54/150
# 8/8 [==============================] - 0s 15ms/step - loss: 0.2244 - accuracy: 1.0000 - val_loss: 0.2166 - val_accuracy: 1.0000
# Epoch 55/150
# 8/8 [==============================] - 0s 15ms/step - loss: 0.2147 - accuracy: 1.0000 - val_loss: 0.2105 - val_accuracy: 1.0000
# Epoch 56/150
# 8/8 [==============================] - 0s 19ms/step - loss: 0.2118 - accuracy: 1.0000 - val_loss: 0.2109 - val_accuracy: 1.0000
# Epoch 57/150
# 8/8 [==============================] - 0s 20ms/step - loss: 0.2072 - accuracy: 1.0000 - val_loss: 0.2087 - val_accuracy: 1.0000
# Epoch 58/150
# 8/8 [==============================] - 0s 16ms/step - loss: 0.2039 - accuracy: 1.0000 - val_loss: 0.2032 - val_accuracy: 1.0000
# Epoch 59/150
# 8/8 [==============================] - 0s 14ms/step - loss: 0.2012 - accuracy: 1.0000 - val_loss: 0.1995 - val_accuracy: 1.0000
# Epoch 60/150
# 8/8 [==============================] - 0s 18ms/step - loss: 0.1991 - accuracy: 1.0000 - val_loss: 0.1973 - val_accuracy: 1.0000
# Epoch 61/150
# 8/8 [==============================] - 0s 14ms/step - loss: 0.1989 - accuracy: 1.0000 - val_loss: 1.1352 - val_accuracy: 0.6667
# Epoch 62/150
# 8/8 [==============================] - 0s 26ms/step - loss: 0.5284 - accuracy: 0.8947 - val_loss: 0.2102 - val_accuracy: 1.0000
# Epoch 63/150
# 8/8 [==============================] - 0s 14ms/step - loss: 0.2550 - accuracy: 0.9825 - val_loss: 0.2081 - val_accuracy: 1.0000
# Epoch 64/150
# 8/8 [==============================] - 0s 16ms/step - loss: 0.3771 - accuracy: 0.9298 - val_loss: 0.2454 - val_accuracy: 1.0000
# Epoch 65/150
# 8/8 [==============================] - 0s 16ms/step - loss: 0.3841 - accuracy: 0.9298 - val_loss: 0.5772 - val_accuracy: 0.6667
# Epoch 66/150
# 8/8 [==============================] - 0s 14ms/step - loss: 0.4958 - accuracy: 0.8246 - val_loss: 0.2893 - val_accuracy: 1.0000
# Epoch 67/150
# 8/8 [==============================] - 0s 16ms/step - loss: 0.3449 - accuracy: 0.9825 - val_loss: 0.2294 - val_accuracy: 1.0000
# Epoch 68/150
# 8/8 [==============================] - 0s 16ms/step - loss: 0.2816 - accuracy: 0.9649 - val_loss: 0.2873 - val_accuracy: 1.0000
# Epoch 69/150
# 8/8 [==============================] - 0s 13ms/step - loss: 0.2269 - accuracy: 1.0000 - val_loss: 0.1996 - val_accuracy: 1.0000
# Epoch 70/150
# 8/8 [==============================] - 0s 33ms/step - loss: 0.2115 - accuracy: 1.0000 - val_loss: 0.2194 - val_accuracy: 1.0000
# Epoch 71/150
# 8/8 [==============================] - 0s 12ms/step - loss: 0.2252 - accuracy: 0.9825 - val_loss: 0.1923 - val_accuracy: 1.0000
# Epoch 72/150
# 8/8 [==============================] - 0s 21ms/step - loss: 0.2186 - accuracy: 0.9825 - val_loss: 0.1907 - val_accuracy: 1.0000
# Epoch 73/150
# 8/8 [==============================] - 0s 13ms/step - loss: 0.2294 - accuracy: 0.9825 - val_loss: 0.1879 - val_accuracy: 1.0000
# Epoch 74/150
# 8/8 [==============================] - 0s 12ms/step - loss: 0.2407 - accuracy: 0.9825 - val_loss: 0.1988 - val_accuracy: 1.0000
# Epoch 75/150
# 8/8 [==============================] - 0s 17ms/step - loss: 0.1907 - accuracy: 1.0000 - val_loss: 0.1854 - val_accuracy: 1.0000
# Epoch 76/150
# 8/8 [==============================] - 0s 13ms/step - loss: 0.1976 - accuracy: 1.0000 - val_loss: 0.1856 - val_accuracy: 1.0000
# Epoch 77/150
# 8/8 [==============================] - 0s 22ms/step - loss: 0.1866 - accuracy: 1.0000 - val_loss: 0.2151 - val_accuracy: 1.0000
# Epoch 78/150
# 8/8 [==============================] - 0s 15ms/step - loss: 0.2107 - accuracy: 0.9825 - val_loss: 0.1795 - val_accuracy: 1.0000
# Epoch 79/150
# 8/8 [==============================] - 0s 14ms/step - loss: 0.2330 - accuracy: 0.9825 - val_loss: 0.1880 - val_accuracy: 1.0000
# Epoch 80/150
# 8/8 [==============================] - 0s 25ms/step - loss: 0.2536 - accuracy: 0.9649 - val_loss: 0.1929 - val_accuracy: 1.0000
# Epoch 81/150
# 8/8 [==============================] - 0s 14ms/step - loss: 0.1837 - accuracy: 1.0000 - val_loss: 0.1837 - val_accuracy: 1.0000
# Epoch 82/150
# 8/8 [==============================] - 0s 15ms/step - loss: 0.1802 - accuracy: 1.0000 - val_loss: 0.1855 - val_accuracy: 1.0000
# Epoch 83/150
# 8/8 [==============================] - 0s 15ms/step - loss: 0.1887 - accuracy: 1.0000 - val_loss: 0.1748 - val_accuracy: 1.0000
# Epoch 84/150
# 8/8 [==============================] - 0s 13ms/step - loss: 0.1775 - accuracy: 1.0000 - val_loss: 0.1719 - val_accuracy: 1.0000
# Epoch 85/150
# 8/8 [==============================] - 0s 14ms/step - loss: 0.1772 - accuracy: 1.0000 - val_loss: 0.1987 - val_accuracy: 1.0000
# Epoch 86/150
# 8/8 [==============================] - 0s 12ms/step - loss: 0.1711 - accuracy: 1.0000 - val_loss: 0.1991 - val_accuracy: 1.0000
# Epoch 87/150
# 8/8 [==============================] - 0s 16ms/step - loss: 0.1684 - accuracy: 1.0000 - val_loss: 0.1711 - val_accuracy: 1.0000
# Epoch 88/150
# 8/8 [==============================] - 0s 15ms/step - loss: 0.1668 - accuracy: 1.0000 - val_loss: 0.1647 - val_accuracy: 1.0000
# Epoch 89/150
# 8/8 [==============================] - 0s 21ms/step - loss: 0.1670 - accuracy: 1.0000 - val_loss: 0.1642 - val_accuracy: 1.0000
# Epoch 90/150
# 8/8 [==============================] - 0s 17ms/step - loss: 0.1624 - accuracy: 1.0000 - val_loss: 0.1630 - val_accuracy: 1.0000
# Epoch 91/150
# 8/8 [==============================] - 0s 23ms/step - loss: 0.1621 - accuracy: 1.0000 - val_loss: 0.1607 - val_accuracy: 1.0000
# Epoch 92/150
# 8/8 [==============================] - 0s 16ms/step - loss: 0.1586 - accuracy: 1.0000 - val_loss: 0.1589 - val_accuracy: 1.0000
# Epoch 93/150
# 8/8 [==============================] - 0s 17ms/step - loss: 0.1577 - accuracy: 1.0000 - val_loss: 0.1565 - val_accuracy: 1.0000
# Epoch 94/150
# 8/8 [==============================] - 0s 14ms/step - loss: 0.1566 - accuracy: 1.0000 - val_loss: 0.1547 - val_accuracy: 1.0000
# Epoch 95/150
# 8/8 [==============================] - 0s 24ms/step - loss: 0.1544 - accuracy: 1.0000 - val_loss: 0.1528 - val_accuracy: 1.0000
# Epoch 96/150
# 8/8 [==============================] - 0s 16ms/step - loss: 0.1522 - accuracy: 1.0000 - val_loss: 0.1514 - val_accuracy: 1.0000
# Epoch 97/150
# 8/8 [==============================] - 0s 14ms/step - loss: 0.1515 - accuracy: 1.0000 - val_loss: 0.1501 - val_accuracy: 1.0000
# Epoch 98/150
# 8/8 [==============================] - 0s 15ms/step - loss: 0.1497 - accuracy: 1.0000 - val_loss: 0.1485 - val_accuracy: 1.0000
# Epoch 99/150
# 8/8 [==============================] - 0s 18ms/step - loss: 0.1479 - accuracy: 1.0000 - val_loss: 0.1471 - val_accuracy: 1.0000
# Epoch 100/150
# 8/8 [==============================] - 0s 15ms/step - loss: 0.1465 - accuracy: 1.0000 - val_loss: 0.1457 - val_accuracy: 1.0000
# Epoch 101/150
# 8/8 [==============================] - 0s 25ms/step - loss: 0.1453 - accuracy: 1.0000 - val_loss: 0.1442 - val_accuracy: 1.0000
# Epoch 102/150
# 8/8 [==============================] - 0s 19ms/step - loss: 0.1438 - accuracy: 1.0000 - val_loss: 0.1429 - val_accuracy: 1.0000
# Epoch 103/150
# 8/8 [==============================] - 0s 20ms/step - loss: 0.1418 - accuracy: 1.0000 - val_loss: 0.1417 - val_accuracy: 1.0000
# Epoch 104/150
# 8/8 [==============================] - 0s 17ms/step - loss: 0.1412 - accuracy: 1.0000 - val_loss: 0.1406 - val_accuracy: 1.0000
# Epoch 105/150
# 8/8 [==============================] - 0s 19ms/step - loss: 0.1478 - accuracy: 1.0000 - val_loss: 0.1380 - val_accuracy: 1.0000
# Epoch 106/150
# 8/8 [==============================] - 0s 20ms/step - loss: 0.1436 - accuracy: 1.0000 - val_loss: 0.1374 - val_accuracy: 1.0000
# Epoch 107/150
# 8/8 [==============================] - 0s 13ms/step - loss: 0.1453 - accuracy: 1.0000 - val_loss: 0.1361 - val_accuracy: 1.0000
# Epoch 108/150
# 8/8 [==============================] - 0s 21ms/step - loss: 0.1368 - accuracy: 1.0000 - val_loss: 0.1357 - val_accuracy: 1.0000
# Epoch 109/150
# 8/8 [==============================] - 0s 23ms/step - loss: 0.1368 - accuracy: 1.0000 - val_loss: 0.1345 - val_accuracy: 1.0000
# Epoch 110/150
# 8/8 [==============================] - 0s 21ms/step - loss: 0.1347 - accuracy: 1.0000 - val_loss: 0.1328 - val_accuracy: 1.0000
# Epoch 111/150
# 8/8 [==============================] - 0s 18ms/step - loss: 0.1328 - accuracy: 1.0000 - val_loss: 0.1314 - val_accuracy: 1.0000
# Epoch 112/150
# 8/8 [==============================] - 0s 20ms/step - loss: 0.1332 - accuracy: 1.0000 - val_loss: 0.1304 - val_accuracy: 1.0000
# Epoch 113/150
# 8/8 [==============================] - 0s 15ms/step - loss: 0.4644 - accuracy: 0.9298 - val_loss: 1.3364 - val_accuracy: 0.6667
# Epoch 114/150
# 8/8 [==============================] - 0s 15ms/step - loss: 0.8630 - accuracy: 0.7544 - val_loss: 0.7599 - val_accuracy: 0.6667
# Epoch 115/150
# 8/8 [==============================] - 0s 20ms/step - loss: 0.5043 - accuracy: 0.8246 - val_loss: 0.4513 - val_accuracy: 1.0000
# Epoch 116/150
# 8/8 [==============================] - 0s 16ms/step - loss: 0.4371 - accuracy: 0.8772 - val_loss: 0.4367 - val_accuracy: 0.6667
# Epoch 117/150
# 8/8 [==============================] - 0s 14ms/step - loss: 0.3231 - accuracy: 0.9649 - val_loss: 0.2670 - val_accuracy: 1.0000
# Epoch 118/150
# 8/8 [==============================] - 0s 22ms/step - loss: 0.2412 - accuracy: 1.0000 - val_loss: 0.2053 - val_accuracy: 1.0000
# Epoch 119/150
# 8/8 [==============================] - 0s 13ms/step - loss: 0.1907 - accuracy: 1.0000 - val_loss: 0.3567 - val_accuracy: 1.0000
# Epoch 120/150
# 8/8 [==============================] - 0s 15ms/step - loss: 0.1835 - accuracy: 0.9825 - val_loss: 0.7492 - val_accuracy: 0.6667
# Epoch 121/150
# 8/8 [==============================] - 0s 16ms/step - loss: 0.3199 - accuracy: 0.9298 - val_loss: 0.1545 - val_accuracy: 1.0000
# Epoch 122/150
# 8/8 [==============================] - 0s 15ms/step - loss: 0.2109 - accuracy: 0.9649 - val_loss: 0.1625 - val_accuracy: 1.0000
# Epoch 123/150
# 8/8 [==============================] - 0s 16ms/step - loss: 0.1656 - accuracy: 1.0000 - val_loss: 0.1527 - val_accuracy: 1.0000
# Epoch 124/150
# 8/8 [==============================] - 0s 17ms/step - loss: 0.1840 - accuracy: 0.9825 - val_loss: 0.2298 - val_accuracy: 1.0000
# Epoch 125/150
# 8/8 [==============================] - 0s 27ms/step - loss: 0.2242 - accuracy: 0.9649 - val_loss: 0.1587 - val_accuracy: 1.0000
# Epoch 126/150
# 8/8 [==============================] - 0s 14ms/step - loss: 0.2038 - accuracy: 0.9649 - val_loss: 0.1487 - val_accuracy: 1.0000
# Epoch 127/150
# 7/8 [=========================>....] - ETA: 0s - loss: 0.1751 - accuracy: 0.9821Restoring model weights from the end of the best epoch: 112.
# 8/8 [==============================] - 0s 24ms/step - loss: 0.2040 - accuracy: 0.9649 - val_loss: 0.1538 - val_accuracy: 1.0000
# Epoch 127: early stopping
# 💾 Modelo guardado en: action.h5
# 2025-07-29 22:46:18.577895: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2025-07-29 22:46:18.578740: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2025-07-29 22:46:18.579558: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2025-07-29 22:46:18.672335: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2025-07-29 22:46:18.673052: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2025-07-29 22:46:18.674379: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 1/1 [==============================] - 0s 330ms/step
# 📊 Accuracy final - Entrenamiento: 0.96, Validación: 1.00
# ✅ Buen desempeño general

# %% [markdown]
# ## 5. Validaciones

# %%
LENGTH_KEYPOINTS = 126

def get_model(max_length_frames, output_length: int):
    model = Sequential()
    model.add(LSTM(64, return_sequences=True, input_shape=(max_length_frames, LENGTH_KEYPOINTS), kernel_regularizer=l2(0.01)))
    model.add(Dropout(0.5))
    model.add(LSTM(128, return_sequences=False, kernel_regularizer=l2(0.001)))
    model.add(Dropout(0.5))
    model.add(Dense(64, activation='relu', kernel_regularizer=l2(0.001)))
    model.add(Dense(64, activation='relu', kernel_regularizer=l2(0.001)))
    model.add(Dense(output_length, activation='softmax'))
    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
    return model

# %%
MODEL_PATH = "action.h5"
DATA_PATH = "data/frases"
WORDS = sorted(os.listdir(DATA_PATH))  # nombres de las clases
MODEL_FRAMES = 30
MIN_LENGTH_FRAMES = 10
FONT = cv2.FONT_HERSHEY_SIMPLEX
FONT_POS = (10, 30)
FONT_SIZE = 1

def mediapipe_detection(image, model):
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    image.flags.writeable = False
    return model.process(image)

def there_hand(results):
    return results.left_hand_landmarks or results.right_hand_landmarks

def extract_keypoints(results):
    lh = np.array([[res.x, res.y, res.z] for res in results.left_hand_landmarks.landmark]) if results.left_hand_landmarks else np.zeros((21, 3))
    rh = np.array([[res.x, res.y, res.z] for res in results.right_hand_landmarks.landmark]) if results.right_hand_landmarks else np.zeros((21, 3))
    return np.concatenate([lh, rh]).flatten()

def normalize_keypoints(keypoints, target_length=30):
    current_length = len(keypoints)
    if current_length == target_length:
        return keypoints
    elif current_length > target_length:
        step = current_length / target_length
        indices = np.arange(0, current_length, step).astype(int)[:target_length]
        return [keypoints[i] for i in indices]
    else:
        indices = np.linspace(0, current_length - 1, target_length)
        interpolated = []
        for i in indices:
            lower = int(np.floor(i))
            upper = int(np.ceil(i))
            weight = i - lower
            if lower == upper:
                interpolated.append(keypoints[lower])
            else:
                interpolated.append(((1 - weight) * np.array(keypoints[lower]) + weight * np.array(keypoints[upper])).tolist())
        return interpolated

def draw_keypoints(image, results):
    mp_drawing = mp.solutions.drawing_utils
    if results.left_hand_landmarks:
        mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp.solutions.holistic.HAND_CONNECTIONS)
    if results.right_hand_landmarks:
        mp_drawing.draw_landmarks(image, results.right_hand_landmarks, mp.solutions.holistic.HAND_CONNECTIONS)

# %%
def evaluate_model(threshold=0.8, margin_frame=1, delay_frames=3, src=0):
    print("🟡 Cargando modelo...")
    model = load_model(MODEL_PATH)

    print("📷 Inicializando cámara...")
    cap = cv2.VideoCapture(src)
    if not cap.isOpened():
        print("❌ No se pudo abrir la cámara.")
        return

    sentence = []
    pred_label = ""
    pred_prob = 0.0
    kp_seq, count_frame, fix_frames = [], 0, 0
    recording = False

    with Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
        print("🎥 Traductor en vivo iniciado. Presiona 'q' para salir.")
        while True:
            ret, frame = cap.read()
            if not ret:
                print("⚠️ No se pudo leer el frame de la cámara.")
                break

            results = mediapipe_detection(frame, holistic)

            if there_hand(results) or recording:
                recording = False
                count_frame += 1
                if count_frame > margin_frame:
                    kp_frame = extract_keypoints(results)
                    kp_seq.append(kp_frame)
            else:
                if count_frame >= MIN_LENGTH_FRAMES + margin_frame:
                    fix_frames += 1
                    if fix_frames < delay_frames:
                        recording = True
                        continue

                    kp_seq = kp_seq[: -(margin_frame + delay_frames)]
                    kp_normalized = normalize_keypoints(kp_seq, target_length=MODEL_FRAMES)
                    input_data = np.expand_dims(np.array(kp_normalized), axis=0)

                    prediction = model.predict(input_data, verbose=0)[0]
                    max_idx = np.argmax(prediction)
                    max_prob = prediction[max_idx]

                    if max_prob > threshold:
                        pred_label = WORDS[max_idx]
                        pred_prob = max_prob * 100
                        sentence.insert(0, pred_label)

                kp_seq = []
                count_frame = 0
                fix_frames = 0
                recording = False

            # Mostrar texto y porcentaje en ventana
            cv2.rectangle(frame, (0, 0), (640, 60), (245, 117, 16), -1)
            cv2.putText(frame, f'{pred_label.upper()} ({pred_prob:.1f}%)', FONT_POS, FONT, FONT_SIZE, (255, 255, 255), 2)

            draw_keypoints(frame, results)
            cv2.imshow('Traductor LSP', frame)

            if cv2.waitKey(10) & 0xFF == ord('q'):
                print("🛑 Cerrando traductor.")
                break

        cap.release()
        cv2.destroyAllWindows()

if __name__ == "__main__":
    evaluate_model()
# Out:
# 🟡 Cargando modelo...
# 2025-07-31 18:39:51.858298: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2025-07-31 18:39:51.859603: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2025-07-31 18:39:51.860368: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2025-07-31 18:39:51.956167: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2025-07-31 18:39:51.956941: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2025-07-31 18:39:51.957603: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 📷 Inicializando cámara...
# libEGL warning: MESA-LOADER: failed to open iris: /usr/lib/dri/iris_dri.so: cannot open shared object file: No such file or directory (search paths /usr/lib/x86_64-linux-gnu/dri:\$${ORIGIN}/dri:/usr/lib/dri, suffix _dri)
#
# libEGL warning: MESA-LOADER: failed to open iris: /usr/lib/dri/iris_dri.so: cannot open shared object file: No such file or directory (search paths /usr/lib/x86_64-linux-gnu/dri:\$${ORIGIN}/dri:/usr/lib/dri, suffix _dri)
#
# libEGL warning: MESA-LOADER: failed to open swrast: /usr/lib/dri/swrast_dri.so: cannot open shared object file: No such file or directory (search paths /usr/lib/x86_64-linux-gnu/dri:\$${ORIGIN}/dri:/usr/lib/dri, suffix _dri)
#
# libEGL warning: MESA-LOADER: failed to open iris: /usr/lib/dri/iris_dri.so: cannot open shared object file: No such file or directory (search paths /usr/lib/x86_64-linux-gnu/dri:\$${ORIGIN}/dri:/usr/lib/dri, suffix _dri)
#
# libEGL warning: MESA-LOADER: failed to open iris: /usr/lib/dri/iris_dri.so: cannot open shared object file: No such file or directory (search paths /usr/lib/x86_64-linux-gnu/dri:\$${ORIGIN}/dri:/usr/lib/dri, suffix _dri)
#
# libEGL warning: MESA-LOADER: failed to open swrast: /usr/lib/dri/swrast_dri.so: cannot open shared object file: No such file or directory (search paths /usr/lib/x86_64-linux-gnu/dri:\$${ORIGIN}/dri:/usr/lib/dri, suffix _dri)
#
# libEGL warning: MESA-LOADER: failed to open iris: /usr/lib/dri/iris_dri.so: cannot open shared object file: No such file or directory (search paths /usr/lib/x86_64-linux-gnu/dri:\$${ORIGIN}/dri:/usr/lib/dri, suffix _dri)
#
# libEGL warning: MESA-LOADER: failed to open iris: /usr/lib/dri/iris_dri.so: cannot open shared object file: No such file or directory (search paths /usr/lib/x86_64-linux-gnu/dri:\$${ORIGIN}/dri:/usr/lib/dri, suffix _dri)
#
# libEGL warning: MESA-LOADER: failed to open swrast: /usr/lib/dri/swrast_dri.so: cannot open shared object file: No such file or directory (search paths /usr/lib/x86_64-linux-gnu/dri:\$${ORIGIN}/dri:/usr/lib/dri, suffix _dri)
#
# libEGL warning: MESA-LOADER: failed to open iris: /usr/lib/dri/iris_dri.so: cannot open shared object file: No such file or directory (search paths /usr/lib/x86_64-linux-gnu/dri:\$${ORIGIN}/dri:/usr/lib/dri, suffix _dri)
#
# libEGL warning: MESA-LOADER: failed to open iris: /usr/lib/dri/iris_dri.so: cannot open shared object file: No such file or directory (search paths /usr/lib/x86_64-linux-gnu/dri:\$${ORIGIN}/dri:/usr/lib/dri, suffix _dri)
#
# libEGL warning: MESA-LOADER: failed to open swrast: /usr/lib/dri/swrast_dri.so: cannot open shared object file: No such file or directory (search paths /usr/lib/x86_64-linux-gnu/dri:\$${ORIGIN}/dri:/usr/lib/dri, suffix _dri)
#
# libEGL warning: MESA-LOADER: failed to open iris: /usr/lib/dri/iris_dri.so: cannot open shared object file: No such file or directory (search paths /usr/lib/x86_64-linux-gnu/dri:\$${ORIGIN}/dri:/usr/lib/dri, suffix _dri)
#
# libEGL warning: MESA-LOADER: failed to open iris: /usr/lib/dri/iris_dri.so: cannot open shared object file: No such file or directory (search paths /usr/lib/x86_64-linux-gnu/dri:\$${ORIGIN}/dri:/usr/lib/dri, suffix _dri)
#
# libEGL warning: MESA-LOADER: failed to open swrast: /usr/lib/dri/swrast_dri.so: cannot open shared object file: No such file or directory (search paths /usr/lib/x86_64-linux-gnu/dri:\$${ORIGIN}/dri:/usr/lib/dri, suffix _dri)
#
# libEGL warning: MESA-LOADER: failed to open iris: /usr/lib/dri/iris_dri.so: cannot open shared object file: No such file or directory (search paths /usr/lib/x86_64-linux-gnu/dri:\$${ORIGIN}/dri:/usr/lib/dri, suffix _dri)
#
# libEGL warning: MESA-LOADER: failed to open iris: /usr/lib/dri/iris_dri.so: cannot open shared object file: No such file or directory (search paths /usr/lib/x86_64-linux-gnu/dri:\$${ORIGIN}/dri:/usr/lib/dri, suffix _dri)
#
# libEGL warning: MESA-LOADER: failed to open swrast: /usr/lib/dri/swrast_dri.so: cannot open shared object file: No such file or directory (search paths /usr/lib/x86_64-linux-gnu/dri:\$${ORIGIN}/dri:/usr/lib/dri, suffix _dri)
#
# libEGL warning: MESA-LOADER: failed to open iris: /usr/lib/dri/iris_dri.so: cannot open shared object file: No such file or directory (search paths /usr/lib/x86_64-linux-gnu/dri:\$${ORIGIN}/dri:/usr/lib/dri, suffix _dri)
#
# libEGL warning: MESA-LOADER: failed to open iris: /usr/lib/dri/iris_dri.so: cannot open shared object file: No such file or directory (search paths /usr/lib/x86_64-linux-gnu/dri:\$${ORIGIN}/dri:/usr/lib/dri, suffix _dri)
#
# libEGL warning: MESA-LOADER: failed to open swrast: /usr/lib/dri/swrast_dri.so: cannot open shared object file: No such file or directory (search paths /usr/lib/x86_64-linux-gnu/dri:\$${ORIGIN}/dri:/usr/lib/dri, suffix _dri)
#
# libEGL warning: MESA-LOADER: failed to open iris: /usr/lib/dri/iris_dri.so: cannot open shared object file: No such file or directory (search paths /usr/lib/x86_64-linux-gnu/dri:\$${ORIGIN}/dri:/usr/lib/dri, suffix _dri)
#
# libEGL warning: MESA-LOADER: failed to open iris: /usr/lib/dri/iris_dri.so: cannot open shared object file: No such file or directory (search paths /usr/lib/x86_64-linux-gnu/dri:\$${ORIGIN}/dri:/usr/lib/dri, suffix _dri)
#
# libEGL warning: MESA-LOADER: failed to open swrast: /usr/lib/dri/swrast_dri.so: cannot open shared object file: No such file or directory (search paths /usr/lib/x86_64-linux-gnu/dri:\$${ORIGIN}/dri:/usr/lib/dri, suffix _dri)
#
# libEGL warning: MESA-LOADER: failed to open iris: /usr/lib/dri/iris_dri.so: cannot open shared object file: No such file or directory (search paths /usr/lib/x86_64-linux-gnu/dri:\$${ORIGIN}/dri:/usr/lib/dri, suffix _dri)
#
# libEGL warning: MESA-LOADER: failed to open iris: /usr/lib/dri/iris_dri.so: cannot open shared object file: No such file or directory (search paths /usr/lib/x86_64-linux-gnu/dri:\$${ORIGIN}/dri:/usr/lib/dri, suffix _dri)
#
# libEGL warning: MESA-LOADER: failed to open swrast: /usr/lib/dri/swrast_dri.so: cannot open shared object file: No such file or directory (search paths /usr/lib/x86_64-linux-gnu/dri:\$${ORIGIN}/dri:/usr/lib/dri, suffix _dri)
#
# libEGL warning: MESA-LOADER: failed to open iris: /usr/lib/dri/iris_dri.so: cannot open shared object file: No such file or directory (search paths /usr/lib/x86_64-linux-gnu/dri:\$${ORIGIN}/dri:/usr/lib/dri, suffix _dri)
#
# libEGL warning: MESA-LOADER: failed to open iris: /usr/lib/dri/iris_dri.so: cannot open shared object file: No such file or directory (search paths /usr/lib/x86_64-linux-gnu/dri:\$${ORIGIN}/dri:/usr/lib/dri, suffix _dri)
#
# libEGL warning: MESA-LOADER: failed to open swrast: /usr/lib/dri/swrast_dri.so: cannot open shared object file: No such file or directory (search paths /usr/lib/x86_64-linux-gnu/dri:\$${ORIGIN}/dri:/usr/lib/dri, suffix _dri)
#
# libEGL warning: MESA-LOADER: failed to open iris: /usr/lib/dri/iris_dri.so: cannot open shared object file: No such file or directory (search paths /usr/lib/x86_64-linux-gnu/dri:\$${ORIGIN}/dri:/usr/lib/dri, suffix _dri)
#
# libEGL warning: MESA-LOADER: failed to open iris: /usr/lib/dri/iris_dri.so: cannot open shared object file: No such file or directory (search paths /usr/lib/x86_64-linux-gnu/dri:\$${ORIGIN}/dri:/usr/lib/dri, suffix _dri)
#
# libEGL warning: MESA-LOADER: failed to open swrast: /usr/lib/dri/swrast_dri.so: cannot open shared object file: No such file or directory (search paths /usr/lib/x86_64-linux-gnu/dri:\$${ORIGIN}/dri:/usr/lib/dri, suffix _dri)
#
# libEGL warning: MESA-LOADER: failed to open iris: /usr/lib/dri/iris_dri.so: cannot open shared object file: No such file or directory (search paths /usr/lib/x86_64-linux-gnu/dri:\$${ORIGIN}/dri:/usr/lib/dri, suffix _dri)
#
# libEGL warning: MESA-LOADER: failed to open iris: /usr/lib/dri/iris_dri.so: cannot open shared object file: No such file or directory (search paths /usr/lib/x86_64-linux-gnu/dri:\$${ORIGIN}/dri:/usr/lib/dri, suffix _dri)
#
# libEGL warning: MESA-LOADER: failed to open swrast: /usr/lib/dri/swrast_dri.so: cannot open shared object file: No such file or directory (search paths /usr/lib/x86_64-linux-gnu/dri:\$${ORIGIN}/dri:/usr/lib/dri, suffix _dri)
#
# libEGL warning: MESA-LOADER: failed to open iris: /usr/lib/dri/iris_dri.so: cannot open shared object file: No such file or directory (search paths /usr/lib/x86_64-linux-gnu/dri:\$${ORIGIN}/dri:/usr/lib/dri, suffix _dri)
#
# libEGL warning: MESA-LOADER: failed to open iris: /usr/lib/dri/iris_dri.so: cannot open shared object file: No such file or directory (search paths /usr/lib/x86_64-linux-gnu/dri:\$${ORIGIN}/dri:/usr/lib/dri, suffix _dri)
#
# libEGL warning: MESA-LOADER: failed to open swrast: /usr/lib/dri/swrast_dri.so: cannot open shared object file: No such file or directory (search paths /usr/lib/x86_64-linux-gnu/dri:\$${ORIGIN}/dri:/usr/lib/dri, suffix _dri)
#
# W0000 00:00:1754008792.693882   16778 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1754008792.717579   16778 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1754008792.719061   16785 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1754008792.719717   16778 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1754008792.720419   16788 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1754008792.725317   16785 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1754008792.731633   16788 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1754008792.732443   16778 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# 🎥 Traductor en vivo iniciado. Presiona 'q' para salir.
# 2025-07-31 18:40:14.257324: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2025-07-31 18:40:14.257972: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2025-07-31 18:40:14.258680: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2025-07-31 18:40:14.346846: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2025-07-31 18:40:14.347563: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2025-07-31 18:40:14.348146: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 🛑 Cerrando traductor.
